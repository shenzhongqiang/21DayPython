# %% [markdown]
# # os库 - 操作系统接口

# %%
# 获取当前的工作目录
import os
os.getcwd()
# Out:
# '/Users/shenzhongqiang/Documents/21DayPython'

# %%
# 获取环境变量
os.environ
# Out:
# environ{'TERM_PROGRAM': 'iTerm.app',
#         'TERM': 'xterm-color',
#         'SHELL': '/bin/bash',
#         'TMPDIR': '/var/folders/mg/6nmjk6vx37z7y6yww9hr0swm0000gn/T/',
#         'CONDA_SHLVL': '1',
#         'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.QNpFYG4jmB/Render',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'TERM_PROGRAM_VERSION': '3.3.3',
#         'TERM_SESSION_ID': 'w0t0p0:E0D9773F-09F1-4B7C-A71E-F200F3738B57',
#         'USER': 'shenzhongqiang',
#         'CONDA_EXE': '/Users/shenzhongqiang/anaconda3/bin/conda',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.K7jvKhxQDg/Listeners',
#         'HOMEBREW_NO_AUTO_UPDATE': '1',
#         '__CF_USER_TEXT_ENCODING': '0x0:25:52',
#         '_CE_CONDA': '',
#         'PATH': '/Users/shenzhongqiang/anaconda3/bin:/Users/shenzhongqiang/anaconda3/condabin:/Library/Frameworks/Python.framework/Versions/3.8/bin:/Library/Frameworks/Python.framework/Versions/3.6/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Frameworks/Mono.framework/Versions/Current/Commands:/Users/shenzhongqiang/go-workspace/bin:/usr/local/opt/go/libexec/bin',
#         'CONDA_PREFIX': '/Users/shenzhongqiang/anaconda3',
#         'PWD': '/Users/shenzhongqiang/Documents/21DayPython',
#         'LANG': 'en_US.UTF-8',
#         'ITERM_PROFILE': 'Default',
#         'XPC_FLAGS': '0x0',
#         '_CE_M': '',
#         'XPC_SERVICE_NAME': '0',
#         'SHLVL': '1',
#         'HOME': '/Users/shenzhongqiang',
#         'COLORFGBG': '7;0',
#         'GOROOT': '/usr/local/opt/go/libexec',
#         'LC_TERMINAL_VERSION': '3.3.3',
#         'ITERM_SESSION_ID': 'w0t0p0:E0D9773F-09F1-4B7C-A71E-F200F3738B57',
#         'CONDA_PYTHON_EXE': '/Users/shenzhongqiang/anaconda3/bin/python',
#         'LOGNAME': 'shenzhongqiang',
#         'GOPATH': '/Users/shenzhongqiang/go-workspace',
#         'CONDA_DEFAULT_ENV': 'base',
#         'LC_TERMINAL': 'iTerm2',
#         'COLORTERM': 'truecolor',
#         '_': '/Users/shenzhongqiang/anaconda3/bin/jupyter',
#         'OLDPWD': '/Users/shenzhongqiang',
#         'KERNEL_LAUNCH_TIMEOUT': '40',
#         'JPY_PARENT_PID': '48472',
#         'CLICOLOR': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'}

# %% [markdown]
# # os.path库 - 常用路径操作

# %%
# 返回路径的基本名称
# linux/mac
os.path.basename("/usr/bin/python")
# windows
os.path.basename("C:\Windows\System32")
# Out:
# 'C:\\Windows\\System32'

# %%
# 返回路径的目录名称
# linux/mac
os.path.dirname("/usr/bin/python")
# windows
os.path.dirname("C:\Windows\System32")
# Out:
# ''

# %%
# 检查文件是否存在
# linux/mac
os.path.exists("/usr/bin/python")
# windows
os.path.exists("C:\Windows\System32")
# Out:
# False

# %%
# 检查路径是否是文件
# linux/mac
os.path.isfile("/usr/bin/python")
# windows
os.path.isfile("C:\Windows\System32")
# Out:
# False

# %%
# 检查路径是否是目录
# linux/mac
os.path.isdir("/usr/bin/python")
# windows
os.path.isdir("C:\Windows\System32")
# Out:
# False

# %%
# 合并路径
# linux/mac
os.path.join("/usr", "bin", "python")
# windows
os.path.join("C:\Windows", "System32")
# Out:
# 'C:\\Windows/System32'

# %% [markdown]
# # math - 数学函数

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
# 计算cosine
math.cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %%
# 计算对数
math.log(1024, 2)
# Out:
# 10.0

# %%
# 向下取整
math.floor(3.1)
# Out:
# 3

# %%
# 向上取整
math.ceil(3.1)
# Out:
# 4

# %%
# 指数运算
math.pow(2, 10)
# Out:
# 1024.0

# %%
# 平方根
math.sqrt(2)
# Out:
# 1.4142135623730951

# %% [markdown]
# # 练习一 - 见PPT

# %% [markdown]
# # random库 - 生成随机数

# %%
import random
# 从非空序列返回一个随机元素
random.choice(['apple', 'pear', 'banana'])
# Out:
# 'apple'

# %%
# 无重复的随机抽样
# 第一参数指定序列，第二个参数指定长度
random.sample(range(10), 5)
# Out:
# [4, 1, 7, 3, 9]

# %%
# 返回 [0.0, 1.0) 范围内的随机浮点数
random.random()
# Out:
# 0.8625643453628713

# %%
# 将序列随机打乱位置。
x = list(range(10))
random.shuffle(x)
print(x)
# Out:
# [9, 3, 0, 7, 2, 4, 6, 5, 8, 1]

# %%
# 返回随机整数
random.randint(1, 10)
# Out:
# 5

# %% [markdown]
# # 练习二 - 见PPT

# %% [markdown]
# # time库 - 时间的访问和转换

# %%
import time
# 睡10秒
time.sleep(10)

# %%
# 返回 seconds since the epoch 
# 什么是epoch？ epoch是1970年1月1日00:00:00（UTC）
time.time()
# Out:
# 1580816141.9111118

# %% [markdown]
# # datetime库 - 日期和时间处理

# %%
import datetime
# date类 - 表示日期
# 创建date对象
d = datetime.date(year=2020, month=1, day=1)
print(d)
# 获取今天的日期
d = datetime.date.today()
# 获取星期几，星期一为0，星期天为6
d.weekday()
# Out:
# 2020-01-01
# 1

# %%
# datetime类
# 创建datetime对象
dt = datetime.datetime(year=2020, month=1, day=1, hour=9, minute=0, second=0)
print(dt)
# Out:
# 2020-01-01 09:00:00

# %%
# 获取当前时间
dt = datetime.datetime.now()
print(dt)
# Out:
# 2020-02-04 19:35:41.953452

# %%
# timedelta类 - 表示时间间隔
# 创建timedelta对象
delta = datetime.timedelta(days=5)
print(delta)
# Out:
# 5 days, 0:00:00

# %%
# 时间运算
# 计算7天前的时间
today = datetime.datetime.now()
today - datetime.timedelta(days=7)
# Out:
# datetime.datetime(2020, 1, 28, 19, 35, 41, 981971)

# %%
# 计算两个日期间隔了多少时间
today = datetime.date.today()
new_year_day = datetime.date(year=2020, month=1, day=1)
today-new_year_day
# Out:
# datetime.timedelta(days=34)

# %%
# 格式化时间
today = datetime.datetime.now()
today.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2020-02-04 19:35:42'

# %%
# 解析时间字符串
date_string = "2020-01-01 09:00:00"
dt = datetime.datetime.strptime(date_string, "%Y-%m-%d %H:%M:%S")
print(type(dt))
print(dt)
# Out:
# <class 'datetime.datetime'>
# 2020-01-01 09:00:00

# %%
# 所有日期和时间的格式代码，可参考
# https://docs.python.org/zh-cn/3/library/datetime.html#strftime-and-strptime-format-codes

# %% [markdown]
# # 练习三 - 见PPT

# %% [markdown]
# # 练习四 - 见PPT
