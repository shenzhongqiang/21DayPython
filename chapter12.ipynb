# %% [markdown]
# # matplotlib介绍
# + John Hunter创建于2002年
#
# + 仿照MATLAB的函数形式的绘图接口
#
# + 衍生了出多个数据可视化工具集

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 绘制折线图

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
# 绘制多组数据
import numpy as np
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # 绘制散点图

# %%
import numpy as np
x = np.arange(20)
noise = np.random.randn(20)
y = 5*x + 5 + noise *10
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # 绘制直方图

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
plt.hist(x, 50)
plt.show()

# %% [markdown]
# # 绘制柱状图

# %%
models = ['iphone11', 'mate30', 'Xiaomi9']
sales = [20, 30, 15]
plt.bar(models, sales)
plt.show()

# %% [markdown]
# # 绘制饼图

# %%
models = ['iphone11', 'iphoneX', 'iphoneXs']
sales = [30, 20, 10]
plt.pie(sales, explode=[0,0,0.1], labels=models, autopct='%.2f%%')
plt.show()

# %% [markdown]
# # 绘制箱线图

# %%
all_data=[np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(all_data, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1173752d0>,
#   <matplotlib.lines.Line2D at 0x117375310>,
#   <matplotlib.lines.Line2D at 0x117388590>,
#   <matplotlib.lines.Line2D at 0x1173885d0>,
#   <matplotlib.lines.Line2D at 0x11739b650>,
#   <matplotlib.lines.Line2D at 0x11739bc10>],
#  'caps': [<matplotlib.lines.Line2D at 0x117375890>,
#   <matplotlib.lines.Line2D at 0x117375e50>,
#   <matplotlib.lines.Line2D at 0x117388b10>,
#   <matplotlib.lines.Line2D at 0x117388b90>,
#   <matplotlib.lines.Line2D at 0x11739bcd0>,
#   <matplotlib.lines.Line2D at 0x1173a3690>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x11736aa10>,
#   <matplotlib.patches.PathPatch at 0x11737fe50>,
#   <matplotlib.patches.PathPatch at 0x117392f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x11737f890>,
#   <matplotlib.lines.Line2D at 0x117392a10>,
#   <matplotlib.lines.Line2D at 0x1173a3750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11737fdd0>,
#   <matplotlib.lines.Line2D at 0x117392f10>,
#   <matplotlib.lines.Line2D at 0x1173a3bd0>],
#  'means': []}

# %% [markdown]
# # 创建子图

# %%
# Figure
fig = plt.figure()

# Subplot
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# 理解subplot，见PPT

# %%
# 在子图上绘图
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.plot(np.arange(10))
ax2.scatter(np.arange(10), 2*np.arange(10))
ax3.hist(np.random.randn(100), bins=20)
# Out:
# (array([ 1.,  1.,  1.,  1.,  2.,  1.,  8., 10.,  7., 12., 10.,  8., 10.,
#          8.,  5.,  2.,  6.,  3.,  3.,  1.]),
#  array([-2.28482391, -2.06675962, -1.84869534, -1.63063105, -1.41256677,
#         -1.19450248, -0.97643819, -0.75837391, -0.54030962, -0.32224534,
#         -0.10418105,  0.11388323,  0.33194752,  0.5500118 ,  0.76807609,
#          0.98614038,  1.20420466,  1.42226895,  1.64033323,  1.85839752,
#          2.0764618 ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # 常用的可定制属性

# %%
# 设置颜色
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(10)
y = np.arange(10) ** 2

ax.plot(x, y, color='g')
ax.plot(x, y, color='#CECECE')
ax.scatter(x, y, color='r')

# %%
# 设置标记
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.plot(x, y, marker='o')
ax.plot(x, y, marker='*')

# %%
# 设置线型
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.plot(x, y, linestyle='-')
ax.plot(x, y, linestyle='--')

# %%
# 设置刻度位置
x = np.arange(100)
y = np.sin(x/50*np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.set_xticks([0, 50, 100])
ax.set_yticks([-1, 0, 1])
ax.plot(x, y)

# %%
# 设置刻度标签
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)
ax.set_xticks([0, 50, 100])

labels = ax.set_xticklabels(['one','two','three'])
ax.plot(x,y)

# %%
# 设置图表范围
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)

ax.set_xlim(0, 200)
ax.set_ylim(-10, 10)
ax.plot(x,y)

# %%
# 设置标题
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)

ax.set_title('Sine Wave')
ax.plot(x,y)

# %%
# 设置轴标签
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.plot(x,y)

# %%
# 批量设定属性
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)

props = {
    'title': 'Sine Wave',
    'xlabel': 'x',
    'ylabel': 'y',
}
ax.set(**props)
ax.plot(x,y)

# %%
# 添加图例
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)
y2 = np.sin(x/50*np.pi) + 2

ax.plot(x, y, label='one')
ax.plot(x, y2, label='two')
ax.legend()

# %%
# 添加注解
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
x = np.arange(100)
y = np.sin(x/50*np.pi)
ax.text(50, 1, 'Hello world!',
  family='monospace', fontsize=10)
ax.plot(x, y)

# %%
# 添加指向性注解
x = np.arange(100)
y = np.sin(x/50*np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks([0, 50, 100])
ax.set_yticks([-1, 0, 1])
ax.set_ylim(-1.5, 1.5)

ax.annotate('peak', xy=(25,1),
                xytext=(30, 1.5),
                arrowprops=dict(facecolor='black', headwidth=6, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')
ax.annotate('valley', xy=(75,-1),
                xytext=(80, -0.5),
                arrowprops=dict(facecolor='black', headwidth=6, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')
ax.plot(x,y, label='one')
ax.legend()

# %%
# 自动调整x轴上的日期，为了更清楚的显示
import pandas as pd
dates=pd.date_range('2019-01-01', periods=100)
data = np.random.randn(100).cumsum()
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.gcf().autofmt_xdate()
ax.plot(dates, data)
# Out:
# /Users/shenzhongqiang/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Pandas绘图
# + Pandas的绘图方法封装了Matplotlib的pyplot方法
# + 提供简单的绘图功能

# %%
# 折线图
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
  columns=['A', 'B', 'C', 'D'],
  index=np.arange(0, 100, 10))
df.plot()

# %%
# 散点图
a = np.arange(20)
b = a * 2 + 1 + np.random.randn(20)
c = a * 5 + 2 + np.random.randn(20)
df = pd.DataFrame({'A': a, 'B': b, 'C': c})
df.plot(x='A', y='B', kind='scatter')

# %%
# 矩阵散点图
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a233890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a2b9c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a2ee910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a32cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a364950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a3a2c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a3d8990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a4181d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a418cd0>]],
#       dtype=object)

# %%
# 直方图
df = pd.DataFrame({'A':np.random.randn(1000)})
df['A'].plot(kind='hist')

# %%
# 密度图
df = pd.DataFrame({'A':np.arange(1000)})
df['A'].plot(kind='density')
#df['A'].plot.density()

# %%
df = pd.DataFrame(np.random.rand(6, 4),
  index=['2014', '2015', '2016', '2017', '2018', '2019'],
  columns=pd.Index(['iphone', 'huawei', 'samsung', 'xiaomi'], name='Brand'))

df.plot(kind='bar')
#df.plot.bar()
#df.plot(stacked=True, alpha=0.5, kind='barh')
#df.plot.barh(stacked=True, alpha=0.5)

# %%
# 饼图
df = pd.DataFrame({'sales': [200, 300, 500]},
  index=['iphone', 'huawei', 'xiaomi'],
  columns=['sales'])

df.plot(y='sales', kind='pie', startangle=90)
#df.plot.pie(y='sales', startangle=90)

# %% [markdown]
# # 实战项目 - 见PPT

# %%
# 调整图像显示大小
import pylab
pylab.rcParams['figure.figsize'] = (15.0, 8.0)

# %%
import pandas as pd
df = pd.read_csv("houses.csv", sep='>', index_col=0)
df = df.drop_duplicates(["title", "price",
                    "xiaoqu_name", "size",
                    "buildyear", "huxing",
                    "chaoxiang", "zhuangxiu",
                    "cenggao", "district_name",
                    "sub_district_name"])
df.head(2)
# Out:
#                         _id                        title  price  up_price  \
# 0  5dd2198f18bba2b4a9a0b854     大华电梯两房/房型正气/开门南北通/房东诚意出售  690.0   76531.0
# 1  5dd2198f18bba2b4a9a0b855  非底楼 满五年唯一 税费少 婚房装修 楼称佳 户型方正  330.0   52290.0
#
#          xiaoqu_name   size  buildyear huxing chaoxiang zhuangxiu  \
# 0  大华锦绣华城(十六街区)(公寓)   90.16       2010  2室2厅         南        简装
# 1               芳雅苑   63.11       1995  2室1厅         南        精装
#
#        cenggao louxing district_name sub_district_name
# 0   中楼层(共18层)       板楼            浦东                北蔡
# 1    低楼层(共6层)       板楼            浦东                北蔡

# %%
# 每个区的均价
df_avg = df.groupby("district_name")["up_price"].agg(avg_price="mean").sort_index()
df_avg["district_pinyin"] = ["jiading", "fengxian", "baoshan", "xuhui", "putuo", "yangpu", "songjiang", "pudong",
                            "hongkou", "jinshan", "changning", "minhang", "qingpu", "jingan", "huangpu"]
df_avg.sort_values("avg_price", inplace=True)
plt.bar(df_avg["district_pinyin"], df_avg["avg_price"])
# Out:
# <BarContainer object of 15 artists>

# %%
# 房源面积的分布情况
plt.hist(df["size"], bins=100)
# Out:
# (array([2.0400e+02, 9.6450e+03, 1.5949e+04, 1.3511e+04, 1.2623e+04,
#         6.2340e+03, 5.7010e+03, 2.7500e+03, 1.5980e+03, 1.0630e+03,
#         6.7200e+02, 6.1900e+02, 4.5400e+02, 3.8200e+02, 3.7700e+02,
#         2.8600e+02, 2.0200e+02, 2.1100e+02, 1.5800e+02, 1.6200e+02,
#         1.0200e+02, 1.0500e+02, 7.8000e+01, 6.3000e+01, 6.4000e+01,
#         4.1000e+01, 5.0000e+01, 4.4000e+01, 3.1000e+01, 1.5000e+01,
#         2.4000e+01, 1.7000e+01, 1.2000e+01, 1.5000e+01, 9.0000e+00,
#         1.6000e+01, 1.7000e+01, 1.0000e+01, 1.5000e+01, 9.0000e+00,
#         6.0000e+00, 1.1000e+01, 7.0000e+00, 1.3000e+01, 5.0000e+00,
#         1.0000e+00, 3.0000e+00, 4.0000e+00, 3.0000e+00, 3.0000e+00,
#         1.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00, 3.0000e+00,
#         3.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         2.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([   8.24  ,   27.3132,   46.3864,   65.4596,   84.5328,  103.606 ,
#          122.6792,  141.7524,  160.8256,  179.8988,  198.972 ,  218.0452,
#          237.1184,  256.1916,  275.2648,  294.338 ,  313.4112,  332.4844,
#          351.5576,  370.6308,  389.704 ,  408.7772,  427.8504,  446.9236,
#          465.9968,  485.07  ,  504.1432,  523.2164,  542.2896,  561.3628,
#          580.436 ,  599.5092,  618.5824,  637.6556,  656.7288,  675.802 ,
#          694.8752,  713.9484,  733.0216,  752.0948,  771.168 ,  790.2412,
#          809.3144,  828.3876,  847.4608,  866.534 ,  885.6072,  904.6804,
#          923.7536,  942.8268,  961.9   ,  980.9732, 1000.0464, 1019.1196,
#         1038.1928, 1057.266 , 1076.3392, 1095.4124, 1114.4856, 1133.5588,
#         1152.632 , 1171.7052, 1190.7784, 1209.8516, 1228.9248, 1247.998 ,
#         1267.0712, 1286.1444, 1305.2176, 1324.2908, 1343.364 , 1362.4372,
#         1381.5104, 1400.5836, 1419.6568, 1438.73  , 1457.8032, 1476.8764,
#         1495.9496, 1515.0228, 1534.096 , 1553.1692, 1572.2424, 1591.3156,
#         1610.3888, 1629.462 , 1648.5352, 1667.6084, 1686.6816, 1705.7548,
#         1724.828 , 1743.9012, 1762.9744, 1782.0476, 1801.1208, 1820.194 ,
#         1839.2672, 1858.3404, 1877.4136, 1896.4868, 1915.56  ]),
#  <a list of 100 Patch objects>)

# %%
# 房源在各个区的分布情况
df_district = df.groupby("district_name")["price"].agg(house_num="count").sort_index()
df_district["district_pinyin"] = ["jiading", "fengxian", "baoshan", "xuhui", "putuo", "yangpu", "songjiang", "pudong",
                            "hongkou", "jinshan", "changning", "minhang", "qingpu", "jingan", "huangpu"]
df_district.sort_values("house_num", inplace=True)
plt.pie(df_district["house_num"], labels=df_district["district_pinyin"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a1e5beb10>,
#   <matplotlib.patches.Wedge at 0x1a1e5bef50>,
#   <matplotlib.patches.Wedge at 0x1a1e86b550>,
#   <matplotlib.patches.Wedge at 0x1a1e86b5d0>,
#   <matplotlib.patches.Wedge at 0x1a1e875210>,
#   <matplotlib.patches.Wedge at 0x1a1e875910>,
#   <matplotlib.patches.Wedge at 0x1a1e875650>,
#   <matplotlib.patches.Wedge at 0x1a1e87f150>,
#   <matplotlib.patches.Wedge at 0x1a1e86bb10>,
#   <matplotlib.patches.Wedge at 0x1a1e875690>,
#   <matplotlib.patches.Wedge at 0x1a1e5a42d0>,
#   <matplotlib.patches.Wedge at 0x1a1e88e090>,
#   <matplotlib.patches.Wedge at 0x1a1e88e590>,
#   <matplotlib.patches.Wedge at 0x1a1e88ead0>,
#   <matplotlib.patches.Wedge at 0x1a1e89b050>],
#  [Text(1.0991432567612036, 0.04340623361194954, 'jinshan'),
#   Text(1.0876852433409907, 0.16413656331923673, 'qingpu'),
#   Text(1.0478947080393792, 0.33453950568365504, 'fengxian'),
#   Text(0.9720921152625287, 0.5148173651348824, 'huangpu'),
#   Text(0.8582139624731236, 0.6880906877848154, 'hongkou'),
#   Text(0.655877013271813, 0.883077201303287, 'changning'),
#   Text(0.33413705429868956, 1.0480231051577988, 'jiading'),
#   Text(-0.058878843093637875, 1.098423088721261, 'jingan'),
#   Text(-0.46545193873947377, 0.9966717075966717, 'putuo'),
#   Text(-0.8085094707849722, 0.7458635502898666, 'xuhui'),
#   Text(-1.0327509580023821, 0.3787155380297487, 'songjiang'),
#   Text(-1.0982975774811234, -0.06117541417183647, 'yangpu'),
#   Text(-0.9741274235742978, -0.5109557345215932, 'baoshan'),
#   Text(-0.4762266664684498, -0.9915685362819597, 'minhang'),
#   Text(0.7671244495414269, -0.7883654475658881, 'pudong')])

# %%
# 房源的装修情况
df_zhuangxiu = df[df.zhuangxiu!=""].groupby("zhuangxiu")["price"].agg(house_num="count").sort_values(by="house_num")
df_zhuangxiu["zhuangxiu_pinyin"] = ["maopie", "qita", "jianzhuang", "jingzhuang"]
df_zhuangxiu.sort_values("house_num", inplace=True)
plt.pie(df_zhuangxiu["house_num"], labels=df_zhuangxiu["zhuangxiu_pinyin"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a1f5932d0>,
#   <matplotlib.patches.Wedge at 0x1a1f593710>,
#   <matplotlib.patches.Wedge at 0x1a1f5936d0>,
#   <matplotlib.patches.Wedge at 0x1a1f59b210>],
#  [Text(1.0640590479683003, 0.27888768785443846, 'maopie'),
#   Text(0.7866204674014206, 0.7689136754312352, 'qita'),
#   Text(-0.5754543093225145, 0.9374712464295362, 'jianzhuang'),
#   Text(0.03612631511213478, -1.0994066078373457, 'jingzhuang')])

# %%
# 房价和面积的关系
plt.scatter(df["size"], df["price"], alpha=0.3)

# %%
# 选取一个小区的房源，查看房价和面积的关系
df_xiaoqu = df.groupby("xiaoqu_name")["price"].agg(house_num="count").sort_values(by="house_num")
df_xiaoqu.tail(1)
# Out:
#              house_num
# xiaoqu_name
# 上海康城               220

# %%
df2 = df[df.xiaoqu_name=="上海康城 "]
plt.scatter(df2["size"], df2["price"], alpha=0.3)
