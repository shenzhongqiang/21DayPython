# %% [markdown]
# # pyecharts介绍
# + 基于百度开源的一个数据可视化JS库echarts
# + 支持非常多的图表类型
# + 可视化效果非常棒
# + 可交互的动态效果
# + 用Python生成Echarts图表的类库

# %% [markdown]
# # 安装echarts
# 打开Anaconda命令行，运行
# ```bash
# conda install pyecharts==1.5.1
# ```

# %% [markdown]
# # 验证版本

# %%
import pyecharts
print(pyecharts.__version__)
# Out:
# 1.5.1

# %% [markdown]
# # 绘图

# %%
# 折线图
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line

line = Line()
line.add_xaxis(Faker.choose())
line.add_yaxis("商家A", Faker.values())
line.add_yaxis("商家B", Faker.values())
line.set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8bfb885ae15c452a9df5cd40f954b826" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8bfb885ae15c452a9df5cd40f954b826 = echarts.init(
#                     document.getElementById('8bfb885ae15c452a9df5cd40f954b826'), 'white', {renderer: 'canvas'});
#                 var option_8bfb885ae15c452a9df5cd40f954b826 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     49
#                 ],
#                 [
#                     "\u8292\u679c",
#                     66
#                 ],
#                 [
#                     "\u8461\u8404",
#                     103
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     97
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     34
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     108
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     51
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     120
#                 ],
#                 [
#                     "\u8292\u679c",
#                     149
#                 ],
#                 [
#                     "\u8461\u8404",
#                     86
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     110
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     31
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     109
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     97
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_8bfb885ae15c452a9df5cd40f954b826.setOption(option_8bfb885ae15c452a9df5cd40f954b826);
#         });
#     </script>

# %%
# 柱状图
from pyecharts.faker import Faker
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
G = Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34670f3dd38a4f68a332eb9f84f7acf4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34670f3dd38a4f68a332eb9f84f7acf4 = echarts.init(
#                     document.getElementById('34670f3dd38a4f68a332eb9f84f7acf4'), 'white', {renderer: 'canvas'});
#                 var option_34670f3dd38a4f68a332eb9f84f7acf4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 116,
#                 130,
#                 95,
#                 66,
#                 32,
#                 130,
#                 48
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 82,
#                 70,
#                 89,
#                 127,
#                 40,
#                 129,
#                 145
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5"
#         }
#     ]
# };
#                 chart_34670f3dd38a4f68a332eb9f84f7acf4.setOption(option_34670f3dd38a4f68a332eb9f84f7acf4);
#         });
#     </script>

# %%
# 柱状图（横向）
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9403d17b051845b68b6615c8eb748e8f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9403d17b051845b68b6615c8eb748e8f = echarts.init(
#                     document.getElementById('9403d17b051845b68b6615c8eb748e8f'), 'white', {renderer: 'canvas'});
#                 var option_9403d17b051845b68b6615c8eb748e8f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 116,
#                 130,
#                 95,
#                 66,
#                 32,
#                 130,
#                 48
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 82,
#                 70,
#                 89,
#                 127,
#                 40,
#                 129,
#                 145
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5"
#         }
#     ]
# };
#                 chart_9403d17b051845b68b6615c8eb748e8f.setOption(option_9403d17b051845b68b6615c8eb748e8f);
#         });
#     </script>

# %%
# 象形柱状图
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType


location = ["山西", "四川", "西藏", "北京", "上海", "内蒙古", "云南", "黑龙江", "广东", "福建"]
values = [13, 42, 67, 81, 86, 94, 166, 220, 249, 262]

c = PictorialBar()
c.add_xaxis(location)
c.add_yaxis(
    "",
    values,
    label_opts=opts.LabelOpts(is_show=False),
    symbol_size=18,
    symbol_repeat="fixed",
    symbol_offset=[0, 0],
    is_symbol_clip=True,
    symbol=SymbolType.ROUND_RECT,
)
c.reversal_axis()
c.set_global_opts(
    title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量"),
    xaxis_opts=opts.AxisOpts(is_show=False),
    yaxis_opts=opts.AxisOpts(
        axistick_opts=opts.AxisTickOpts(is_show=False),
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(opacity=0)
        ),
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="91d77e3c699b4158a5ab1d57f0d6739e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_91d77e3c699b4158a5ab1d57f0d6739e = echarts.init(
#                     document.getElementById('91d77e3c699b4158a5ab1d57f0d6739e'), 'white', {renderer: 'canvas'});
#                 var option_91d77e3c699b4158a5ab1d57f0d6739e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 13,
#                 42,
#                 67,
#                 81,
#                 86,
#                 94,
#                 166,
#                 220,
#                 249,
#                 262
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u897f",
#                 "\u56db\u5ddd",
#                 "\u897f\u85cf",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u798f\u5efa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf\uff08\u865a\u5047\u6570\u636e\uff09"
#         }
#     ]
# };
#                 chart_91d77e3c699b4158a5ab1d57f0d6739e.setOption(option_91d77e3c699b4158a5ab1d57f0d6739e);
#         });
#     </script>

# %%
# 散点图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Scatter


scatter = Scatter()
scatter.add_xaxis(Faker.choose())
scatter.add_yaxis("商家A", Faker.values())
scatter.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3efb58db20ca4e15a7222c580d512715" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3efb58db20ca4e15a7222c580d512715 = echarts.init(
#                     document.getElementById('3efb58db20ca4e15a7222c580d512715'), 'white', {renderer: 'canvas'});
#                 var option_3efb58db20ca4e15a7222c580d512715 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     125
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     82
#                 ],
#                 [
#                     "\u8001\u864e",
#                     72
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     67
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     64
#                 ],
#                 [
#                     "\u718a\u732b",
#                     80
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     143
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_3efb58db20ca4e15a7222c580d512715.setOption(option_3efb58db20ca4e15a7222c580d512715);
#         });
#     </script>

# %%
# 饼图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
pie = Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f490c12efffd4372a7e97c4bc7937f53" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f490c12efffd4372a7e97c4bc7937f53 = echarts.init(
#                     document.getElementById('f490c12efffd4372a7e97c4bc7937f53'), 'white', {renderer: 'canvas'});
#                 var option_f490c12efffd4372a7e97c4bc7937f53 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_f490c12efffd4372a7e97c4bc7937f53.setOption(option_f490c12efffd4372a7e97c4bc7937f53);
#         });
#     </script>

# %%
# 箱线图
from pyecharts import options as opts
from pyecharts.charts import Boxplot


v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
    + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900]
    + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
    + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    + [870, 810, 740, 810, 940, 950, 800, 810, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"]).add_yaxis("A", c.prepare_data(v1)).add_yaxis(
    "B", c.prepare_data(v2)
)
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9d26a04a7e484a1d8addc821cb256fab" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9d26a04a7e484a1d8addc821cb256fab = echarts.init(
#                     document.getElementById('9d26a04a7e484a1d8addc821cb256fab'), 'white', {renderer: 'canvas'});
#                 var option_9d26a04a7e484a1d8addc821cb256fab = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_9d26a04a7e484a1d8addc821cb256fab.setOption(option_9d26a04a7e484a1d8addc821cb256fab);
#         });
#     </script>

# %%
# 热力图
import random

from pyecharts.faker import  Faker
from pyecharts import options as opts
from pyecharts.charts import HeatMap


value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
heatmap = HeatMap()
heatmap.add_xaxis(Faker.clock)
heatmap.add_yaxis("series0", Faker.week, value)
heatmap.set_global_opts(
    title_opts=opts.TitleOpts(title="HeatMap-基本示例"),
    visualmap_opts=opts.VisualMapOpts(),
)
heatmap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="93e542a1ef644749b2f709a2c063a42b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_93e542a1ef644749b2f709a2c063a42b = echarts.init(
#                     document.getElementById('93e542a1ef644749b2f709a2c063a42b'), 'white', {renderer: 'canvas'});
#                 var option_93e542a1ef644749b2f709a2c063a42b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     6
#                 ],
#                 [
#                     0,
#                     1,
#                     42
#                 ],
#                 [
#                     0,
#                     2,
#                     33
#                 ],
#                 [
#                     0,
#                     3,
#                     26
#                 ],
#                 [
#                     0,
#                     4,
#                     32
#                 ],
#                 [
#                     0,
#                     5,
#                     1
#                 ],
#                 [
#                     0,
#                     6,
#                     42
#                 ],
#                 [
#                     1,
#                     0,
#                     32
#                 ],
#                 [
#                     1,
#                     1,
#                     25
#                 ],
#                 [
#                     1,
#                     2,
#                     46
#                 ],
#                 [
#                     1,
#                     3,
#                     0
#                 ],
#                 [
#                     1,
#                     4,
#                     25
#                 ],
#                 [
#                     1,
#                     5,
#                     6
#                 ],
#                 [
#                     1,
#                     6,
#                     32
#                 ],
#                 [
#                     2,
#                     0,
#                     47
#                 ],
#                 [
#                     2,
#                     1,
#                     1
#                 ],
#                 [
#                     2,
#                     2,
#                     44
#                 ],
#                 [
#                     2,
#                     3,
#                     43
#                 ],
#                 [
#                     2,
#                     4,
#                     18
#                 ],
#                 [
#                     2,
#                     5,
#                     3
#                 ],
#                 [
#                     2,
#                     6,
#                     1
#                 ],
#                 [
#                     3,
#                     0,
#                     5
#                 ],
#                 [
#                     3,
#                     1,
#                     8
#                 ],
#                 [
#                     3,
#                     2,
#                     42
#                 ],
#                 [
#                     3,
#                     3,
#                     31
#                 ],
#                 [
#                     3,
#                     4,
#                     1
#                 ],
#                 [
#                     3,
#                     5,
#                     36
#                 ],
#                 [
#                     3,
#                     6,
#                     2
#                 ],
#                 [
#                     4,
#                     0,
#                     9
#                 ],
#                 [
#                     4,
#                     1,
#                     5
#                 ],
#                 [
#                     4,
#                     2,
#                     34
#                 ],
#                 [
#                     4,
#                     3,
#                     0
#                 ],
#                 [
#                     4,
#                     4,
#                     46
#                 ],
#                 [
#                     4,
#                     5,
#                     7
#                 ],
#                 [
#                     4,
#                     6,
#                     3
#                 ],
#                 [
#                     5,
#                     0,
#                     12
#                 ],
#                 [
#                     5,
#                     1,
#                     35
#                 ],
#                 [
#                     5,
#                     2,
#                     20
#                 ],
#                 [
#                     5,
#                     3,
#                     18
#                 ],
#                 [
#                     5,
#                     4,
#                     8
#                 ],
#                 [
#                     5,
#                     5,
#                     14
#                 ],
#                 [
#                     5,
#                     6,
#                     26
#                 ],
#                 [
#                     6,
#                     0,
#                     28
#                 ],
#                 [
#                     6,
#                     1,
#                     43
#                 ],
#                 [
#                     6,
#                     2,
#                     13
#                 ],
#                 [
#                     6,
#                     3,
#                     47
#                 ],
#                 [
#                     6,
#                     4,
#                     41
#                 ],
#                 [
#                     6,
#                     5,
#                     26
#                 ],
#                 [
#                     6,
#                     6,
#                     43
#                 ],
#                 [
#                     7,
#                     0,
#                     4
#                 ],
#                 [
#                     7,
#                     1,
#                     32
#                 ],
#                 [
#                     7,
#                     2,
#                     50
#                 ],
#                 [
#                     7,
#                     3,
#                     10
#                 ],
#                 [
#                     7,
#                     4,
#                     48
#                 ],
#                 [
#                     7,
#                     5,
#                     5
#                 ],
#                 [
#                     7,
#                     6,
#                     9
#                 ],
#                 [
#                     8,
#                     0,
#                     23
#                 ],
#                 [
#                     8,
#                     1,
#                     24
#                 ],
#                 [
#                     8,
#                     2,
#                     45
#                 ],
#                 [
#                     8,
#                     3,
#                     45
#                 ],
#                 [
#                     8,
#                     4,
#                     40
#                 ],
#                 [
#                     8,
#                     5,
#                     25
#                 ],
#                 [
#                     8,

# %%
# 漏斗图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page

f = Funnel()
f.add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
f.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
f.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6964263ae95948bead4c722d599a08e0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6964263ae95948bead4c722d599a08e0 = echarts.init(
#                     document.getElementById('6964263ae95948bead4c722d599a08e0'), 'white', {renderer: 'canvas'});
#                 var option_6964263ae95948bead4c722d599a08e0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 84
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 102
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9886\u5e26",
#                 "\u98ce\u8863",
#                 "\u6bdb\u8863",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50",
#                 "\u886c\u886b"
#             ],
#             "selected": {
#                 "\u886c\u886b": true,
#                 "\u6bdb\u8863": true,
#                 "\u9886\u5e26": true,
#                 "\u88e4\u5b50": true,
#                 "\u98ce\u8863": true,
#                 "\u9ad8\u8ddf\u978b": true,
#                 "\u889c\u5b50": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_6964263ae95948bead4c722d599a08e0.setOption(option_6964263ae95948bead4c722d599a08e0);
#         });
#     </script>

# %%
# 词云图
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
words = [
    ("Sam S Club", 10000), ("Macys", 6181), ("Amy Schumer", 4386),
    ("Jurassic World", 4055), ("Charter Communications", 2467),
    ("Chick Fil A", 2244), ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484), ("Express", 1112),
    ("Home", 865), ("Johnny Depp", 847),
    ("Lena Dunham", 582), ("Lewis Hamilton", 555),
    ("KXAN", 550), ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366), ("Rita Ora", 360),
    ("Serena Williams", 282), ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="1dd69af079a343e8931beb6aeb55ccb2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_1dd69af079a343e8931beb6aeb55ccb2 = echarts.init(
#                     document.getElementById('1dd69af079a343e8931beb6aeb55ccb2'), 'white', {renderer: 'canvas'});
#                 var option_1dd69af079a343e8931beb6aeb55ccb2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,40,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,72,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,128,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,3,79)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(73,23,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,95,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,142,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,113,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(13,2,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,157,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,127,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,35,32)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,48,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,100,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,58,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,96,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,109,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,91,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,9,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,116,142)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "WordCloud-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# }

# %%
# 仪表盘
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page


g = Gauge()
g.add("", [("完成率", 66.6)])
g.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9a381a3ecbeb493d900168d5282bddf9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9a381a3ecbeb493d900168d5282bddf9 = echarts.init(
#                     document.getElementById('9a381a3ecbeb493d900168d5282bddf9'), 'white', {renderer: 'canvas'});
#                 var option_9a381a3ecbeb493d900168d5282bddf9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_9a381a3ecbeb493d900168d5282bddf9.setOption(option_9a381a3ecbeb493d900168d5282bddf9);
#         });
#     </script>

# %%
# 水球图
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [0.6, 0.7])
l.set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="275c1ea3a2ef40c884bcd32b15f414c1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_275c1ea3a2ef40c884bcd32b15f414c1 = echarts.init(
#                     document.getElementById('275c1ea3a2ef40c884bcd32b15f414c1'), 'white', {renderer: 'canvas'});
#                 var option_275c1ea3a2ef40c884bcd32b15f414c1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_275c1ea3a2ef40c884bcd32b15f414c1.setOption(option_275c1ea3a2ef40c884bcd32b15f414c1);
#         });
#     </script>

# %%
# 日历图
import datetime
import random
from pyecharts import options as opts
from pyecharts.charts import Calendar

begin = datetime.date(2019, 1, 1)
end = datetime.date(2019, 12, 31)
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]
c = Calendar()
c.add("", data, calendar_opts=opts.CalendarOpts(range_="2019"))
c.set_global_opts(
    title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
    visualmap_opts=opts.VisualMapOpts(
        max_=20000,
        min_=500,
        orient="horizontal",
        is_piecewise=True,
        pos_top="230px",
        pos_left="100px",
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5cdb7af09d84432ab960771070169d73" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5cdb7af09d84432ab960771070169d73 = echarts.init(
#                     document.getElementById('5cdb7af09d84432ab960771070169d73'), 'white', {renderer: 'canvas'});
#                 var option_5cdb7af09d84432ab960771070169d73 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2019-01-01",
#                     3689
#                 ],
#                 [
#                     "2019-01-02",
#                     16592
#                 ],
#                 [
#                     "2019-01-03",
#                     24295
#                 ],
#                 [
#                     "2019-01-04",
#                     6729
#                 ],
#                 [
#                     "2019-01-05",
#                     14929
#                 ],
#                 [
#                     "2019-01-06",
#                     18184
#                 ],
#                 [
#                     "2019-01-07",
#                     6345
#                 ],
#                 [
#                     "2019-01-08",
#                     23062
#                 ],
#                 [
#                     "2019-01-09",
#                     4278
#                 ],
#                 [
#                     "2019-01-10",
#                     18717
#                 ],
#                 [
#                     "2019-01-11",
#                     2860
#                 ],
#                 [
#                     "2019-01-12",
#                     1276
#                 ],
#                 [
#                     "2019-01-13",
#                     10644
#                 ],
#                 [
#                     "2019-01-14",
#                     19063
#                 ],
#                 [
#                     "2019-01-15",
#                     24379
#                 ],
#                 [
#                     "2019-01-16",
#                     18731
#                 ],
#                 [
#                     "2019-01-17",
#                     5447
#                 ],
#                 [
#                     "2019-01-18",
#                     17698
#                 ],
#                 [
#                     "2019-01-19",
#                     5141
#                 ],
#                 [
#                     "2019-01-20",
#                     7381
#                 ],
#                 [
#                     "2019-01-21",
#                     22141
#                 ],
#                 [
#                     "2019-01-22",
#                     2939
#                 ],
#                 [
#                     "2019-01-23",
#                     2317
#                 ],
#                 [
#                     "2019-01-24",
#                     3984
#                 ],
#                 [
#                     "2019-01-25",
#                     8536
#                 ],
#                 [
#                     "2019-01-26",
#                     2893
#                 ],
#                 [
#                     "2019-01-27",
#                     8442
#                 ],
#                 [
#                     "2019-01-28",
#                     14813
#                 ],
#                 [
#                     "2019-01-29",
#                     16296
#                 ],
#                 [
#                     "2019-01-30",
#                     21992
#                 ],
#                 [
#                     "2019-01-31",
#                     11459
#                 ],
#                 [
#                     "2019-02-01",
#                     20926
#                 ],
#                 [
#                     "2019-02-02",
#                     8535
#                 ],
#                 [
#                     "2019-02-03",
#                     21520
#                 ],
#                 [
#                     "2019-02-04",
#                     20729
#                 ],
#                 [
#                     "2019-02-05",
#                     24438
#                 ],
#                 [
#                     "2019-02-06",
#                     11109
#                 ],
#                 [
#                     "2019-02-07",
#                     6771
#                 ],
#                 [
#                     "2019-02-08",
#                     3499
#                 ],
#                 [
#                     "2019-02-09",
#                     7679
#                 ],
#                 [
#                     "2019-02-10",
#                     23999
#                 ],
#                 [
#                     "2019-02-11",
#                     13900
#                 ],
#                 [
#                     "2019-02-12",
#                     10151
#                 ],
#                 [
#                     "2019-02-13",
#                     9533
#                 ],
#                 [
#                     "2019-02-14",
#                     19533
#                 ],
#                 [
#                     "2019-02-15",
#                     17114
#                 ],
#                 [
#                     "2019-02-16",
#                     7993
#                 ],
#                 [
#                     "2019-02-17",
#                     15414
#                 ],
#                 [
#                     "2019-02-18",
#                     6538
#                 ],
#                 [
#                     "2019-02-19",
#                     11318
#                 ],
#                 [
#                     "2019-02-20",
#                     12113
#                 ],
#                 [
#                     "2019-02-21",
#                     21726
#                 ],
#                 [
#                     "2019-02-22",
#                     8562
#                 ],
#                 [
#                     "2019-02-23",
#                     8951
#                 ],
#                 [
#                     "2019-02-24",
#                     2706
#                 ],
#                 [
#                     "2019-02-25",
#                     11933
#                 ],
#                 [
#                     "2019-02-26",
#                     16452
#                 ],
#                 [
#                     "2019-02-27",
#                     20757
#                 ],
#                 [
#                     "2019-02-28",
#                     23255
#                 ],
#                 [
#                     "2019-03-01",
#                     8800
#                 ],
#                 [
#                     "2019-03-02",
#                     1323
#                 ],
#                 [
#                     "2019-03-03",
#                     8635
#                 ],
#                 [
#                     "2019-03-04",
#                     19178
#                 ],
#                 [
#                     "2019-03-05",
#                     23840
#                 ],
#                 [
#                     "2019-03-06",
#                     24693
#                 ],
#                 [
#                     "2019-03-07",
#                     23330
#                 ],
#                 [
#                     "2019-03-08",
#                     20287
#                 ],
#                 [
#                     "2019-03-09",
#                     15797
#                 ],
#                 [

# %%
# 矩形树图
import json
import os
from pyecharts import options as opts
from pyecharts.charts import Page, TreeMap

data = [
    {"value": 40, "name": "我是A"},
    {
        "value": 180,
        "name": "我是B",
        "children": [{
            "value": 76,
            "name": "我是B.children",
            "children": [
                {"value": 12, "name": "我是B.children.a"},
                {"value": 28, "name": "我是B.children.b"},
                {"value": 20, "name": "我是B.children.c"},
                {"value": 16, "name": "我是B.children.d"},
            ],
        }],
    }]

c = TreeMap()
c.add("演示数据", data)
c.set_global_opts(title_opts=opts.TitleOpts(title="TreeMap-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7f893067618a4514a67140f5e9f9bb99" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7f893067618a4514a67140f5e9f9bb99 = echarts.init(
#                     document.getElementById('7f893067618a4514a67140f5e9f9bb99'), 'white', {renderer: 'canvas'});
#                 var option_7f893067618a4514a67140f5e9f9bb99 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6f14\u793a\u6570\u636e",
#             "data": [
#                 {
#                     "value": 40,
#                     "name": "\u6211\u662fA"
#                 },
#                 {
#                     "value": 180,
#                     "name": "\u6211\u662fB",
#                     "children": [
#                         {
#                             "value": 76,
#                             "name": "\u6211\u662fB.children",
#                             "children": [
#                                 {
#                                     "value": 12,
#                                     "name": "\u6211\u662fB.children.a"
#                                 },
#                                 {
#                                     "value": 28,
#                                     "name": "\u6211\u662fB.children.b"
#                                 },
#                                 {
#                                     "value": 20,
#                                     "name": "\u6211\u662fB.children.c"
#                                 },
#                                 {
#                                     "value": 16,
#                                     "name": "\u6211\u662fB.children.d"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "drillDownIcon": "\u25b6"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6f14\u793a\u6570\u636e"
#             ],
#             "selected": {
#                 "\u6f14\u793a\u6570\u636e": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "TreeMap-\u57fa\u672c\u793a\u4f8b"
#         }
#     ]
# };
#                 chart_7f893067618a4514a67140f5e9f9bb99.setOption(option_7f893067618a4514a67140f5e9f9bb99);
#         });
#     </script>

# %%
# 地图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()
m.add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b8b3f96fd88448f8804ed7416878511d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b8b3f96fd88448f8804ed7416878511d = echarts.init(
#                     document.getElementById('b8b3f96fd88448f8804ed7416878511d'), 'white', {renderer: 'canvas'});
#                 var option_b8b3f96fd88448f8804ed7416878511d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 119
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 94
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#                 chart_b8b3f96fd88448f8804ed7416878511d.setOption(option_b8b3f96fd88448f8804ed7416878511d);
#         });
#     </script>

# %% [markdown]
# # 定制主题

# %%
# 默认主题
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType

# 等价于 Bar(init_opts=opts.InitOpts(theme=ThemeType.WHITE))
c = Bar()
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("Theme-default"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="19aceffc34224aaebf9ed1430744b766" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_19aceffc34224aaebf9ed1430744b766 = echarts.init(
#                     document.getElementById('19aceffc34224aaebf9ed1430744b766'), 'white', {renderer: 'canvas'});
#                 var option_19aceffc34224aaebf9ed1430744b766 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 57,
#                 68,
#                 34,
#                 46,
#                 109,
#                 72,
#                 120
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 75,
#                 111,
#                 149,
#                 133,
#                 101,
#                 139,
#                 51
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 89,
#                 129,
#                 137,
#                 119,
#                 79,
#                 21,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 75,
#                 45,
#                 107,
#                 117,
#                 37,
#                 43,
#                 50
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Theme-default"
#         }
#     ]
# };
#                 chart_19aceffc34224aaebf9ed1430744b766.setOption(option_19aceffc34224aaebf9ed1430744b766);
#         });
#     </script>

# %%
# LIGHT主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("LIGHT主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6b99f8451e784ee79fe505bc0f667bf0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6b99f8451e784ee79fe505bc0f667bf0 = echarts.init(
#                     document.getElementById('6b99f8451e784ee79fe505bc0f667bf0'), 'light', {renderer: 'canvas'});
#                 var option_6b99f8451e784ee79fe505bc0f667bf0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 125,
#                 90,
#                 145,
#                 73,
#                 27,
#                 118,
#                 128
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 85,
#                 52,
#                 142,
#                 149,
#                 90,
#                 145,
#                 135
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 124,
#                 115,
#                 48,
#                 83,
#                 72,
#                 87,
#                 102
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 39,
#                 45,
#                 127,
#                 111,
#                 119,
#                 136,
#                 56
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "LIGHT\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_6b99f8451e784ee79fe505bc0f667bf0.setOption(option_6b99f8451e784ee79fe505bc0f667bf0);
#         });
#     </script>

# %%
# DARK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("DARK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="75417750c4534e66a2a97b48e99fb24c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_75417750c4534e66a2a97b48e99fb24c = echarts.init(
#                     document.getElementById('75417750c4534e66a2a97b48e99fb24c'), 'dark', {renderer: 'canvas'});
#                 var option_75417750c4534e66a2a97b48e99fb24c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 60,
#                 93,
#                 98,
#                 132,
#                 73,
#                 27,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 54,
#                 142,
#                 28,
#                 88,
#                 28,
#                 67,
#                 47
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 24,
#                 120,
#                 104,
#                 53,
#                 63,
#                 67,
#                 99
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 135,
#                 107,
#                 38,
#                 51,
#                 106,
#                 142,
#                 42
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "DARK\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_75417750c4534e66a2a97b48e99fb24c.setOption(option_75417750c4534e66a2a97b48e99fb24c);
#         });
#     </script>

# %%
# CHALK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("CHALK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="1763fd63ecc44c349cb356a18e61964e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_1763fd63ecc44c349cb356a18e61964e = echarts.init(
#                     document.getElementById('1763fd63ecc44c349cb356a18e61964e'), 'chalk', {renderer: 'canvas'});
#                 var option_1763fd63ecc44c349cb356a18e61964e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 119,
#                 38,
#                 80,
#                 63,
#                 118,
#                 37,
#                 146
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 113,
#                 135,
#                 107,
#                 26,
#                 108,
#                 50,
#                 24
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 132,
#                 39,
#                 132,
#                 109,
#                 41,
#                 144,
#                 39
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 35,
#                 128,
#                 139,
#                 80,
#                 30,
#                 146,
#                 83
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "CHALK\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_1763fd63ecc44c349cb356a18e61964e.setOption(option_1763fd63ecc44c349cb356a18e61964e);
#         });
#     </script>

# %%
# ESSOS主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ESSOS主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="4f6027e07e51420e804a973d1790a52a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_4f6027e07e51420e804a973d1790a52a = echarts.init(
#                     document.getElementById('4f6027e07e51420e804a973d1790a52a'), 'essos', {renderer: 'canvas'});
#                 var option_4f6027e07e51420e804a973d1790a52a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 51,
#                 90,
#                 116,
#                 138,
#                 57,
#                 28,
#                 42
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 32,
#                 82,
#                 111,
#                 116,
#                 92,
#                 96,
#                 82
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 38,
#                 26,
#                 100,
#                 100,
#                 29,
#                 148,
#                 20
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 108,
#                 106,
#                 81,
#                 70,
#                 148,
#                 119,
#                 32
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ESSOS\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_4f6027e07e51420e804a973d1790a52a.setOption(option_4f6027e07e51420e804a973d1790a52a);
#         });
#     </script>

# %%
# PURPLE_PASSION主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("PURPLE_PASSION主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="50e830e8af464d88b07eb52d23e5c1bb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_50e830e8af464d88b07eb52d23e5c1bb = echarts.init(
#                     document.getElementById('50e830e8af464d88b07eb52d23e5c1bb'), 'purple-passion', {renderer: 'canvas'});
#                 var option_50e830e8af464d88b07eb52d23e5c1bb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 51,
#                 142,
#                 146,
#                 92,
#                 79,
#                 75,
#                 54
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 112,
#                 120,
#                 72,
#                 24,
#                 33,
#                 83,
#                 54
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 77,
#                 22,
#                 81,
#                 73,
#                 103,
#                 68,
#                 97
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 60,
#                 23,
#                 78,
#                 96,
#                 125,
#                 115,
#                 89
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "PURPLE_PASSION\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_50e830e8af464d88b07eb52d23e5c1bb.setOption(option_50e830e8af464d88b07eb52d23e5c1bb);
#         });
#     </script>

# %%
# ROMA主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ROMA主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="6b358d7055374e28b0ac5d6abb36cf0d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_6b358d7055374e28b0ac5d6abb36cf0d = echarts.init(
#                     document.getElementById('6b358d7055374e28b0ac5d6abb36cf0d'), 'roma', {renderer: 'canvas'});
#                 var option_6b358d7055374e28b0ac5d6abb36cf0d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 44,
#                 56,
#                 109,
#                 38,
#                 73,
#                 108,
#                 146
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 91,
#                 70,
#                 49,
#                 113,
#                 96,
#                 82,
#                 63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 129,
#                 93,
#                 140,
#                 94,
#                 70,
#                 36,
#                 128
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 104,
#                 103,
#                 77,
#                 46,
#                 35,
#                 73,
#                 96
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ROMA\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_6b358d7055374e28b0ac5d6abb36cf0d.setOption(option_6b358d7055374e28b0ac5d6abb36cf0d);
#         });
#     </script>

# %%
# VINTAGE主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("VINTAGE主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="249d7dbca69d402fab0d7bb2a35a2fc9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_249d7dbca69d402fab0d7bb2a35a2fc9 = echarts.init(
#                     document.getElementById('249d7dbca69d402fab0d7bb2a35a2fc9'), 'vintage', {renderer: 'canvas'});
#                 var option_249d7dbca69d402fab0d7bb2a35a2fc9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 121,
#                 136,
#                 78,
#                 147,
#                 140,
#                 28,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 130,
#                 86,
#                 115,
#                 25,
#                 150,
#                 20,
#                 82
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 52,
#                 112,
#                 129,
#                 146,
#                 117,
#                 83,
#                 73
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 113,
#                 137,
#                 95,
#                 99,
#                 101,
#                 49,
#                 66
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "VINTAGE\u4e3b\u9898"
#         }
#     ]
# };
#                 chart_249d7dbca69d402fab0d7bb2a35a2fc9.setOption(option_249d7dbca69d402fab0d7bb2a35a2fc9);
#         });
#     </script>

# %% [markdown]
# # 实战项目一 - 见PPT

# %%
import pandas as pd
df = pd.read_csv("jobs.csv")
df.drop_duplicates(inplace=True)
df
# Out:
#                                                  title                company  \
# 0                                              招聘数据分析师           北京越铖国际科技有限公司
# 1                                                数据分析师      北京新东方教育科技（集团）有限公司
# 2                                            数据分析师(新浪)          新浪网技术(中国)有限公司
# 3                                                数据分析师         北京美科思远环境科技有限公司
# 4    助理、临床样本库采样人员、软件工程师、数据库管理工程师、机械设计与结构工程师、Android...  中国人民解放军总医院（北京市解放军医学院）
# ..                                                 ...                    ...
# 645                                      数据分析工程师(清控紫荆)     清控紫荆(北京)教育科技股份有限公司
# 646                  风险决策分析师-大数据方向009777(京东数字科技控股有限公司)           京东数字科技控股有限公司
# 647                                数据分析工程师（物流规划）(旷视科技)             北京旷视科技有限公司
# 648                       网络人工智能架构师大数据分析架构师(国内知名互联网企业)              国内知名互联网企业
# 649                             气象数据分析工程师(航天新气象科技有限公司)            航天新气象科技有限公司
#
#     company_size      industry type       salary company_type     source  \
# 0         20-99人    人事/行政/高级管理   全职   8000-12000           民营         斗米
# 1            NaN  计算机/互联网/信息技术   全职  12000-20000           民营  OFweek人才网
# 2     2000-5000人         数据分析师   全职  20000-25000     外商独资/办事处         猎聘
# 3         20-99人      环保/环境科学类   全职  12000-20000          股份制      北极星招聘
# 4            NaN            医疗   全职           面议         公立医院    康强医疗人才网
# ..           ...           ...  ...          ...          ...        ...
# 645       50-99人    其他互联网+技术职位   全职      25000以上           民营         猎聘
# 646   2000-5000人   能源/采掘/化工/环保   全职           面议     外商独资/办事处         猎聘
# 647   2000-5000人         数据分析师   全职           面议           民营         猎聘
# 648       50-99人        IT/互联网   全职      25000以上           民营         猎聘
# 649     100-499人         数据分析师   全职           面议           国企         猎聘
#
#     experience education  salary2
# 0           不限        不限  10000.0
# 1           不限        不限  16000.0
# 2         3-5年        本科  22500.0
# 3           不限        硕士  16000.0
# 4           不限        不限      NaN
# ..         ...       ...      ...
# 645       3-5年        本科  25000.0
# 646       3-5年        硕士      NaN
# 647       3-5年        本科      NaN
# 648      5-10年        本科  25000.0
# 649         不限        本科      NaN
#
# [650 rows x 11 columns]

# %%
# 统计各类规模的招聘公司的数量
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
s_size = df.company_size.value_counts()
bar = Bar()
bar.add_xaxis(s_size.index.tolist())
bar.add_yaxis("公司数量", s_size.values.tolist())
bar.set_global_opts(title_opts=opts.TitleOpts(title="各类规模的公司数量"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4663ed49bfd04583b3c97725d50910d3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4663ed49bfd04583b3c97725d50910d3 = echarts.init(
#                     document.getElementById('4663ed49bfd04583b3c97725d50910d3'), 'white', {renderer: 'canvas'});
#                 var option_4663ed49bfd04583b3c97725d50910d3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "data": [
#                 193,
#                 81,
#                 63,
#                 56,
#                 54,
#                 49,
#                 35,
#                 29,
#                 24,
#                 2,
#                 1,
#                 1
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "100-499\u4eba",
#                 "10000\u4eba\u4ee5\u4e0a",
#                 "500-999\u4eba",
#                 "50-99\u4eba",
#                 "2000-5000\u4eba",
#                 "1000-2000\u4eba",
#                 "5000-10000\u4eba",
#                 "20-99\u4eba",
#                 "1-49\u4eba",
#                 "\u5176\u5b83",
#                 "1000-9999\u4eba",
#                 "100"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u7c7b\u89c4\u6a21\u7684\u516c\u53f8\u6570\u91cf"
#         }
#     ]
# };
#                 chart_4663ed49bfd04583b3c97725d50910d3.setOption(option_4663ed49bfd04583b3c97725d50910d3);
#         });
#     </script>

# %%
# 统计职位来源
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_source = df["source"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_source.index.tolist(), s_source.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="职位来源"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="010c1150b1b64ecba9acd14bdc729c00" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_010c1150b1b64ecba9acd14bdc729c00 = echarts.init(
#                     document.getElementById('010c1150b1b64ecba9acd14bdc729c00'), 'white', {renderer: 'canvas'});
#                 var option_010c1150b1b64ecba9acd14bdc729c00 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u730e\u8058",
#                     "value": 580
#                 },
#                 {
#                     "name": "OFweek\u4eba\u624d\u7f51",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u6597\u7c73",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u767e\u59d3\u7f51",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5317\u6781\u661f\u62db\u8058",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u666e\u5de5\u62db\u8058\u7f51",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5de5\u5382\u76f4\u8058\u7f51",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u730e\u8058",
#                 "OFweek\u4eba\u624d\u7f51",
#                 "\u6597\u7c73",
#                 "\u767e\u59d3\u7f51",
#                 "\u5317\u6781\u661f\u62db\u8058",
#                 "\u666e\u5de5\u62db\u8058\u7f51",
#                 "\u5de5\u5382\u76f4\u8058\u7f51",
#                 "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u804c\u4f4d\u6765\u6e90"
#         }
#     ]
# };
#                 chart_010c1150b1b64ecba9acd14bdc729c00.setOption(option_010c1150b1b64ecba9acd14bdc729c00);
#         });
#     </script>

# %%
# 统计工作年限要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_exp = df["experience"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_exp.index.tolist(), s_exp.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="工作年限要求"),
                   legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="94b9a6c55b3542969dddc63e37f6a921" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_94b9a6c55b3542969dddc63e37f6a921 = echarts.init(
#                     document.getElementById('94b9a6c55b3542969dddc63e37f6a921'), 'white', {renderer: 'canvas'});
#                 var option_94b9a6c55b3542969dddc63e37f6a921 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 232
#                 },
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 142
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 75
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 4
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "3-5\u5e74",
#                 "1-3\u5e74",
#                 "\u4e0d\u9650",
#                 "5-10\u5e74",
#                 "10\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5de5\u4f5c\u5e74\u9650\u8981\u6c42"
#         }
#     ]
# };
#                 chart_94b9a6c55b3542969dddc63e37f6a921.setOption(option_94b9a6c55b3542969dddc63e37f6a921);
#         });
#     </script>

# %%
# 统计学历背景要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_edu = df["education"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_edu.index.tolist(), s_edu.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="学历背景要求"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d679fe56a5b246408c3642e30a110eea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d679fe56a5b246408c3642e30a110eea = echarts.init(
#                     document.getElementById('d679fe56a5b246408c3642e30a110eea'), 'white', {renderer: 'canvas'});
#                 var option_d679fe56a5b246408c3642e30a110eea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 489
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u521d\u4e2d",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u535a\u58eb",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672c\u79d1",
#                 "\u4e0d\u9650",
#                 "\u7855\u58eb",
#                 "\u5927\u4e13",
#                 "\u521d\u4e2d",
#                 "\u535a\u58eb"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5b66\u5386\u80cc\u666f\u8981\u6c42"
#         }
#     ]
# };
#                 chart_d679fe56a5b246408c3642e30a110eea.setOption(option_d679fe56a5b246408c3642e30a110eea);
#         });
#     </script>

# %%
# 统计不同工资段的分布
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_salary = df["salary"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_salary.index.tolist(), s_salary.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="不同工资段的分布"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="02962d34f66f478d85524a4313596777" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_02962d34f66f478d85524a4313596777 = echarts.init(
#                     document.getElementById('02962d34f66f478d85524a4313596777'), 'white', {renderer: 'canvas'});
#                 var option_02962d34f66f478d85524a4313596777 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "8000-12000",
#                     "value": 191
#                 },
#                 {
#                     "name": "12000-20000",
#                     "value": 170
#                 },
#                 {
#                     "name": "\u9762\u8bae",
#                     "value": 104
#                 },
#                 {
#                     "name": "20000-25000",
#                     "value": 60
#                 },
#                 {
#                     "name": "25000\u4ee5\u4e0a",
#                     "value": 59
#                 },
#                 {
#                     "name": "5000-8000",
#                     "value": 46
#                 },
#                 {
#                     "name": "5001-8000",
#                     "value": 5
#                 },
#                 {
#                     "name": "3000-5000",
#                     "value": 5
#                 },
#                 {
#                     "name": "6000-8000",
#                     "value": 2
#                 },
#                 {
#                     "name": "2500-4000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2000-3000",
#                     "value": 1
#                 },
#                 {
#                     "name": "3000-6000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2800-3500",
#                     "value": 1
#                 },
#                 {
#                     "name": "5500-12000",
#                     "value": 1
#                 },
#                 {
#                     "name": "5500-15000",
#                     "value": 1
#                 },
#                 {
#                     "name": "3150-5650",
#                     "value": 1
#                 },
#                 {
#                     "name": "9000-12000",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "8000-12000",
#                 "12000-20000",
#                 "\u9762\u8bae",
#                 "20000-25000",
#                 "25000\u4ee5\u4e0a",
#                 "5000-8000",
#                 "5001-8000",
#                 "3000-5000",
#                 "6000-8000",
#                 "2500-4000",
#                 "2000-3000",
#                 "3000-6000",
#                 "2800-3500",
#                 "5500-12000",
#                 "5500-15000",
#                 "3150-5650",
#                 "9000-12000"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0d\u540c\u5de5\u8d44\u6bb5\u7684\u5206\u5e03"
#         }
#     ]
# };
#                 chart_02962d34f66f478d85524a4313596777.setOption(option_02962d34f66f478d85524a4313596777);
#         });
#     </script>

# %%
# 统计哪些公司工资最高
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
import numpy as np

df_avgsalary = df.groupby("company")["salary2"].agg(avgsalary="mean")
df_avgsalary.dropna(how="any", inplace=True)
companies = list(zip(df_avgsalary.index.tolist(), df_avgsalary["avgsalary"].astype(np.uint16).tolist()))
wc = WordCloud()
wc.add("", companies, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="哪些公司工资最高"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="e8bd50d649e940cca8f6ed61ab3f9d14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_e8bd50d649e940cca8f6ed61ab3f9d14 = echarts.init(
#                     document.getElementById('e8bd50d649e940cca8f6ed61ab3f9d14'), 'white', {renderer: 'canvas'});
#                 var option_e8bd50d649e940cca8f6ed61ab3f9d14 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "xx\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(32,102,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e07\u5b66\u79d1\u6280(\u5317\u4eac)\u6709\u9650\u516c\u53f8",
#                     "value": 4000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,47,10)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u51b0\u9274\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,44,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5357\u71d5\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 6500,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,159,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u53f8\u7fbd\u901a\u4fe1\u8bbe\u5907\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,67,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u60a6\u6613\u7f51\u7edc\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,131,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6295\u4e2d\u4fe1\u606f\u54a8\u8be2\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,146,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u65ed\u626c\u822a\u8fd0\u670d\u52a1\u6709\u9650\u516c\u53f814",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,78,61)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6ca3\u77f3\u6570\u636e\u670d\u52a1\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,8,98)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6dc7\u6bd3\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,27,2)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u70db\u9f99\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,35,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79d1\u65ed\u7f51\u7edc\u79d1\u6280\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,84,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79fb\u8bfa\u56fd\u9645\u7269\u6d41\u6709\u9650\u516c\u53f813",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,106,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8054\u851a\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,124,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8c6b\u8f89\u8d27\u7269\u8fd0\u8f93\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(23,12,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u91d1\u606a\u4f01\u4e1a\u7ba1\u7406\u54a8\u8be2\u6709\u9650\u516c\u53f8",
#                     "value": 13000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,14,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u94f8\u5ca9\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,139,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u9877\u6167\u7269\u6d41\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,54,44)"
#                         }
#                     }
#                 },

# %%
# 统计各类型公司的数量
from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType

s_comptype = df["company_type"].value_counts(ascending=True)


companies = s_comptype.index.tolist()
comptypes = s_comptype.values.tolist()

c = PictorialBar()
c.add_xaxis(companies)
c.add_yaxis(
            "",
            comptypes,
            label_opts=opts.LabelOpts(is_show=False),
            symbol_size=18,
            symbol_repeat="fixed",
            symbol_offset=[0, 0],
            is_symbol_clip=True,
            symbol=SymbolType.ROUND_RECT,
        )
c.reversal_axis()
c.set_global_opts(
            title_opts=opts.TitleOpts(title="公司类型"),
            xaxis_opts=opts.AxisOpts(is_show=False),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
            ),
        )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="31f9c138bf98472daf22a95fd78417d1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_31f9c138bf98472daf22a95fd78417d1 = echarts.init(
#                     document.getElementById('31f9c138bf98472daf22a95fd78417d1'), 'white', {renderer: 'canvas'});
#                 var option_31f9c138bf98472daf22a95fd78417d1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 1,
#                 1,
#                 1,
#                 2,
#                 4,
#                 34,
#                 42,
#                 45,
#                 62,
#                 458
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u516c\u7acb\u533b\u9662",
#                 "\u80a1\u4efd\u5236",
#                 "\u5176\u5b83",
#                 "\u4e2a\u4eba\u4f01\u4e1a",
#                 "\u4e8b\u4e1a\u5355\u4f4d",
#                 "\u56fd\u4f01",
#                 "\u4e2d\u5916\u5408\u8d44/\u5408\u4f5c",
#                 "\u5916\u5546\u72ec\u8d44/\u529e\u4e8b\u5904",
#                 "\u4e0a\u5e02\u516c\u53f8",
#                 "\u6c11\u8425"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u516c\u53f8\u7c7b\u578b"
#         }
#     ]
# };
#                 chart_31f9c138bf98472daf22a95fd78417d1.setOption(option_31f9c138bf98472daf22a95fd78417d1);
#         });
#     </script>

# %% [markdown]
# # 实战项目二 - 见PPT

# %%
df = pd.read_csv("stocks.csv")
df.head()
# Out:
#    name industry area      pe  outstanding  totals  totalAssets  liquidAssets  \
# 0   N有方     软件服务   深圳  134.49         0.19    0.92         8.03          6.18
# 1   N泽璟     化学制药   江苏    0.00         0.55    2.40         2.97          1.17
# 2  N玉禾田     环境保护   安徽   18.46         0.35    1.38        24.84         14.23
# 3  热景生物     医疗保健   北京  251.27         0.14    0.62         6.98          5.45
# 4  鲁抗医药     化学制药   山东   73.98         8.52    8.80        70.58         27.59
#
#    fixedAssets  reserved  ...   bvps    pb  timeToMarket  undp  perundp  \
# 0         0.06      2.82  ...   9.81  5.77      20200123  1.23     1.34
# 1         0.56      2.86  ...   8.20  9.10      20200123 -4.09    -1.70
# 2         5.47      0.28  ...  13.60  3.13      20200123  7.88     5.70
# 3         1.25      4.46  ...  10.04  7.09      20190930  1.06     1.71
# 4        22.30     16.25  ...   3.42  3.33      19970226  3.51     0.40
#
#      rev  profit    gpr   npr   holders
# 0   0.00    0.00  22.88  5.66   19486.0
# 1   0.00    0.00   0.00  0.00   36598.0
# 2   0.00    0.00  21.73  9.09   68996.0
# 3   0.00    0.00  72.54  9.60   10316.0
# 4  15.07  -29.42  28.21  3.72  112796.0
#
# [5 rows x 22 columns]

# %%
# 计算市盈率中位数
df.pe.median()
# Out:
# 28.58

# %%
# 盈利能力排名
df_company = df[df.pe>0][["name", "pe", "pb"]].sort_values("pe").head(10)

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_company.name.values.tolist())
bar.add_yaxis("市盈率", df_company.pe.values.tolist())
bar.add_yaxis("市净率", df_company.pb.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="市盈率"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d669026778964c0d8fbdb99ecc511883" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d669026778964c0d8fbdb99ecc511883 = echarts.init(
#                     document.getElementById('d669026778964c0d8fbdb99ecc511883'), 'white', {renderer: 'canvas'});
#                 var option_d669026778964c0d8fbdb99ecc511883 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e02\u76c8\u7387",
#             "data": [
#                 2.74,
#                 2.75,
#                 3.05,
#                 4.11,
#                 4.13,
#                 4.26,
#                 4.3,
#                 4.39,
#                 4.52,
#                 4.63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e02\u51c0\u7387",
#             "data": [
#                 1.08,
#                 1.23,
#                 1.07,
#                 1.04,
#                 0.9,
#                 0.72,
#                 1.14,
#                 0.6,
#                 0.87,
#                 0.57
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e02\u76c8\u7387",
#                 "\u5e02\u51c0\u7387"
#             ],
#             "selected": {
#                 "\u5e02\u76c8\u7387": true,
#                 "\u5e02\u51c0\u7387": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u795e\u706b\u80a1\u4efd",
#                 "\u6d59\u6c5f\u5e7f\u53a6",
#                 "\u65b0\u96c6\u80fd\u6e90",
#                 "\u5e7f\u5b87\u53d1\u5c55",
#                 "\u534e\u83f1\u94a2\u94c1",
#                 "\u65b0\u94a2\u80a1\u4efd",
#                 "\u4e94\u6d32\u4ea4\u901a",
#                 "\u6c11\u751f\u94f6\u884c",
#                 "\u5357\u94a2\u80a1\u4efd",
#                 "ST\u8f85\u4ec1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e02\u76c8\u7387"
#         }
#     ]
# };
#                 chart_d669026778964c0d8fbdb99ecc511883.setOption(option_d669026778964c0d8fbdb99ecc511883);
#         });
#     </script>

# %%
# 各地区公司数量
df_num = df.groupby("area")["name"].agg(company_num="count")

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()

m.add("公司数量", [list(z) for z in zip(df_num.index.values.tolist(), df_num.company_num.values.tolist())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=500, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="144d4806101040f3ae4537fc2cda7972" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_144d4806101040f3ae4537fc2cda7972 = echarts.init(
#                     document.getElementById('144d4806101040f3ae4537fc2cda7972'), 'white', {renderer: 'canvas'});
#                 var option_144d4806101040f3ae4537fc2cda7972 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 305
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 348
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 323
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 429
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 464
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 302
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#                 chart_144d4806101040f3ae4537fc2cda7972.setOption(option_144d4806101040f3ae4537fc2cda7972);
#         });
#     </script>

# %%
# 净利润率和毛利率中位数
npr = df["npr"].median()/100
gpr = df["gpr"].median()/100

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [gpr, npr])
l.set_global_opts(title_opts=opts.TitleOpts(title="利润率"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="f9f7b1b2238b4dbe8703c391e8949eca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_f9f7b1b2238b4dbe8703c391e8949eca = echarts.init(
#                     document.getElementById('f9f7b1b2238b4dbe8703c391e8949eca'), 'white', {renderer: 'canvas'});
#                 var option_f9f7b1b2238b4dbe8703c391e8949eca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.2718,
#                 0.0738
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5229\u6da6\u7387"
#         }
#     ]
# };
#                 chart_f9f7b1b2238b4dbe8703c391e8949eca.setOption(option_f9f7b1b2238b4dbe8703c391e8949eca);
#         });
#     </script>

# %%
df_npr = df.groupby("industry")["npr"].agg(avg_npr="mean").sort_values("avg_npr", ascending=False)
df_top = df_npr.head(10)
df_top["avg_npr"] = df_top["avg_npr"].apply(lambda x: float("{:.2f}".format(x)))
df_top
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           avg_npr
# industry
# 证券         238.11
# 多元金融        65.45
# 路桥          43.23
# 水力发电        41.61
# 保险          39.60
# 影视音像        36.98
# 银行          34.50
# 商品城         30.27
# 机场          26.31
# 园区开发        25.26

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_top.index.tolist())
bar.add_yaxis("净利润率", df_top.avg_npr.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="净利润率排名"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d859d07430264811ad4c10fa103eeb8d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d859d07430264811ad4c10fa103eeb8d = echarts.init(
#                     document.getElementById('d859d07430264811ad4c10fa103eeb8d'), 'white', {renderer: 'canvas'});
#                 var option_d859d07430264811ad4c10fa103eeb8d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u51c0\u5229\u6da6\u7387",
#             "data": [
#                 238.11,
#                 65.45,
#                 43.23,
#                 41.61,
#                 39.6,
#                 36.98,
#                 34.5,
#                 30.27,
#                 26.31,
#                 25.26
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51c0\u5229\u6da6\u7387"
#             ],
#             "selected": {
#                 "\u51c0\u5229\u6da6\u7387": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8bc1\u5238",
#                 "\u591a\u5143\u91d1\u878d",
#                 "\u8def\u6865",
#                 "\u6c34\u529b\u53d1\u7535",
#                 "\u4fdd\u9669",
#                 "\u5f71\u89c6\u97f3\u50cf",
#                 "\u94f6\u884c",
#                 "\u5546\u54c1\u57ce",
#                 "\u673a\u573a",
#                 "\u56ed\u533a\u5f00\u53d1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u51c0\u5229\u6da6\u7387\u6392\u540d"
#         }
#     ]
# };
#                 chart_d859d07430264811ad4c10fa103eeb8d.setOption(option_d859d07430264811ad4c10fa103eeb8d);
#         });
#     </script>

# %%
# 各行业公司数量
df_industry = df.groupby("industry")["name"].agg(company_num="count")

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

words = [list(z) for z in zip(df_industry.index.values.tolist(), df_industry.company_num.values.tolist())]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100], shape="diamond")
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="349b37712bf94af98fd0a3e2ccf1b2ea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_349b37712bf94af98fd0a3e2ccf1b2ea = echarts.init(
#                     document.getElementById('349b37712bf94af98fd0a3e2ccf1b2ea'), 'white', {renderer: 'canvas'});
#                 var option_349b37712bf94af98fd0a3e2ccf1b2ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "IT\u8bbe\u5907",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,69,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u7528\u673a\u68b0",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,135,27)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6210\u836f",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,80,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e73\u5236\u54c1",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,77,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,141,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ed3\u50a8\u7269\u6d41",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,7,144)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u4f9b\u70ed",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(118,100,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u9669",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,134,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5143\u5668\u4ef6",
#                     "value": 183,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,67,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5168\u56fd\u5730\u4ea7",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,120,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u4ea4\u901a",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,57,106)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u8def",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,89,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5546\u4e1a",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,72,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5efa\u6750",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,135,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u4e1a\u7efc\u5408",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,124,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u7528\u673a\u68b0",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,1,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u836f\u5316\u80a5",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,143,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u7248\u4e1a",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,86,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5b66\u5236\u836f",
#                     "value": 104,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,105,75)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u539f\u6599",
#                     "value": 164,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,4,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u673a\u68b0",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,71,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u7e
