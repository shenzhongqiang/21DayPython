# %% [markdown]
# # pyecharts介绍
# + 基于百度开源的一个数据可视化JS库echarts
# + 支持非常多的图表类型
# + 可视化效果非常棒
# + 可交互的动态效果
# + 用Python生成Echarts图表的类库

# %% [markdown]
# # 安装pyecharts
# 打开Anaconda命令行，运行
# ```bash
# pip install pyecharts==1.6.2 -i https://mirrors.aliyun.com/pypi/simple/
# ```

# %% [markdown]
# # 验证版本

# %%
import pyecharts
print(pyecharts.__version__)
# Out:
# 1.6.2

# %% [markdown]
# # 绘图

# %%
# 折线图
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line

line = Line()
line.add_xaxis(Faker.choose())
line.add_yaxis("商家A", Faker.values())
line.add_yaxis("商家B", Faker.values())
line.set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1428e811e4b241f3b6355c87dd1f6e8d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1428e811e4b241f3b6355c87dd1f6e8d = echarts.init(
#                     document.getElementById('1428e811e4b241f3b6355c87dd1f6e8d'), 'white', {renderer: 'canvas'});
#                 var option_1428e811e4b241f3b6355c87dd1f6e8d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     132
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     39
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     93
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     96
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     80
#                 ],
#                 [
#                     "VIVO",
#                     148
#                 ],
#                 [
#                     "OPPO",
#                     90
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     117
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     97
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     139
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     20
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     58
#                 ],
#                 [
#                     "VIVO",
#                     50
#                 ],
#                 [
#                     "OPPO",
#                     113
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1428e811e4b241f3b6355c87dd1f6e8d.setOption(option_1428e811e4b241f3b6355c87dd1f6e8d);
#         });
#     </script>

# %%
# 柱状图
from pyecharts.faker import Faker
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
bar = Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d92577b5bb014fd7a116899660c861a8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d92577b5bb014fd7a116899660c861a8 = echarts.init(
#                     document.getElementById('d92577b5bb014fd7a116899660c861a8'), 'white', {renderer: 'canvas'});
#                 var option_d92577b5bb014fd7a116899660c861a8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 84,
#                 46,
#                 125,
#                 105,
#                 130,
#                 52,
#                 148
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 113,
#                 91,
#                 32,
#                 46,
#                 127,
#                 24,
#                 88
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d92577b5bb014fd7a116899660c861a8.setOption(option_d92577b5bb014fd7a116899660c861a8);
#         });
#     </script>

# %%
# 柱状图（横向）
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b1b242d8549e42a7a899012db944b63f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b1b242d8549e42a7a899012db944b63f = echarts.init(
#                     document.getElementById('b1b242d8549e42a7a899012db944b63f'), 'white', {renderer: 'canvas'});
#                 var option_b1b242d8549e42a7a899012db944b63f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 84,
#                 46,
#                 125,
#                 105,
#                 130,
#                 52,
#                 148
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 113,
#                 91,
#                 32,
#                 46,
#                 127,
#                 24,
#                 88
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b1b242d8549e42a7a899012db944b63f.setOption(option_b1b242d8549e42a7a899012db944b63f);
#         });
#     </script>

# %%
# 象形柱状图
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType


location = ["山西", "四川", "西藏", "北京", "上海", "内蒙古", "云南", "黑龙江", "广东", "福建"]
values = [13, 42, 67, 81, 86, 94, 166, 220, 249, 262]

c = PictorialBar()
c.add_xaxis(location)
c.add_yaxis(
    "",
    values,
    label_opts=opts.LabelOpts(is_show=False),
    symbol_size=18,
    symbol_repeat="fixed",
    symbol_offset=[0, 0],
    is_symbol_clip=True,
    symbol=SymbolType.ROUND_RECT,
)
c.reversal_axis()
c.set_global_opts(
    title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量"),
    xaxis_opts=opts.AxisOpts(is_show=False),
    yaxis_opts=opts.AxisOpts(
        axistick_opts=opts.AxisTickOpts(is_show=False),
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(opacity=0)
        ),
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="65205a6dc5c54a41b51ac9ac7ab854ab" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_65205a6dc5c54a41b51ac9ac7ab854ab = echarts.init(
#                     document.getElementById('65205a6dc5c54a41b51ac9ac7ab854ab'), 'white', {renderer: 'canvas'});
#                 var option_65205a6dc5c54a41b51ac9ac7ab854ab = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 13,
#                 42,
#                 67,
#                 81,
#                 86,
#                 94,
#                 166,
#                 220,
#                 249,
#                 262
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u897f",
#                 "\u56db\u5ddd",
#                 "\u897f\u85cf",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u798f\u5efa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_65205a6dc5c54a41b51ac9ac7ab854ab.setOption(option_65205a6dc5c54a41b51ac9ac7ab854ab);
#         });
#     </script>

# %%
# 散点图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Scatter


scatter = Scatter()
scatter.add_xaxis(Faker.choose())
scatter.add_yaxis("商家A", Faker.values())
scatter.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b0aae8b4d40b4df0912a1e0d0974dc57" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b0aae8b4d40b4df0912a1e0d0974dc57 = echarts.init(
#                     document.getElementById('b0aae8b4d40b4df0912a1e0d0974dc57'), 'white', {renderer: 'canvas'});
#                 var option_b0aae8b4d40b4df0912a1e0d0974dc57 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     41
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     140
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     41
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     126
#                 ],
#                 [
#                     "\u5976\u8336",
#                     130
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     42
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     42
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b0aae8b4d40b4df0912a1e0d0974dc57.setOption(option_b0aae8b4d40b4df0912a1e0d0974dc57);
#         });
#     </script>

# %%
# 饼图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
pie = Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e53e729e431f40c78dbc2d9200042ca2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e53e729e431f40c78dbc2d9200042ca2 = echarts.init(
#                     document.getElementById('e53e729e431f40c78dbc2d9200042ca2'), 'white', {renderer: 'canvas'});
#                 var option_e53e729e431f40c78dbc2d9200042ca2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 146
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 128
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e53e729e431f40c78dbc2d9200042ca2.setOption(option_e53e729e431f40c78dbc2d9200042ca2);
#         });
#     </script>

# %%
# 箱线图
from pyecharts import options as opts
from pyecharts.charts import Boxplot


v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
    + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900]
    + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
    + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    + [870, 810, 740, 810, 940, 950, 800, 810, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"])
c.add_yaxis("A", c.prepare_data(v1))
c.add_yaxis("B", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="58706ae5ff824a56ab160f8fcb074401" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_58706ae5ff824a56ab160f8fcb074401 = echarts.init(
#                     document.getElementById('58706ae5ff824a56ab160f8fcb074401'), 'white', {renderer: 'canvas'});
#                 var option_58706ae5ff824a56ab160f8fcb074401 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_58706ae5ff824a56ab160f8fcb074401.setOption(option_58706ae5ff824a56ab160f8fcb074401);
#         });
#     </script>

# %%
# 热力图
import random

from pyecharts.faker import  Faker
from pyecharts import options as opts
from pyecharts.charts import HeatMap


value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
print(value)
heatmap = HeatMap()
heatmap.add_xaxis(Faker.clock)
heatmap.add_yaxis("series0", Faker.week, value)
heatmap.set_global_opts(
    title_opts=opts.TitleOpts(title="HeatMap-基本示例"),
    visualmap_opts=opts.VisualMapOpts(),
)
heatmap.render_notebook()
# Out:
# [[0, 0, 4], [0, 1, 7], [0, 2, 15], [0, 3, 25], [0, 4, 18], [0, 5, 10], [0, 6, 2], [1, 0, 29], [1, 1, 24], [1, 2, 42], [1, 3, 13], [1, 4, 14], [1, 5, 27], [1, 6, 2], [2, 0, 36], [2, 1, 26], [2, 2, 41], [2, 3, 38], [2, 4, 8], [2, 5, 17], [2, 6, 22], [3, 0, 5], [3, 1, 43], [3, 2, 42], [3, 3, 38], [3, 4, 49], [3, 5, 7], [3, 6, 38], [4, 0, 39], [4, 1, 18], [4, 2, 23], [4, 3, 36], [4, 4, 29], [4, 5, 5], [4, 6, 10], [5, 0, 29], [5, 1, 42], [5, 2, 4], [5, 3, 21], [5, 4, 23], [5, 5, 37], [5, 6, 37], [6, 0, 41], [6, 1, 47], [6, 2, 26], [6, 3, 24], [6, 4, 7], [6, 5, 46], [6, 6, 46], [7, 0, 11], [7, 1, 21], [7, 2, 8], [7, 3, 6], [7, 4, 2], [7, 5, 25], [7, 6, 48], [8, 0, 18], [8, 1, 28], [8, 2, 28], [8, 3, 24], [8, 4, 40], [8, 5, 21], [8, 6, 1], [9, 0, 47], [9, 1, 8], [9, 2, 26], [9, 3, 18], [9, 4, 38], [9, 5, 27], [9, 6, 6], [10, 0, 2], [10, 1, 50], [10, 2, 35], [10, 3, 46], [10, 4, 1], [10, 5, 27], [10, 6, 12], [11, 0, 42], [11, 1, 24], [11, 2, 8], [11, 3, 50], [11, 4, 36], [11, 5, 28], [11, 6, 40], [12, 0, 12], [12, 1, 20], [12, 2, 1], [12, 3, 24], [12, 4, 29], [12, 5, 9], [12, 6, 41], [13, 0, 5], [13, 1, 28], [13, 2, 32], [13, 3, 47], [13, 4, 12], [13, 5, 15], [13, 6, 45], [14, 0, 26], [14, 1, 7], [14, 2, 28], [14, 3, 4], [14, 4, 15], [14, 5, 31], [14, 6, 46], [15, 0, 8], [15, 1, 21], [15, 2, 14], [15, 3, 48], [15, 4, 4], [15, 5, 46], [15, 6, 26], [16, 0, 36], [16, 1, 18], [16, 2, 28], [16, 3, 12], [16, 4, 30], [16, 5, 39], [16, 6, 31], [17, 0, 30], [17, 1, 44], [17, 2, 43], [17, 3, 47], [17, 4, 43], [17, 5, 14], [17, 6, 11], [18, 0, 37], [18, 1, 14], [18, 2, 30], [18, 3, 36], [18, 4, 16], [18, 5, 34], [18, 6, 43], [19, 0, 15], [19, 1, 31], [19, 2, 35], [19, 3, 37], [19, 4, 24], [19, 5, 37], [19, 6, 6], [20, 0, 6], [20, 1, 13], [20, 2, 29], [20, 3, 30], [20, 4, 3], [20, 5, 34], [20, 6, 5], [21, 0, 30], [21, 1, 45], [21, 2, 16], [21, 3, 36], [21, 4, 31], [21, 5, 29], [21, 6, 2], [22, 0, 18], [22, 1, 24], [22, 2, 9], [22, 3, 33], [22, 4, 5], [22, 5, 1], [22, 6, 41], [23, 0, 4], [23, 1, 34], [23, 2, 8], [23, 3, 0], [23, 4, 13], [23, 5, 15], [23, 6, 22]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fa097d9b06a243c6bf2969b955c8a9bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fa097d9b06a243c6bf2969b955c8a9bd = echarts.init(
#                     document.getElementById('fa097d9b06a243c6bf2969b955c8a9bd'), 'white', {renderer: 'canvas'});
#                 var option_fa097d9b06a243c6bf2969b955c8a9bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     4
#                 ],
#                 [
#                     0,
#                     1,
#                     7
#                 ],
#                 [
#                     0,
#                     2,
#                     15
#                 ],
#                 [
#                     0,
#                     3,
#                     25
#                 ],
#                 [
#                     0,
#                     4,
#                     18
#                 ],
#                 [
#                     0,
#                     5,
#                     10
#                 ],
#                 [
#                     0,
#                     6,
#                     2
#                 ],
#                 [
#                     1,
#                     0,
#                     29
#                 ],
#                 [
#                     1,
#                     1,
#                     24
#                 ],
#                 [
#                     1,
#                     2,
#                     42
#                 ],
#                 [
#                     1,
#                     3,
#                     13
#                 ],
#                 [
#                     1,
#                     4,
#                     14
#                 ],
#                 [
#                     1,
#                     5,
#                     27
#                 ],
#                 [
#                     1,
#                     6,
#                     2
#                 ],
#                 [
#                     2,
#                     0,
#                     36
#                 ],
#                 [
#                     2,
#                     1,
#                     26
#                 ],
#                 [
#                     2,
#                     2,
#                     41
#                 ],
#                 [
#                     2,
#                     3,
#                     38
#                 ],
#                 [
#                     2,
#                     4,
#                     8
#                 ],
#                 [
#                     2,
#                     5,
#                     17
#                 ],
#                 [
#                     2,
#                     6,
#                     22
#                 ],
#                 [
#                     3,
#                     0,
#                     5
#                 ],
#                 [
#                     3,
#                     1,
#                     43
#                 ],
#                 [
#                     3,
#                     2,
#                     42
#                 ],
#                 [
#                     3,
#                     3,
#                     38
#                 ],
#                 [
#                     3,
#                     4,
#                     49
#                 ],
#                 [
#                     3,
#                     5,
#                     7
#                 ],
#                 [
#                     3,
#                     6,
#                     38
#                 ],
#                 [
#                     4,
#                     0,
#                     39
#                 ],
#                 [
#                     4,
#                     1,
#                     18
#                 ],
#                 [
#                     4,
#                     2,
#                     23
#                 ],
#                 [
#                     4,
#                     3,
#                     36
#                 ],
#                 [
#                     4,
#                     4,
#                     29
#                 ],
#                 [
#                     4,
#                     5,
#                     5
#                 ],
#                 [
#                     4,
#                     6,
#                     10
#                 ],
#                 [
#                     5,
#                     0,
#                     29
#                 ],
#                 [
#                     5,
#                     1,
#                     42
#                 ],
#                 [
#                     5,
#                     2,
#                     4
#                 ],
#                 [
#                     5,
#                     3,
#                     21
#                 ],
#                 [
#                     5,
#                     4,
#                     23
#                 ],
#                 [
#                     5,
#                     5,
#                     37
#                 ],
#                 [
#                     5,
#                     6,
#                     37
#                 ],
#                 [
#                     6,
#                     0,
#                     41
#                 ],
#                 [
#                     6,
#                     1,
#                     47
#                 ],
#                 [
#                     6,
#                     2,
#                     26
#                 ],
#                 [
#                     6,
#                     3,
#                     24
#                 ],
#                 [
#                     6,
#                     4,
#                     7
#                 ],
#                 [
#                     6,
#                     5,
#                     46
#                 ],
#                 [
#                     6,
#                     6,
#                     46
#                 ],
#                 [
#                     7,
#                     0,
#                     11
#                 ],
#                 [
#                     7,
#                     1,
#                     21
#                 ],
#                 [
#                     7,
#                     2,
#                     8
#                 ],
#                 [
#                     7,
#                     3,
#                     6
#                 ],
#                 [
#                     7,
#                     4,
#                     2
#                 ],
#                 [
#                     7,
#                     5,
#                     25
#                 ],
#                 [
#                     7,
#                     6,
#                     48
#                 ],
#                 [
#                     8,
#                     0,
#                     18
#                 ],
#                 [
#                     8,
#                     1,
#                     28
#                 ],
#                 [
#                     8,
#                     2,
#                     28
#                 ],
#                 [
#                     8,
#                     3,
#                     24
#                 ],
#                 [
#                     8,
#                     4,
#                     40
#                 ],
#                 [
#                     8,
#                     5,
#                     21
#                 ],
#                 [
#                     8,

# %%
# 漏斗图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page

f = Funnel()
f.add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
f.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
f.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="84556077c7b348799e9f5864c31efafc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_84556077c7b348799e9f5864c31efafc = echarts.init(
#                     document.getElementById('84556077c7b348799e9f5864c31efafc'), 'white', {renderer: 'canvas'});
#                 var option_84556077c7b348799e9f5864c31efafc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 140
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6a59\u6c41",
#                 "\u767e\u5a01",
#                 "\u53ef\u4e50",
#                 "\u9752\u5c9b",
#                 "\u5976\u8336",
#                 "\u7eff\u8336",
#                 "\u96ea\u78a7"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_84556077c7b348799e9f5864c31efafc.setOption(option_84556077c7b348799e9f5864c31efafc);
#         });
#     </script>

# %%
# 词云图
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
words = [
    ("Sam S Club", 10000), ("Macys", 6181), ("Amy Schumer", 4386),
    ("Jurassic World", 4055), ("Charter Communications", 2467),
    ("Chick Fil A", 2244), ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484), ("Express", 1112),
    ("Home", 865), ("Johnny Depp", 847),
    ("Lena Dunham", 582), ("Lewis Hamilton", 555),
    ("KXAN", 550), ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366), ("Rita Ora", 360),
    ("Serena Williams", 282), ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="987b8d83ea6947e38a272ca0ccb70f14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_987b8d83ea6947e38a272ca0ccb70f14 = echarts.init(
#                     document.getElementById('987b8d83ea6947e38a272ca0ccb70f14'), 'white', {renderer: 'canvas'});
#                 var option_987b8d83ea6947e38a272ca0ccb70f14 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,6,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,11,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,10,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,11,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,151,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,52,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,49,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(43,125,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(27,130,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,124,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,83,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,111,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,68,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,105,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,11,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,72,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(77,96,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,98,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,120,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,62,102)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWid

# %%
# 仪表盘
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page


g = Gauge()
g.add("", [("完成率", 66.6)])
g.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="006117cd0a04405b83cad368a88832aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_006117cd0a04405b83cad368a88832aa = echarts.init(
#                     document.getElementById('006117cd0a04405b83cad368a88832aa'), 'white', {renderer: 'canvas'});
#                 var option_006117cd0a04405b83cad368a88832aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_006117cd0a04405b83cad368a88832aa.setOption(option_006117cd0a04405b83cad368a88832aa);
#         });
#     </script>

# %%
# 水球图
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [0.6, 0.7])
l.set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="cc4ef0d843734d2f90419383ea5ada30" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_cc4ef0d843734d2f90419383ea5ada30 = echarts.init(
#                     document.getElementById('cc4ef0d843734d2f90419383ea5ada30'), 'white', {renderer: 'canvas'});
#                 var option_cc4ef0d843734d2f90419383ea5ada30 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_cc4ef0d843734d2f90419383ea5ada30.setOption(option_cc4ef0d843734d2f90419383ea5ada30);
#         });
#     </script>

# %%
# 日历图
import datetime
import random
from pyecharts import options as opts
from pyecharts.charts import Calendar

begin = datetime.date(2019, 1, 1)
end = datetime.date(2019, 12, 31)
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]
c = Calendar()
c.add("", data, calendar_opts=opts.CalendarOpts(range_="2019"))
c.set_global_opts(
    title_opts=opts.TitleOpts(title="Calendar-2019年微信步数情况"),
    visualmap_opts=opts.VisualMapOpts(
        max_=20000,
        min_=500,
        orient="horizontal",
        is_piecewise=True,
        pos_top="230px",
        pos_left="100px",
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5fa7d6c2f67745468169541b4d728264" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5fa7d6c2f67745468169541b4d728264 = echarts.init(
#                     document.getElementById('5fa7d6c2f67745468169541b4d728264'), 'white', {renderer: 'canvas'});
#                 var option_5fa7d6c2f67745468169541b4d728264 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2019-01-01",
#                     23049
#                 ],
#                 [
#                     "2019-01-02",
#                     8814
#                 ],
#                 [
#                     "2019-01-03",
#                     15794
#                 ],
#                 [
#                     "2019-01-04",
#                     10583
#                 ],
#                 [
#                     "2019-01-05",
#                     24745
#                 ],
#                 [
#                     "2019-01-06",
#                     2681
#                 ],
#                 [
#                     "2019-01-07",
#                     19431
#                 ],
#                 [
#                     "2019-01-08",
#                     10274
#                 ],
#                 [
#                     "2019-01-09",
#                     17735
#                 ],
#                 [
#                     "2019-01-10",
#                     12967
#                 ],
#                 [
#                     "2019-01-11",
#                     23160
#                 ],
#                 [
#                     "2019-01-12",
#                     4181
#                 ],
#                 [
#                     "2019-01-13",
#                     10083
#                 ],
#                 [
#                     "2019-01-14",
#                     22494
#                 ],
#                 [
#                     "2019-01-15",
#                     20127
#                 ],
#                 [
#                     "2019-01-16",
#                     4847
#                 ],
#                 [
#                     "2019-01-17",
#                     12144
#                 ],
#                 [
#                     "2019-01-18",
#                     9421
#                 ],
#                 [
#                     "2019-01-19",
#                     9248
#                 ],
#                 [
#                     "2019-01-20",
#                     8686
#                 ],
#                 [
#                     "2019-01-21",
#                     11717
#                 ],
#                 [
#                     "2019-01-22",
#                     5353
#                 ],
#                 [
#                     "2019-01-23",
#                     21610
#                 ],
#                 [
#                     "2019-01-24",
#                     16365
#                 ],
#                 [
#                     "2019-01-25",
#                     1169
#                 ],
#                 [
#                     "2019-01-26",
#                     17085
#                 ],
#                 [
#                     "2019-01-27",
#                     11831
#                 ],
#                 [
#                     "2019-01-28",
#                     14678
#                 ],
#                 [
#                     "2019-01-29",
#                     19384
#                 ],
#                 [
#                     "2019-01-30",
#                     22082
#                 ],
#                 [
#                     "2019-01-31",
#                     6637
#                 ],
#                 [
#                     "2019-02-01",
#                     22005
#                 ],
#                 [
#                     "2019-02-02",
#                     19751
#                 ],
#                 [
#                     "2019-02-03",
#                     22609
#                 ],
#                 [
#                     "2019-02-04",
#                     6372
#                 ],
#                 [
#                     "2019-02-05",
#                     4480
#                 ],
#                 [
#                     "2019-02-06",
#                     7297
#                 ],
#                 [
#                     "2019-02-07",
#                     23608
#                 ],
#                 [
#                     "2019-02-08",
#                     15484
#                 ],
#                 [
#                     "2019-02-09",
#                     8207
#                 ],
#                 [
#                     "2019-02-10",
#                     14675
#                 ],
#                 [
#                     "2019-02-11",
#                     22864
#                 ],
#                 [
#                     "2019-02-12",
#                     3203
#                 ],
#                 [
#                     "2019-02-13",
#                     9864
#                 ],
#                 [
#                     "2019-02-14",
#                     7769
#                 ],
#                 [
#                     "2019-02-15",
#                     2401
#                 ],
#                 [
#                     "2019-02-16",
#                     17447
#                 ],
#                 [
#                     "2019-02-17",
#                     8847
#                 ],
#                 [
#                     "2019-02-18",
#                     16730
#                 ],
#                 [
#                     "2019-02-19",
#                     14782
#                 ],
#                 [
#                     "2019-02-20",
#                     7069
#                 ],
#                 [
#                     "2019-02-21",
#                     11993
#                 ],
#                 [
#                     "2019-02-22",
#                     19478
#                 ],
#                 [
#                     "2019-02-23",
#                     13612
#                 ],
#                 [
#                     "2019-02-24",
#                     8665
#                 ],
#                 [
#                     "2019-02-25",
#                     15923
#                 ],
#                 [
#                     "2019-02-26",
#                     7077
#                 ],
#                 [
#                     "2019-02-27",
#                     23267
#                 ],
#                 [
#                     "2019-02-28",
#                     17495
#                 ],
#                 [
#                     "2019-03-01",
#                     22326
#                 ],
#                 [
#                     "2019-03-02",
#                     13641
#                 ],
#                 [
#                     "2019-03-03",
#                     12794
#                 ],
#                 [
#                     "2019-03-04",
#                     6718
#                 ],
#                 [
#                     "2019-03-05",
#                     12595
#                 ],
#                 [
#                     "2019-03-06",
#                     9460
#                 ],
#                 [
#                     "2019-03-07",
#                     21018
#                 ],
#                 [
#                     "2019-03-08",
#                     5497
#                 ],
#                 [
#                     "2019-03-09",
#                     17897
#                 ],
#                 [

# %%
# 矩形树图
import json
import os
from pyecharts import options as opts
from pyecharts.charts import Page, TreeMap

data = [
    {"value": 40, "name": "我是A"},
    {
        "value": 180,
        "name": "我是B",
        "children": [{
            "value": 76,
            "name": "我是B.children",
            "children": [
                {"value": 12, "name": "我是B.children.a"},
                {"value": 28, "name": "我是B.children.b"},
                {"value": 20, "name": "我是B.children.c"},
                {"value": 16, "name": "我是B.children.d"},
            ],
        }],
    }]

c = TreeMap()
c.add("演示数据", data)
c.set_global_opts(title_opts=opts.TitleOpts(title="TreeMap-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="516b6160129c4eaca016cd5770ab4454" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_516b6160129c4eaca016cd5770ab4454 = echarts.init(
#                     document.getElementById('516b6160129c4eaca016cd5770ab4454'), 'white', {renderer: 'canvas'});
#                 var option_516b6160129c4eaca016cd5770ab4454 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6f14\u793a\u6570\u636e",
#             "data": [
#                 {
#                     "value": 40,
#                     "name": "\u6211\u662fA"
#                 },
#                 {
#                     "value": 180,
#                     "name": "\u6211\u662fB",
#                     "children": [
#                         {
#                             "value": 76,
#                             "name": "\u6211\u662fB.children",
#                             "children": [
#                                 {
#                                     "value": 12,
#                                     "name": "\u6211\u662fB.children.a"
#                                 },
#                                 {
#                                     "value": 28,
#                                     "name": "\u6211\u662fB.children.b"
#                                 },
#                                 {
#                                     "value": 20,
#                                     "name": "\u6211\u662fB.children.c"
#                                 },
#                                 {
#                                     "value": 16,
#                                     "name": "\u6211\u662fB.children.d"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "width": "80%",
#             "height": "80%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "drillDownIcon": "\u25b6",
#             "roam": true,
#             "nodeClick": "zoomToNode"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6f14\u793a\u6570\u636e"
#             ],
#             "selected": {
#                 "\u6f14\u793a\u6570\u636e": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "TreeMap-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_516b6160129c4eaca016cd5770ab4454.setOption(option_516b6160129c4eaca016cd5770ab4454);
#         });
#     </script>

# %%
# 地图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()
m.add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="99c53d612d17443b9898c1b37f515496" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_99c53d612d17443b9898c1b37f515496 = echarts.init(
#                     document.getElementById('99c53d612d17443b9898c1b37f515496'), 'white', {renderer: 'canvas'});
#                 var option_99c53d612d17443b9898c1b37f515496 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 82
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 58
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 28
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_99c53d612d17443b9898c1b37f515496.setOption(option_99c53d612d17443b9898c1b37f515496);
#         });
#     </script>

# %% [markdown]
# # 定制主题

# %%
# 默认主题
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType

# 等价于 Bar(init_opts=opts.InitOpts(theme=ThemeType.WHITE))
c = Bar(init_opts=opts.InitOpts(theme=ThemeType.WHITE))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("Theme-default"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6aaaa4c624da4004b060ff74c45ba086" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6aaaa4c624da4004b060ff74c45ba086 = echarts.init(
#                     document.getElementById('6aaaa4c624da4004b060ff74c45ba086'), 'white', {renderer: 'canvas'});
#                 var option_6aaaa4c624da4004b060ff74c45ba086 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 100,
#                 31,
#                 132,
#                 96,
#                 97,
#                 88,
#                 144
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 72,
#                 66,
#                 78,
#                 75,
#                 85,
#                 124,
#                 128
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 124,
#                 77,
#                 120,
#                 64,
#                 56,
#                 43,
#                 74
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 108,
#                 98,
#                 100,
#                 101,
#                 80,
#                 76,
#                 147
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Theme-default",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6aaaa4c624da4004b060ff74c45ba086.setOption(option_6aaaa4c624da4004b060ff74c45ba086);
#         });
#     </script>

# %%
# LIGHT主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("LIGHT主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="13a17b4a07b64cc5b8da9010b77aebc5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_13a17b4a07b64cc5b8da9010b77aebc5 = echarts.init(
#                     document.getElementById('13a17b4a07b64cc5b8da9010b77aebc5'), 'light', {renderer: 'canvas'});
#                 var option_13a17b4a07b64cc5b8da9010b77aebc5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 95,
#                 23,
#                 50,
#                 135,
#                 64,
#                 85,
#                 98
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 26,
#                 129,
#                 144,
#                 58,
#                 73,
#                 95,
#                 79
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 95,
#                 36,
#                 30,
#                 92,
#                 68,
#                 69,
#                 120
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 86,
#                 88,
#                 20,
#                 42,
#                 132,
#                 75,
#                 83
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "LIGHT\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_13a17b4a07b64cc5b8da9010b77aebc5.setOption(option_13a17b4a07b64cc5b8da9010b77aebc5);
#         });
#     </script>

# %%
# DARK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("DARK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5956ed36c18e4558ae0918c3e3299583" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5956ed36c18e4558ae0918c3e3299583 = echarts.init(
#                     document.getElementById('5956ed36c18e4558ae0918c3e3299583'), 'dark', {renderer: 'canvas'});
#                 var option_5956ed36c18e4558ae0918c3e3299583 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 150,
#                 103,
#                 83,
#                 104,
#                 61,
#                 99,
#                 64
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 109,
#                 55,
#                 77,
#                 117,
#                 62,
#                 34,
#                 41
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 149,
#                 113,
#                 128,
#                 70,
#                 62,
#                 108,
#                 22
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 124,
#                 28,
#                 109,
#                 113,
#                 90,
#                 30,
#                 120
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "DARK\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5956ed36c18e4558ae0918c3e3299583.setOption(option_5956ed36c18e4558ae0918c3e3299583);
#         });
#     </script>

# %%
# CHALK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("CHALK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="7b3484c062ff4bd496e993d7de65f566" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_7b3484c062ff4bd496e993d7de65f566 = echarts.init(
#                     document.getElementById('7b3484c062ff4bd496e993d7de65f566'), 'chalk', {renderer: 'canvas'});
#                 var option_7b3484c062ff4bd496e993d7de65f566 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 39,
#                 73,
#                 65,
#                 92,
#                 48,
#                 81,
#                 21
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 69,
#                 52,
#                 72,
#                 62,
#                 22,
#                 115,
#                 70
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 21,
#                 23,
#                 136,
#                 130,
#                 113,
#                 26,
#                 41
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 83,
#                 74,
#                 100,
#                 108,
#                 132,
#                 135,
#                 149
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "CHALK\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7b3484c062ff4bd496e993d7de65f566.setOption(option_7b3484c062ff4bd496e993d7de65f566);
#         });
#     </script>

# %%
# ESSOS主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ESSOS主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="469a88a4a0f74d25b33088f37abf7b92" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_469a88a4a0f74d25b33088f37abf7b92 = echarts.init(
#                     document.getElementById('469a88a4a0f74d25b33088f37abf7b92'), 'essos', {renderer: 'canvas'});
#                 var option_469a88a4a0f74d25b33088f37abf7b92 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 74,
#                 79,
#                 65,
#                 93,
#                 118,
#                 23,
#                 51
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 33,
#                 88,
#                 126,
#                 124,
#                 95,
#                 94,
#                 144
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 87,
#                 38,
#                 140,
#                 66,
#                 94,
#                 69,
#                 46
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 120,
#                 131,
#                 105,
#                 144,
#                 114,
#                 59,
#                 123
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ESSOS\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_469a88a4a0f74d25b33088f37abf7b92.setOption(option_469a88a4a0f74d25b33088f37abf7b92);
#         });
#     </script>

# %%
# PURPLE_PASSION主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("PURPLE_PASSION主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="c990a26520b448ec851f0e2e9dc64ad1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_c990a26520b448ec851f0e2e9dc64ad1 = echarts.init(
#                     document.getElementById('c990a26520b448ec851f0e2e9dc64ad1'), 'purple-passion', {renderer: 'canvas'});
#                 var option_c990a26520b448ec851f0e2e9dc64ad1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 134,
#                 41,
#                 37,
#                 108,
#                 139,
#                 110,
#                 99
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 106,
#                 116,
#                 97,
#                 107,
#                 118,
#                 87,
#                 94
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 54,
#                 144,
#                 65,
#                 101,
#                 144,
#                 117,
#                 135
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 69,
#                 110,
#                 132,
#                 56,
#                 27,
#                 118,
#                 69
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "PURPLE_PASSION\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c990a26520b448ec851f0e2e9dc64ad1.setOption(option_c990a26520b448ec851f0e2e9dc64ad1);
#         });
#     </script>

# %%
# ROMA主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ROMA主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="e2e0b583b5a946c79c023f11a65b2892" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_e2e0b583b5a946c79c023f11a65b2892 = echarts.init(
#                     document.getElementById('e2e0b583b5a946c79c023f11a65b2892'), 'roma', {renderer: 'canvas'});
#                 var option_e2e0b583b5a946c79c023f11a65b2892 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 138,
#                 111,
#                 150,
#                 125,
#                 80,
#                 120,
#                 70
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 58,
#                 62,
#                 121,
#                 50,
#                 112,
#                 127,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 60,
#                 130,
#                 24,
#                 62,
#                 61,
#                 79,
#                 150
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 143,
#                 122,
#                 22,
#                 38,
#                 107,
#                 46,
#                 80
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ROMA\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e2e0b583b5a946c79c023f11a65b2892.setOption(option_e2e0b583b5a946c79c023f11a65b2892);
#         });
#     </script>

# %%
# VINTAGE主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("VINTAGE主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="f82ed675374e48beb0a41f0ccaf95ef4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_f82ed675374e48beb0a41f0ccaf95ef4 = echarts.init(
#                     document.getElementById('f82ed675374e48beb0a41f0ccaf95ef4'), 'vintage', {renderer: 'canvas'});
#                 var option_f82ed675374e48beb0a41f0ccaf95ef4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 74,
#                 121,
#                 92,
#                 26,
#                 58,
#                 147,
#                 140
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 46,
#                 129,
#                 52,
#                 47,
#                 141,
#                 53,
#                 72
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 117,
#                 27,
#                 52,
#                 79,
#                 85,
#                 115,
#                 30
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 103,
#                 86,
#                 125,
#                 85,
#                 42,
#                 92,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "VINTAGE\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_f82ed675374e48beb0a41f0ccaf95ef4.setOption(option_f82ed675374e48beb0a41f0ccaf95ef4);
#         });
#     </script>

# %% [markdown]
# # 实战项目一 - 见PPT

# %%
import pandas as pd
df = pd.read_csv("jobs.csv")
df.drop_duplicates(inplace=True)
df
# Out:
#                                                  title                company  \
# 0                                              招聘数据分析师           北京越铖国际科技有限公司
# 1                                                数据分析师      北京新东方教育科技（集团）有限公司
# 2                                            数据分析师(新浪)          新浪网技术(中国)有限公司
# 3                                                数据分析师         北京美科思远环境科技有限公司
# 4    助理、临床样本库采样人员、软件工程师、数据库管理工程师、机械设计与结构工程师、Android...  中国人民解放军总医院（北京市解放军医学院）
# ..                                                 ...                    ...
# 645                                      数据分析工程师(清控紫荆)     清控紫荆(北京)教育科技股份有限公司
# 646                  风险决策分析师-大数据方向009777(京东数字科技控股有限公司)           京东数字科技控股有限公司
# 647                                数据分析工程师（物流规划）(旷视科技)             北京旷视科技有限公司
# 648                       网络人工智能架构师大数据分析架构师(国内知名互联网企业)              国内知名互联网企业
# 649                             气象数据分析工程师(航天新气象科技有限公司)            航天新气象科技有限公司
#
#     company_size      industry type       salary company_type     source  \
# 0         20-99人    人事/行政/高级管理   全职   8000-12000           民营         斗米
# 1            NaN  计算机/互联网/信息技术   全职  12000-20000           民营  OFweek人才网
# 2     2000-5000人         数据分析师   全职  20000-25000     外商独资/办事处         猎聘
# 3         20-99人      环保/环境科学类   全职  12000-20000          股份制      北极星招聘
# 4            NaN            医疗   全职           面议         公立医院    康强医疗人才网
# ..           ...           ...  ...          ...          ...        ...
# 645       50-99人    其他互联网+技术职位   全职      25000以上           民营         猎聘
# 646   2000-5000人   能源/采掘/化工/环保   全职           面议     外商独资/办事处         猎聘
# 647   2000-5000人         数据分析师   全职           面议           民营         猎聘
# 648       50-99人        IT/互联网   全职      25000以上           民营         猎聘
# 649     100-499人         数据分析师   全职           面议           国企         猎聘
#
#     experience education  salary2
# 0           不限        不限  10000.0
# 1           不限        不限  16000.0
# 2         3-5年        本科  22500.0
# 3           不限        硕士  16000.0
# 4           不限        不限      NaN
# ..         ...       ...      ...
# 645       3-5年        本科  25000.0
# 646       3-5年        硕士      NaN
# 647       3-5年        本科      NaN
# 648      5-10年        本科  25000.0
# 649         不限        本科      NaN
#
# [650 rows x 11 columns]

# %%
# 统计各类规模的招聘公司的数量
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
s_size = df.company_size.value_counts()
bar = Bar()
bar.add_xaxis(s_size.index.tolist())
bar.add_yaxis("公司数量", s_size.values.tolist())
bar.set_global_opts(title_opts=opts.TitleOpts(title="各类规模的公司数量"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce59bc303fbc466a9905a4f22f2d2131" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce59bc303fbc466a9905a4f22f2d2131 = echarts.init(
#                     document.getElementById('ce59bc303fbc466a9905a4f22f2d2131'), 'white', {renderer: 'canvas'});
#                 var option_ce59bc303fbc466a9905a4f22f2d2131 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "data": [
#                 193,
#                 81,
#                 63,
#                 56,
#                 54,
#                 49,
#                 35,
#                 29,
#                 24,
#                 2,
#                 1,
#                 1
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "100-499\u4eba",
#                 "10000\u4eba\u4ee5\u4e0a",
#                 "500-999\u4eba",
#                 "50-99\u4eba",
#                 "2000-5000\u4eba",
#                 "1000-2000\u4eba",
#                 "5000-10000\u4eba",
#                 "20-99\u4eba",
#                 "1-49\u4eba",
#                 "\u5176\u5b83",
#                 "1000-9999\u4eba",
#                 "100"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u7c7b\u89c4\u6a21\u7684\u516c\u53f8\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ce59bc303fbc466a9905a4f22f2d2131.setOption(option_ce59bc303fbc466a9905a4f22f2d2131);
#         });
#     </script>

# %%
# 统计职位来源
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_source = df["source"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_source.index.tolist(), s_source.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="职位来源"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4cec81af40f54cad8cc1ba538136ffbd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4cec81af40f54cad8cc1ba538136ffbd = echarts.init(
#                     document.getElementById('4cec81af40f54cad8cc1ba538136ffbd'), 'white', {renderer: 'canvas'});
#                 var option_4cec81af40f54cad8cc1ba538136ffbd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u730e\u8058",
#                     "value": 580
#                 },
#                 {
#                     "name": "OFweek\u4eba\u624d\u7f51",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u6597\u7c73",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u5317\u6781\u661f\u62db\u8058",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u767e\u59d3\u7f51",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u666e\u5de5\u62db\u8058\u7f51",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5de5\u5382\u76f4\u8058\u7f51",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u730e\u8058",
#                 "OFweek\u4eba\u624d\u7f51",
#                 "\u6597\u7c73",
#                 "\u5317\u6781\u661f\u62db\u8058",
#                 "\u767e\u59d3\u7f51",
#                 "\u666e\u5de5\u62db\u8058\u7f51",
#                 "\u5de5\u5382\u76f4\u8058\u7f51",
#                 "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u804c\u4f4d\u6765\u6e90",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4cec81af40f54cad8cc1ba538136ffbd.setOption(option_4cec81af40f54cad8cc1ba538136ffbd);
#         });
#     </script>

# %%
# 统计工作年限要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_exp = df["experience"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_exp.index.tolist(), s_exp.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="工作年限要求"),
                   legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1175cb40c6744a8385f662cf2ae6fa56" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1175cb40c6744a8385f662cf2ae6fa56 = echarts.init(
#                     document.getElementById('1175cb40c6744a8385f662cf2ae6fa56'), 'white', {renderer: 'canvas'});
#                 var option_1175cb40c6744a8385f662cf2ae6fa56 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 232
#                 },
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 142
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 75
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 4
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "3-5\u5e74",
#                 "1-3\u5e74",
#                 "\u4e0d\u9650",
#                 "5-10\u5e74",
#                 "10\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5de5\u4f5c\u5e74\u9650\u8981\u6c42",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1175cb40c6744a8385f662cf2ae6fa56.setOption(option_1175cb40c6744a8385f662cf2ae6fa56);
#         });
#     </script>

# %%
# 统计学历背景要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_edu = df["education"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_edu.index.tolist(), s_edu.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="学历背景要求"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4b11bc146b814f5a8e19ae149b55c50e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4b11bc146b814f5a8e19ae149b55c50e = echarts.init(
#                     document.getElementById('4b11bc146b814f5a8e19ae149b55c50e'), 'white', {renderer: 'canvas'});
#                 var option_4b11bc146b814f5a8e19ae149b55c50e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 489
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u521d\u4e2d",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u535a\u58eb",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672c\u79d1",
#                 "\u4e0d\u9650",
#                 "\u7855\u58eb",
#                 "\u5927\u4e13",
#                 "\u521d\u4e2d",
#                 "\u535a\u58eb"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5b66\u5386\u80cc\u666f\u8981\u6c42",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4b11bc146b814f5a8e19ae149b55c50e.setOption(option_4b11bc146b814f5a8e19ae149b55c50e);
#         });
#     </script>

# %%
# 统计不同工资段的分布
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_salary = df["salary"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_salary.index.tolist(), s_salary.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="不同工资段的分布"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d3f099e25fd2452aa1a0476a162c87b9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d3f099e25fd2452aa1a0476a162c87b9 = echarts.init(
#                     document.getElementById('d3f099e25fd2452aa1a0476a162c87b9'), 'white', {renderer: 'canvas'});
#                 var option_d3f099e25fd2452aa1a0476a162c87b9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "8000-12000",
#                     "value": 191
#                 },
#                 {
#                     "name": "12000-20000",
#                     "value": 170
#                 },
#                 {
#                     "name": "\u9762\u8bae",
#                     "value": 104
#                 },
#                 {
#                     "name": "20000-25000",
#                     "value": 60
#                 },
#                 {
#                     "name": "25000\u4ee5\u4e0a",
#                     "value": 59
#                 },
#                 {
#                     "name": "5000-8000",
#                     "value": 46
#                 },
#                 {
#                     "name": "3000-5000",
#                     "value": 5
#                 },
#                 {
#                     "name": "5001-8000",
#                     "value": 5
#                 },
#                 {
#                     "name": "6000-8000",
#                     "value": 2
#                 },
#                 {
#                     "name": "2800-3500",
#                     "value": 1
#                 },
#                 {
#                     "name": "3150-5650",
#                     "value": 1
#                 },
#                 {
#                     "name": "3000-6000",
#                     "value": 1
#                 },
#                 {
#                     "name": "9000-12000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2500-4000",
#                     "value": 1
#                 },
#                 {
#                     "name": "5500-15000",
#                     "value": 1
#                 },
#                 {
#                     "name": "5500-12000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2000-3000",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "8000-12000",
#                 "12000-20000",
#                 "\u9762\u8bae",
#                 "20000-25000",
#                 "25000\u4ee5\u4e0a",
#                 "5000-8000",
#                 "3000-5000",
#                 "5001-8000",
#                 "6000-8000",
#                 "2800-3500",
#                 "3150-5650",
#                 "3000-6000",
#                 "9000-12000",
#                 "2500-4000",
#                 "5500-15000",
#                 "5500-12000",
#                 "2000-3000"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0d\u540c\u5de5\u8d44\u6bb5\u7684\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d3f099e25fd2452aa1a0476a162c87b9.setOption(option_d3f099e25fd2452aa1a0476a162c87b9);
#         });
#     </script>

# %%
# 统计哪些公司工资最高
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
import numpy as np

df_avgsalary = df.groupby("company")["salary2"].agg(avgsalary="mean")
df_avgsalary.dropna(how="any", inplace=True)
companies = list(zip(df_avgsalary.index.tolist(), df_avgsalary["avgsalary"].astype(np.uint16).tolist()))
wc = WordCloud()
wc.add("", companies, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="哪些公司工资最高"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="168d1534afab4bc48c8807ce30c1a91e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_168d1534afab4bc48c8807ce30c1a91e = echarts.init(
#                     document.getElementById('168d1534afab4bc48c8807ce30c1a91e'), 'white', {renderer: 'canvas'});
#                 var option_168d1534afab4bc48c8807ce30c1a91e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "xx\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,139,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e07\u5b66\u79d1\u6280(\u5317\u4eac)\u6709\u9650\u516c\u53f8",
#                     "value": 4000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(81,18,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u51b0\u9274\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,153,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5357\u71d5\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 6500,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,38,126)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u53f8\u7fbd\u901a\u4fe1\u8bbe\u5907\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,151,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u60a6\u6613\u7f51\u7edc\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,60,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6295\u4e2d\u4fe1\u606f\u54a8\u8be2\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,120,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u65ed\u626c\u822a\u8fd0\u670d\u52a1\u6709\u9650\u516c\u53f814",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,107,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6ca3\u77f3\u6570\u636e\u670d\u52a1\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,132,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6dc7\u6bd3\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,57,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u70db\u9f99\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,5,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79d1\u65ed\u7f51\u7edc\u79d1\u6280\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,152,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79fb\u8bfa\u56fd\u9645\u7269\u6d41\u6709\u9650\u516c\u53f813",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,128,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8054\u851a\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,34,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8c6b\u8f89\u8d27\u7269\u8fd0\u8f93\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,127,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u91d1\u606a\u4f01\u4e1a\u7ba1\u7406\u54a8\u8be2\u6709\u9650\u516c\u53f8",
#                     "value": 13000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,66,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u94f8\u5ca9\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(31,61,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u9877\u6167\u7269\u6d41\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,40,47)"
#                         }
#                     }
#                 },

# %%
# 统计各类型公司的数量
from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType

s_comptype = df["company_type"].value_counts(ascending=True)


companies = s_comptype.index.tolist()
comptypes = s_comptype.values.tolist()

c = PictorialBar()
c.add_xaxis(companies)
c.add_yaxis(
            "",
            comptypes,
            label_opts=opts.LabelOpts(is_show=False),
            symbol_size=18,
            symbol_repeat="fixed",
            symbol_offset=[0, 0],
            is_symbol_clip=True,
            symbol=SymbolType.ROUND_RECT,
        )
c.reversal_axis()
c.set_global_opts(
            title_opts=opts.TitleOpts(title="公司类型"),
            xaxis_opts=opts.AxisOpts(is_show=False),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
            ),
        )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="16a7153b78bc42c79529139f8ce1f5e2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_16a7153b78bc42c79529139f8ce1f5e2 = echarts.init(
#                     document.getElementById('16a7153b78bc42c79529139f8ce1f5e2'), 'white', {renderer: 'canvas'});
#                 var option_16a7153b78bc42c79529139f8ce1f5e2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 1,
#                 1,
#                 1,
#                 2,
#                 4,
#                 34,
#                 42,
#                 45,
#                 62,
#                 458
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u80a1\u4efd\u5236",
#                 "\u5176\u5b83",
#                 "\u516c\u7acb\u533b\u9662",
#                 "\u4e2a\u4eba\u4f01\u4e1a",
#                 "\u4e8b\u4e1a\u5355\u4f4d",
#                 "\u56fd\u4f01",
#                 "\u4e2d\u5916\u5408\u8d44/\u5408\u4f5c",
#                 "\u5916\u5546\u72ec\u8d44/\u529e\u4e8b\u5904",
#                 "\u4e0a\u5e02\u516c\u53f8",
#                 "\u6c11\u8425"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u516c\u53f8\u7c7b\u578b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_16a7153b78bc42c79529139f8ce1f5e2.setOption(option_16a7153b78bc42c79529139f8ce1f5e2);
#         });
#     </script>

# %% [markdown]
# # 实战项目二 - 见PPT

# %%
df = pd.read_csv("stocks.csv")
df.head()
# Out:
#    name industry area      pe  outstanding  totals  totalAssets  liquidAssets  \
# 0   N有方     软件服务   深圳  134.49         0.19    0.92         8.03          6.18
# 1   N泽璟     化学制药   江苏    0.00         0.55    2.40         2.97          1.17
# 2  N玉禾田     环境保护   安徽   18.46         0.35    1.38        24.84         14.23
# 3  热景生物     医疗保健   北京  251.27         0.14    0.62         6.98          5.45
# 4  鲁抗医药     化学制药   山东   73.98         8.52    8.80        70.58         27.59
#
#    fixedAssets  reserved  ...   bvps    pb  timeToMarket  undp  perundp  \
# 0         0.06      2.82  ...   9.81  5.77      20200123  1.23     1.34
# 1         0.56      2.86  ...   8.20  9.10      20200123 -4.09    -1.70
# 2         5.47      0.28  ...  13.60  3.13      20200123  7.88     5.70
# 3         1.25      4.46  ...  10.04  7.09      20190930  1.06     1.71
# 4        22.30     16.25  ...   3.42  3.33      19970226  3.51     0.40
#
#      rev  profit    gpr   npr   holders
# 0   0.00    0.00  22.88  5.66   19486.0
# 1   0.00    0.00   0.00  0.00   36598.0
# 2   0.00    0.00  21.73  9.09   68996.0
# 3   0.00    0.00  72.54  9.60   10316.0
# 4  15.07  -29.42  28.21  3.72  112796.0
#
# [5 rows x 22 columns]

# %%
# 计算市盈率中位数
df.pe.median()
# Out:
# 28.58

# %%
# 盈利能力排名
df_company = df[df.pe>0][["name", "pe", "pb"]].sort_values("pe").head(10)
df_company
# Out:
#       name    pe    pb
# 2738  神火股份  2.74  1.08
# 107   浙江广厦  2.75  1.23
# 1080  新集能源  3.05  1.07
# 2446  广宇发展  4.11  1.04
# 2178  华菱钢铁  4.13  0.90
# 2152  新钢股份  4.26  0.72
# 1318  五洲交通  4.30  1.14
# 1294  民生银行  4.39  0.60
# 1403  南钢股份  4.52  0.87
# 2811  ST辅仁  4.63  0.57

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_company.name.values.tolist())
bar.add_yaxis("市盈率", df_company.pe.values.tolist())
bar.add_yaxis("市净率", df_company.pb.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="市盈率"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="55b9ca8c185f481aa04c714cba15351b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_55b9ca8c185f481aa04c714cba15351b = echarts.init(
#                     document.getElementById('55b9ca8c185f481aa04c714cba15351b'), 'white', {renderer: 'canvas'});
#                 var option_55b9ca8c185f481aa04c714cba15351b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e02\u76c8\u7387",
#             "data": [
#                 2.74,
#                 2.75,
#                 3.05,
#                 4.11,
#                 4.13,
#                 4.26,
#                 4.3,
#                 4.39,
#                 4.52,
#                 4.63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e02\u51c0\u7387",
#             "data": [
#                 1.08,
#                 1.23,
#                 1.07,
#                 1.04,
#                 0.9,
#                 0.72,
#                 1.14,
#                 0.6,
#                 0.87,
#                 0.57
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e02\u76c8\u7387",
#                 "\u5e02\u51c0\u7387"
#             ],
#             "selected": {
#                 "\u5e02\u76c8\u7387": true,
#                 "\u5e02\u51c0\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u795e\u706b\u80a1\u4efd",
#                 "\u6d59\u6c5f\u5e7f\u53a6",
#                 "\u65b0\u96c6\u80fd\u6e90",
#                 "\u5e7f\u5b87\u53d1\u5c55",
#                 "\u534e\u83f1\u94a2\u94c1",
#                 "\u65b0\u94a2\u80a1\u4efd",
#                 "\u4e94\u6d32\u4ea4\u901a",
#                 "\u6c11\u751f\u94f6\u884c",
#                 "\u5357\u94a2\u80a1\u4efd",
#                 "ST\u8f85\u4ec1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e02\u76c8\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_55b9ca8c185f481aa04c714cba15351b.setOption(option_55b9ca8c185f481aa04c714cba15351b);
#         });
#     </script>

# %%
# 各地区公司数量
df_num = df.groupby("area")["name"].agg(company_num="count")

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()

m.add("公司数量", [list(z) for z in zip(df_num.index.values.tolist(), df_num.company_num.values.tolist())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=500, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8ec39a28217449f99affb4c5e03ae405" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8ec39a28217449f99affb4c5e03ae405 = echarts.init(
#                     document.getElementById('8ec39a28217449f99affb4c5e03ae405'), 'white', {renderer: 'canvas'});
#                 var option_8ec39a28217449f99affb4c5e03ae405 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 305
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 348
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 323
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 429
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 464
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 302
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_8ec39a28217449f99affb4c5e03ae405.setOption(option_8ec39a28217449f99affb4c5e03ae405);
#         });
#     </script>

# %%
# 净利润率和毛利率中位数
npr = df["npr"].median()/100
gpr = df["gpr"].median()/100

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [gpr, npr])
l.set_global_opts(title_opts=opts.TitleOpts(title="利润率"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="690224e8ae5746d6b399210caa8c0069" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_690224e8ae5746d6b399210caa8c0069 = echarts.init(
#                     document.getElementById('690224e8ae5746d6b399210caa8c0069'), 'white', {renderer: 'canvas'});
#                 var option_690224e8ae5746d6b399210caa8c0069 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.2718,
#                 0.0738
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5229\u6da6\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_690224e8ae5746d6b399210caa8c0069.setOption(option_690224e8ae5746d6b399210caa8c0069);
#         });
#     </script>

# %%
df_npr = df.groupby("industry")["npr"].agg(avg_npr="mean").sort_values("avg_npr", ascending=False)
df_top = df_npr.head(10)
df_top["avg_npr"] = df_top["avg_npr"].apply(lambda x: float("{:.2f}".format(x)))
df_top
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           avg_npr
# industry
# 证券         238.11
# 多元金融        65.45
# 路桥          43.23
# 水力发电        41.61
# 保险          39.60
# 影视音像        36.98
# 银行          34.50
# 商品城         30.27
# 机场          26.31
# 园区开发        25.26

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_top.index.tolist())
bar.add_yaxis("净利润率", df_top.avg_npr.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="净利润率排名"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6a3e42b610d64d7386e25471a1630a04" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6a3e42b610d64d7386e25471a1630a04 = echarts.init(
#                     document.getElementById('6a3e42b610d64d7386e25471a1630a04'), 'white', {renderer: 'canvas'});
#                 var option_6a3e42b610d64d7386e25471a1630a04 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u51c0\u5229\u6da6\u7387",
#             "data": [
#                 238.11,
#                 65.45,
#                 43.23,
#                 41.61,
#                 39.6,
#                 36.98,
#                 34.5,
#                 30.27,
#                 26.31,
#                 25.26
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51c0\u5229\u6da6\u7387"
#             ],
#             "selected": {
#                 "\u51c0\u5229\u6da6\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8bc1\u5238",
#                 "\u591a\u5143\u91d1\u878d",
#                 "\u8def\u6865",
#                 "\u6c34\u529b\u53d1\u7535",
#                 "\u4fdd\u9669",
#                 "\u5f71\u89c6\u97f3\u50cf",
#                 "\u94f6\u884c",
#                 "\u5546\u54c1\u57ce",
#                 "\u673a\u573a",
#                 "\u56ed\u533a\u5f00\u53d1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u51c0\u5229\u6da6\u7387\u6392\u540d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6a3e42b610d64d7386e25471a1630a04.setOption(option_6a3e42b610d64d7386e25471a1630a04);
#         });
#     </script>

# %%
# 各行业公司数量
df_industry = df.groupby("industry")["name"].agg(company_num="count")

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

words = [list(z) for z in zip(df_industry.index.values.tolist(), df_industry.company_num.values.tolist())]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100], shape="diamond")
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ca9418812b0f41598a2ac4305cb45622" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ca9418812b0f41598a2ac4305cb45622 = echarts.init(
#                     document.getElementById('ca9418812b0f41598a2ac4305cb45622'), 'white', {renderer: 'canvas'});
#                 var option_ca9418812b0f41598a2ac4305cb45622 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "IT\u8bbe\u5907",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(47,22,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u7528\u673a\u68b0",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,12,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6210\u836f",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,92,108)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e73\u5236\u54c1",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,72,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,50,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ed3\u50a8\u7269\u6d41",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,17,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u4f9b\u70ed",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,127,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u9669",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,103,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5143\u5668\u4ef6",
#                     "value": 183,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(75,52,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5168\u56fd\u5730\u4ea7",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,132,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u4ea4\u901a",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(45,108,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u8def",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,44,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5546\u4e1a",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,81,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5efa\u6750",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,13,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u4e1a\u7efc\u5408",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,90,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u7528\u673a\u68b0",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,65,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u836f\u5316\u80a5",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,10,101)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u7248\u4e1a",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,7,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5b66\u5236\u836f",
#                     "value": 104,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,120,59)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u539f\u6599",
#                     "value": 164,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,45,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u673a\u68b0",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,53,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u7ea4",

# %% [markdown]
# # 实战项目三 - 见PPT

# %%
df = pd.read_csv("houses.csv", sep='>', index_col=0)
df = df.drop_duplicates(["title", "price",
                    "xiaoqu_name", "size",
                    "buildyear", "huxing",
                    "chaoxiang", "zhuangxiu",
                    "cenggao", "district_name",
                    "sub_district_name"])
df.head(2)
# Out:
#                         _id                        title  price  up_price  \
# 0  5dd2198f18bba2b4a9a0b854     大华电梯两房/房型正气/开门南北通/房东诚意出售  690.0   76531.0
# 1  5dd2198f18bba2b4a9a0b855  非底楼 满五年唯一 税费少 婚房装修 楼称佳 户型方正  330.0   52290.0
#
#          xiaoqu_name   size  buildyear huxing chaoxiang zhuangxiu  \
# 0  大华锦绣华城(十六街区)(公寓)   90.16       2010  2室2厅         南        简装
# 1               芳雅苑   63.11       1995  2室1厅         南        精装
#
#        cenggao louxing district_name sub_district_name
# 0   中楼层(共18层)       板楼            浦东                北蔡
# 1    低楼层(共6层)       板楼            浦东                北蔡

# %%
# 每个区的均价
df_avg = df.groupby("district_name")["up_price"].agg(avg_price="mean").sort_values("avg_price")

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = Bar()
avg_price = np.round(df_avg.avg_price.values).tolist()
bar.add_xaxis(df_avg.index.values.tolist())
bar.add_yaxis("均价", avg_price)

bar.set_global_opts(title_opts=opts.TitleOpts(title="上海各区均价"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0323552e89134323a792f1af64403a2d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0323552e89134323a792f1af64403a2d = echarts.init(
#                     document.getElementById('0323552e89134323a792f1af64403a2d'), 'white', {renderer: 'canvas'});
#                 var option_0323552e89134323a792f1af64403a2d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5747\u4ef7",
#             "data": [
#                 19382.0,
#                 23728.0,
#                 36142.0,
#                 36309.0,
#                 37088.0,
#                 42185.0,
#                 49007.0,
#                 55620.0,
#                 58060.0,
#                 62052.0,
#                 66926.0,
#                 72458.0,
#                 75622.0,
#                 75852.0,
#                 96033.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u5747\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u91d1\u5c71",
#                 "\u5949\u8d24",
#                 "\u5609\u5b9a",
#                 "\u677e\u6c5f",
#                 "\u9752\u6d66",
#                 "\u5b9d\u5c71",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c",
#                 "\u666e\u9640",
#                 "\u6768\u6d66",
#                 "\u8679\u53e3",
#                 "\u957f\u5b81",
#                 "\u9759\u5b89",
#                 "\u5f90\u6c47",
#                 "\u9ec4\u6d66"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u5747\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0323552e89134323a792f1af64403a2d.setOption(option_0323552e89134323a792f1af64403a2d);
#         });
#     </script>

# %%
# 房源在各个区的分布情况
df_district = df.groupby("district_name")["price"].agg(house_num="count").sort_values(by="house_num")

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
pie = Pie()
districts = df_district.index.values.tolist()
values = df_district.house_num.values.tolist()
pie.add("", [list(z) for z in zip(districts, values)])
pie.set_global_opts(
    title_opts=opts.TitleOpts(title="房源分布"),
    legend_opts=opts.LegendOpts(orient="verticle", pos_right=20))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3d503626a0544355b47e06287c18270d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3d503626a0544355b47e06287c18270d = echarts.init(
#                     document.getElementById('3d503626a0544355b47e06287c18270d'), 'white', {renderer: 'canvas'});
#                 var option_3d503626a0544355b47e06287c18270d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91d1\u5c71",
#                     "value": 925
#                 },
#                 {
#                     "name": "\u9752\u6d66",
#                     "value": 1660
#                 },
#                 {
#                     "name": "\u5949\u8d24",
#                     "value": 2072
#                 },
#                 {
#                     "name": "\u9ec4\u6d66",
#                     "value": 2100
#                 },
#                 {
#                     "name": "\u8679\u53e3",
#                     "value": 2324
#                 },
#                 {
#                     "name": "\u957f\u5b81",
#                     "value": 3679
#                 },
#                 {
#                     "name": "\u5609\u5b9a",
#                     "value": 4059
#                 },
#                 {
#                     "name": "\u9759\u5b89",
#                     "value": 4429
#                 },
#                 {
#                     "name": "\u666e\u9640",
#                     "value": 4555
#                 },
#                 {
#                     "name": "\u5f90\u6c47",
#                     "value": 4556
#                 },
#                 {
#                     "name": "\u677e\u6c5f",
#                     "value": 4669
#                 },
#                 {
#                     "name": "\u6768\u6d66",
#                     "value": 4872
#                 },
#                 {
#                     "name": "\u5b9d\u5c71",
#                     "value": 5145
#                 },
#                 {
#                     "name": "\u95f5\u884c",
#                     "value": 9853
#                 },
#                 {
#                     "name": "\u6d66\u4e1c",
#                     "value": 18726
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u5c71",
#                 "\u9752\u6d66",
#                 "\u5949\u8d24",
#                 "\u9ec4\u6d66",
#                 "\u8679\u53e3",
#                 "\u957f\u5b81",
#                 "\u5609\u5b9a",
#                 "\u9759\u5b89",
#                 "\u666e\u9640",
#                 "\u5f90\u6c47",
#                 "\u677e\u6c5f",
#                 "\u6768\u6d66",
#                 "\u5b9d\u5c71",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c"
#             ],
#             "selected": {},
#             "show": true,
#             "right": 20,
#             "orient": "verticle",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u623f\u6e90\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3d503626a0544355b47e06287c18270d.setOption(option_3d503626a0544355b47e06287c18270d);
#         });
#     </script>

# %%
# 房源的装修情况
df_zhuangxiu = df[df.zhuangxiu!=""].groupby("zhuangxiu")["price"].agg(house_num="count").sort_values(by="house_num")

# %%
zhuangxiu = df_zhuangxiu.index.values.tolist()
house_num = df_zhuangxiu.house_num.values.tolist()

from pyecharts import options as opts
from pyecharts.charts import Pie
pie = Pie()
pie.add("", [list(z) for z in zip(zhuangxiu, house_num)])
pie.set_global_opts(title_opts=opts.TitleOpts(title="装修"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a99e5a981790487c894d1d7af506d815" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a99e5a981790487c894d1d7af506d815 = echarts.init(
#                     document.getElementById('a99e5a981790487c894d1d7af506d815'), 'white', {renderer: 'canvas'});
#                 var option_a99e5a981790487c894d1d7af506d815 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": " \u6bdb\u576f ",
#                     "value": 5720
#                 },
#                 {
#                     "name": " \u5176\u4ed6 ",
#                     "value": 5832
#                 },
#                 {
#                     "name": " \u7b80\u88c5 ",
#                     "value": 24233
#                 },
#                 {
#                     "name": " \u7cbe\u88c5 ",
#                     "value": 34319
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 " \u6bdb\u576f ",
#                 " \u5176\u4ed6 ",
#                 " \u7b80\u88c5 ",
#                 " \u7cbe\u88c5 "
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u88c5\u4fee",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a99e5a981790487c894d1d7af506d815.setOption(option_a99e5a981790487c894d1d7af506d815);
#         });
#     </script>

# %%
# 用地图展现每个区房价
from pyecharts import options as opts
from pyecharts.charts import Map

districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
avg_price = np.round(df_avg.avg_price.values).tolist()
print(districts)
print(avg_price)
m = Map()
m.add("房价", [list(z) for z in zip(districts, avg_price)], "上海")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="上海各区房价"),
    visualmap_opts=opts.VisualMapOpts(max_=100000, is_piecewise=True),
)
m.render_notebook()
# Out:
# ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
# [19382.0, 23728.0, 36142.0, 36309.0, 37088.0, 42185.0, 49007.0, 55620.0, 58060.0, 62052.0, 66926.0, 72458.0, 75622.0, 75852.0, 96033.0]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="c6aeeb0aa84f4b89abb36e221f171996" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_c6aeeb0aa84f4b89abb36e221f171996 = echarts.init(
#                     document.getElementById('c6aeeb0aa84f4b89abb36e221f171996'), 'white', {renderer: 'canvas'});
#                 var option_c6aeeb0aa84f4b89abb36e221f171996 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u623f\u4ef7",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 19382.0
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 23728.0
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 36142.0
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 36309.0
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 37088.0
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 42185.0
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 49007.0
#                 },
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": 55620.0
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 58060.0
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": 62052.0
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 66926.0
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": 72458.0
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": 75622.0
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": 75852.0
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": 96033.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u623f\u4ef7"
#             ],
#             "selected": {
#                 "\u623f\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u623f\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_c6aeeb0aa84f4b89abb36e221f171996.setOption(option_c6aeeb0aa84f4b89abb36e221f171996);
#         });
#     </script>
