# %% [markdown]
# # pyecharts介绍
# + 基于百度开源的一个数据可视化JS库echarts
# + 支持非常多的图表类型
# + 可视化效果非常棒
# + 可交互的动态效果
# + 用Python生成Echarts图表的类库

# %% [markdown]
# # 安装pyecharts
# 打开Anaconda命令行，运行
# ```bash
# pip install pyecharts==1.6.2 -i https://mirrors.aliyun.com/pypi/simple/
# ```

# %% [markdown]
# # 验证版本

# %%
import pyecharts
print(pyecharts.__version__)
# Out:
# 1.6.2

# %% [markdown]
# # 绘图

# %%
# 折线图
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line

line = Line()
line.add_xaxis(Faker.choose())
line.add_yaxis("商家A", Faker.values())
line.add_yaxis("商家B", Faker.values())
line.set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ccbae665c1094408a85842e709e39f39" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ccbae665c1094408a85842e709e39f39 = echarts.init(
#                     document.getElementById('ccbae665c1094408a85842e709e39f39'), 'white', {renderer: 'canvas'});
#                 var option_ccbae665c1094408a85842e709e39f39 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     23
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     66
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     35
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     108
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     81
#                 ],
#                 [
#                     "VIVO",
#                     73
#                 ],
#                 [
#                     "OPPO",
#                     56
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     102
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     137
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     125
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     31
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     76
#                 ],
#                 [
#                     "VIVO",
#                     43
#                 ],
#                 [
#                     "OPPO",
#                     138
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Line-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ccbae665c1094408a85842e709e39f39.setOption(option_ccbae665c1094408a85842e709e39f39);
#         });
#     </script>

# %%
# 柱状图
from pyecharts.faker import Faker
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
bar = Bar()
bar.add_xaxis(Faker.choose())
bar.add_yaxis("商家A", Faker.values())
bar.add_yaxis("商家B", Faker.values())
bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8e22293e2a8249cb915cdea1d0b39abb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8e22293e2a8249cb915cdea1d0b39abb = echarts.init(
#                     document.getElementById('8e22293e2a8249cb915cdea1d0b39abb'), 'white', {renderer: 'canvas'});
#                 var option_8e22293e2a8249cb915cdea1d0b39abb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 76,
#                 78,
#                 95,
#                 23,
#                 145,
#                 147,
#                 92
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 22,
#                 46,
#                 81,
#                 27,
#                 118,
#                 63,
#                 61
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8e22293e2a8249cb915cdea1d0b39abb.setOption(option_8e22293e2a8249cb915cdea1d0b39abb);
#         });
#     </script>

# %%
# 柱状图（横向）
bar.reversal_axis()
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d37c7bfb2caf4e1698a4d95ddccc4353" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d37c7bfb2caf4e1698a4d95ddccc4353 = echarts.init(
#                     document.getElementById('d37c7bfb2caf4e1698a4d95ddccc4353'), 'white', {renderer: 'canvas'});
#                 var option_d37c7bfb2caf4e1698a4d95ddccc4353 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 76,
#                 78,
#                 95,
#                 23,
#                 145,
#                 147,
#                 92
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 22,
#                 46,
#                 81,
#                 27,
#                 118,
#                 63,
#                 61
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d37c7bfb2caf4e1698a4d95ddccc4353.setOption(option_d37c7bfb2caf4e1698a4d95ddccc4353);
#         });
#     </script>

# %%
# 象形柱状图
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType


location = ["山西", "四川", "西藏", "北京", "上海", "内蒙古", "云南", "黑龙江", "广东", "福建"]
values = [13, 42, 67, 81, 86, 94, 166, 220, 249, 262]

c = PictorialBar()
c.add_xaxis(location)
c.add_yaxis(
    "",
    values,
    label_opts=opts.LabelOpts(is_show=False),
    symbol_size=18,
    symbol_repeat="fixed",
    symbol_offset=[0, 0],
    is_symbol_clip=True,
    symbol=SymbolType.ROUND_RECT,
)
c.reversal_axis()
c.set_global_opts(
    title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量"),
    xaxis_opts=opts.AxisOpts(is_show=False),
    yaxis_opts=opts.AxisOpts(
        axistick_opts=opts.AxisTickOpts(is_show=False),
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(opacity=0)
        ),
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="acb4856bee8e42c295f5559165f710b7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_acb4856bee8e42c295f5559165f710b7 = echarts.init(
#                     document.getElementById('acb4856bee8e42c295f5559165f710b7'), 'white', {renderer: 'canvas'});
#                 var option_acb4856bee8e42c295f5559165f710b7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 13,
#                 42,
#                 67,
#                 81,
#                 86,
#                 94,
#                 166,
#                 220,
#                 249,
#                 262
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u897f",
#                 "\u56db\u5ddd",
#                 "\u897f\u85cf",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u798f\u5efa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_acb4856bee8e42c295f5559165f710b7.setOption(option_acb4856bee8e42c295f5559165f710b7);
#         });
#     </script>

# %%
# 散点图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Scatter


scatter = Scatter()
scatter.add_xaxis(Faker.choose())
scatter.add_yaxis("商家A", Faker.values())
scatter.set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4dd3f2f594cf443caa39c3eebefb3834" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4dd3f2f594cf443caa39c3eebefb3834 = echarts.init(
#                     document.getElementById('4dd3f2f594cf443caa39c3eebefb3834'), 'white', {renderer: 'canvas'});
#                 var option_4dd3f2f594cf443caa39c3eebefb3834 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     28
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     149
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     139
#                 ],
#                 [
#                     "\u7eff\u8336",
#                     72
#                 ],
#                 [
#                     "\u5976\u8336",
#                     142
#                 ],
#                 [
#                     "\u767e\u5a01",
#                     115
#                 ],
#                 [
#                     "\u9752\u5c9b",
#                     87
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4dd3f2f594cf443caa39c3eebefb3834.setOption(option_4dd3f2f594cf443caa39c3eebefb3834);
#         });
#     </script>

# %%
# 饼图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
pie = Pie()
pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3a3e18e2fafd435091fd72ee0f951c2d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3a3e18e2fafd435091fd72ee0f951c2d = echarts.init(
#                     document.getElementById('3a3e18e2fafd435091fd72ee0f951c2d'), 'white', {renderer: 'canvas'});
#                 var option_3a3e18e2fafd435091fd72ee0f951c2d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 23
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3a3e18e2fafd435091fd72ee0f951c2d.setOption(option_3a3e18e2fafd435091fd72ee0f951c2d);
#         });
#     </script>

# %%
# 箱线图
from pyecharts import options as opts
from pyecharts.charts import Boxplot


v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880]
    + [1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900]
    + [840, 830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760]
    + [910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870]
    + [870, 810, 740, 810, 940, 950, 800, 810, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"]).add_yaxis("A", c.prepare_data(v1)).add_yaxis(
    "B", c.prepare_data(v2)
)
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="939110ac5bf84c1199dbaf676264bc28" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_939110ac5bf84c1199dbaf676264bc28 = echarts.init(
#                     document.getElementById('939110ac5bf84c1199dbaf676264bc28'), 'white', {renderer: 'canvas'});
#                 var option_939110ac5bf84c1199dbaf676264bc28 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_939110ac5bf84c1199dbaf676264bc28.setOption(option_939110ac5bf84c1199dbaf676264bc28);
#         });
#     </script>

# %%
# 热力图
import random

from pyecharts.faker import  Faker
from pyecharts import options as opts
from pyecharts.charts import HeatMap


value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
heatmap = HeatMap()
heatmap.add_xaxis(Faker.clock)
heatmap.add_yaxis("series0", Faker.week, value)
heatmap.set_global_opts(
    title_opts=opts.TitleOpts(title="HeatMap-基本示例"),
    visualmap_opts=opts.VisualMapOpts(),
)
heatmap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b2207e1d47e147b8ae6a601fc09e11ff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b2207e1d47e147b8ae6a601fc09e11ff = echarts.init(
#                     document.getElementById('b2207e1d47e147b8ae6a601fc09e11ff'), 'white', {renderer: 'canvas'});
#                 var option_b2207e1d47e147b8ae6a601fc09e11ff = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     32
#                 ],
#                 [
#                     0,
#                     1,
#                     35
#                 ],
#                 [
#                     0,
#                     2,
#                     19
#                 ],
#                 [
#                     0,
#                     3,
#                     6
#                 ],
#                 [
#                     0,
#                     4,
#                     40
#                 ],
#                 [
#                     0,
#                     5,
#                     2
#                 ],
#                 [
#                     0,
#                     6,
#                     47
#                 ],
#                 [
#                     1,
#                     0,
#                     36
#                 ],
#                 [
#                     1,
#                     1,
#                     6
#                 ],
#                 [
#                     1,
#                     2,
#                     23
#                 ],
#                 [
#                     1,
#                     3,
#                     23
#                 ],
#                 [
#                     1,
#                     4,
#                     22
#                 ],
#                 [
#                     1,
#                     5,
#                     35
#                 ],
#                 [
#                     1,
#                     6,
#                     10
#                 ],
#                 [
#                     2,
#                     0,
#                     2
#                 ],
#                 [
#                     2,
#                     1,
#                     19
#                 ],
#                 [
#                     2,
#                     2,
#                     26
#                 ],
#                 [
#                     2,
#                     3,
#                     15
#                 ],
#                 [
#                     2,
#                     4,
#                     13
#                 ],
#                 [
#                     2,
#                     5,
#                     42
#                 ],
#                 [
#                     2,
#                     6,
#                     36
#                 ],
#                 [
#                     3,
#                     0,
#                     31
#                 ],
#                 [
#                     3,
#                     1,
#                     50
#                 ],
#                 [
#                     3,
#                     2,
#                     8
#                 ],
#                 [
#                     3,
#                     3,
#                     28
#                 ],
#                 [
#                     3,
#                     4,
#                     33
#                 ],
#                 [
#                     3,
#                     5,
#                     19
#                 ],
#                 [
#                     3,
#                     6,
#                     3
#                 ],
#                 [
#                     4,
#                     0,
#                     38
#                 ],
#                 [
#                     4,
#                     1,
#                     34
#                 ],
#                 [
#                     4,
#                     2,
#                     37
#                 ],
#                 [
#                     4,
#                     3,
#                     12
#                 ],
#                 [
#                     4,
#                     4,
#                     8
#                 ],
#                 [
#                     4,
#                     5,
#                     15
#                 ],
#                 [
#                     4,
#                     6,
#                     35
#                 ],
#                 [
#                     5,
#                     0,
#                     6
#                 ],
#                 [
#                     5,
#                     1,
#                     6
#                 ],
#                 [
#                     5,
#                     2,
#                     20
#                 ],
#                 [
#                     5,
#                     3,
#                     37
#                 ],
#                 [
#                     5,
#                     4,
#                     34
#                 ],
#                 [
#                     5,
#                     5,
#                     24
#                 ],
#                 [
#                     5,
#                     6,
#                     41
#                 ],
#                 [
#                     6,
#                     0,
#                     0
#                 ],
#                 [
#                     6,
#                     1,
#                     40
#                 ],
#                 [
#                     6,
#                     2,
#                     34
#                 ],
#                 [
#                     6,
#                     3,
#                     32
#                 ],
#                 [
#                     6,
#                     4,
#                     0
#                 ],
#                 [
#                     6,
#                     5,
#                     5
#                 ],
#                 [
#                     6,
#                     6,
#                     47
#                 ],
#                 [
#                     7,
#                     0,
#                     34
#                 ],
#                 [
#                     7,
#                     1,
#                     48
#                 ],
#                 [
#                     7,
#                     2,
#                     43
#                 ],
#                 [
#                     7,
#                     3,
#                     24
#                 ],
#                 [
#                     7,
#                     4,
#                     38
#                 ],
#                 [
#                     7,
#                     5,
#                     9
#                 ],
#                 [
#                     7,
#                     6,
#                     23
#                 ],
#                 [
#                     8,
#                     0,
#                     6
#                 ],
#                 [
#                     8,
#                     1,
#                     3
#                 ],
#                 [
#                     8,
#                     2,
#                     23
#                 ],
#                 [
#                     8,
#                     3,
#                     44
#                 ],
#                 [
#                     8,
#                     4,
#                     42
#                 ],
#                 [
#                     8,
#                     5,
#                     35
#                 ],
#                 [
#                     8,

# %%
# 漏斗图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Funnel, Page

f = Funnel()
f.add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
f.set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
f.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="85d930bf6e994aadb376c2edcada5832" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_85d930bf6e994aadb376c2edcada5832 = echarts.init(
#                     document.getElementById('85d930bf6e994aadb376c2edcada5832'), 'white', {renderer: 'canvas'});
#                 var option_85d930bf6e994aadb376c2edcada5832 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 63
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 60
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 78
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 90
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9b45\u65cf",
#                 "\u4e09\u661f",
#                 "\u82f9\u679c",
#                 "VIVO",
#                 "\u534e\u4e3a",
#                 "\u5c0f\u7c73",
#                 "OPPO"
#             ],
#             "selected": {
#                 "\u5c0f\u7c73": true,
#                 "\u4e09\u661f": true,
#                 "\u534e\u4e3a": true,
#                 "\u82f9\u679c": true,
#                 "\u9b45\u65cf": true,
#                 "VIVO": true,
#                 "OPPO": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_85d930bf6e994aadb376c2edcada5832.setOption(option_85d930bf6e994aadb376c2edcada5832);
#         });
#     </script>

# %%
# 词云图
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
words = [
    ("Sam S Club", 10000), ("Macys", 6181), ("Amy Schumer", 4386),
    ("Jurassic World", 4055), ("Charter Communications", 2467),
    ("Chick Fil A", 2244), ("Planet Fitness", 1868),
    ("Pitch Perfect", 1484), ("Express", 1112),
    ("Home", 865), ("Johnny Depp", 847),
    ("Lena Dunham", 582), ("Lewis Hamilton", 555),
    ("KXAN", 550), ("Mary Ellen Mark", 462),
    ("Farrah Abraham", 366), ("Rita Ora", 360),
    ("Serena Williams", 282), ("NCAA baseball tournament", 273),
    ("Point Break", 265),
]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="dc973e14eda845b581d5cb9cbddb0c97" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_dc973e14eda845b581d5cb9cbddb0c97 = echarts.init(
#                     document.getElementById('dc973e14eda845b581d5cb9cbddb0c97'), 'white', {renderer: 'canvas'});
#                 var option_dc973e14eda845b581d5cb9cbddb0c97 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "Sam S Club",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,85,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Macys",
#                     "value": 6181,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,86,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Amy Schumer",
#                     "value": 4386,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,112,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Jurassic World",
#                     "value": 4055,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,24,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Charter Communications",
#                     "value": 2467,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,94,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Chick Fil A",
#                     "value": 2244,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,102,42)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Planet Fitness",
#                     "value": 1868,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(64,70,44)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Pitch Perfect",
#                     "value": 1484,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,36,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Express",
#                     "value": 1112,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,126,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Home",
#                     "value": 865,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,122,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Johnny Depp",
#                     "value": 847,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(62,140,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lena Dunham",
#                     "value": 582,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,135,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Lewis Hamilton",
#                     "value": 555,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,75,72)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "KXAN",
#                     "value": 550,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,26,35)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Mary Ellen Mark",
#                     "value": 462,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,3,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Farrah Abraham",
#                     "value": 366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(34,58,102)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Rita Ora",
#                     "value": 360,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(51,144,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Serena Williams",
#                     "value": 282,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,39,83)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "NCAA baseball tournament",
#                     "value": 273,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(144,44,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "Point Break",
#                     "value": 265,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,111,146)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "bord

# %%
# 仪表盘
from pyecharts import options as opts
from pyecharts.charts import Gauge, Page


g = Gauge()
g.add("", [("完成率", 66.6)])
g.set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
g.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6d7ab351b2d243568fa31fbce8a893b8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6d7ab351b2d243568fa31fbce8a893b8 = echarts.init(
#                     document.getElementById('6d7ab351b2d243568fa31fbce8a893b8'), 'white', {renderer: 'canvas'});
#                 var option_6d7ab351b2d243568fa31fbce8a893b8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "detail": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 66.6
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6d7ab351b2d243568fa31fbce8a893b8.setOption(option_6d7ab351b2d243568fa31fbce8a893b8);
#         });
#     </script>

# %%
# 水球图
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [0.6, 0.7])
l.set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="ca449c4582b94fc0934a1b9a0826949b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_ca449c4582b94fc0934a1b9a0826949b = echarts.init(
#                     document.getElementById('ca449c4582b94fc0934a1b9a0826949b'), 'white', {renderer: 'canvas'});
#                 var option_ca449c4582b94fc0934a1b9a0826949b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ca449c4582b94fc0934a1b9a0826949b.setOption(option_ca449c4582b94fc0934a1b9a0826949b);
#         });
#     </script>

# %%
# 日历图
import datetime
import random
from pyecharts import options as opts
from pyecharts.charts import Calendar

begin = datetime.date(2019, 1, 1)
end = datetime.date(2019, 12, 31)
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]
c = Calendar()
c.add("", data, calendar_opts=opts.CalendarOpts(range_="2019"))
c.set_global_opts(
    title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
    visualmap_opts=opts.VisualMapOpts(
        max_=20000,
        min_=500,
        orient="horizontal",
        is_piecewise=True,
        pos_top="230px",
        pos_left="100px",
    ),
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="845160e3fc2c40598ba09555efb42ad7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_845160e3fc2c40598ba09555efb42ad7 = echarts.init(
#                     document.getElementById('845160e3fc2c40598ba09555efb42ad7'), 'white', {renderer: 'canvas'});
#                 var option_845160e3fc2c40598ba09555efb42ad7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2019-01-01",
#                     18264
#                 ],
#                 [
#                     "2019-01-02",
#                     4711
#                 ],
#                 [
#                     "2019-01-03",
#                     8415
#                 ],
#                 [
#                     "2019-01-04",
#                     17644
#                 ],
#                 [
#                     "2019-01-05",
#                     22204
#                 ],
#                 [
#                     "2019-01-06",
#                     7035
#                 ],
#                 [
#                     "2019-01-07",
#                     15709
#                 ],
#                 [
#                     "2019-01-08",
#                     8316
#                 ],
#                 [
#                     "2019-01-09",
#                     2973
#                 ],
#                 [
#                     "2019-01-10",
#                     3394
#                 ],
#                 [
#                     "2019-01-11",
#                     14691
#                 ],
#                 [
#                     "2019-01-12",
#                     8926
#                 ],
#                 [
#                     "2019-01-13",
#                     19336
#                 ],
#                 [
#                     "2019-01-14",
#                     3360
#                 ],
#                 [
#                     "2019-01-15",
#                     11896
#                 ],
#                 [
#                     "2019-01-16",
#                     8055
#                 ],
#                 [
#                     "2019-01-17",
#                     21681
#                 ],
#                 [
#                     "2019-01-18",
#                     2610
#                 ],
#                 [
#                     "2019-01-19",
#                     17500
#                 ],
#                 [
#                     "2019-01-20",
#                     24287
#                 ],
#                 [
#                     "2019-01-21",
#                     6267
#                 ],
#                 [
#                     "2019-01-22",
#                     12643
#                 ],
#                 [
#                     "2019-01-23",
#                     2006
#                 ],
#                 [
#                     "2019-01-24",
#                     20969
#                 ],
#                 [
#                     "2019-01-25",
#                     11855
#                 ],
#                 [
#                     "2019-01-26",
#                     19762
#                 ],
#                 [
#                     "2019-01-27",
#                     4769
#                 ],
#                 [
#                     "2019-01-28",
#                     21015
#                 ],
#                 [
#                     "2019-01-29",
#                     16678
#                 ],
#                 [
#                     "2019-01-30",
#                     19733
#                 ],
#                 [
#                     "2019-01-31",
#                     20065
#                 ],
#                 [
#                     "2019-02-01",
#                     22564
#                 ],
#                 [
#                     "2019-02-02",
#                     18345
#                 ],
#                 [
#                     "2019-02-03",
#                     6150
#                 ],
#                 [
#                     "2019-02-04",
#                     17281
#                 ],
#                 [
#                     "2019-02-05",
#                     22153
#                 ],
#                 [
#                     "2019-02-06",
#                     12375
#                 ],
#                 [
#                     "2019-02-07",
#                     23825
#                 ],
#                 [
#                     "2019-02-08",
#                     12794
#                 ],
#                 [
#                     "2019-02-09",
#                     13118
#                 ],
#                 [
#                     "2019-02-10",
#                     15455
#                 ],
#                 [
#                     "2019-02-11",
#                     22062
#                 ],
#                 [
#                     "2019-02-12",
#                     23784
#                 ],
#                 [
#                     "2019-02-13",
#                     19141
#                 ],
#                 [
#                     "2019-02-14",
#                     23541
#                 ],
#                 [
#                     "2019-02-15",
#                     7641
#                 ],
#                 [
#                     "2019-02-16",
#                     3347
#                 ],
#                 [
#                     "2019-02-17",
#                     14139
#                 ],
#                 [
#                     "2019-02-18",
#                     24176
#                 ],
#                 [
#                     "2019-02-19",
#                     8944
#                 ],
#                 [
#                     "2019-02-20",
#                     11013
#                 ],
#                 [
#                     "2019-02-21",
#                     18909
#                 ],
#                 [
#                     "2019-02-22",
#                     4206
#                 ],
#                 [
#                     "2019-02-23",
#                     19673
#                 ],
#                 [
#                     "2019-02-24",
#                     11596
#                 ],
#                 [
#                     "2019-02-25",
#                     24154
#                 ],
#                 [
#                     "2019-02-26",
#                     16585
#                 ],
#                 [
#                     "2019-02-27",
#                     1461
#                 ],
#                 [
#                     "2019-02-28",
#                     2264
#                 ],
#                 [
#                     "2019-03-01",
#                     12911
#                 ],
#                 [
#                     "2019-03-02",
#                     11411
#                 ],
#                 [
#                     "2019-03-03",
#                     4451
#                 ],
#                 [
#                     "2019-03-04",
#                     16875
#                 ],
#                 [
#                     "2019-03-05",
#                     2153
#                 ],
#                 [
#                     "2019-03-06",
#                     23975
#                 ],
#                 [
#                     "2019-03-07",
#                     2290
#                 ],
#                 [
#                     "2019-03-08",
#                     18158
#                 ],
#                 [
#                     "2019-03-09",
#                     2062
#                 ],
#                 [

# %%
# 矩形树图
import json
import os
from pyecharts import options as opts
from pyecharts.charts import Page, TreeMap

data = [
    {"value": 40, "name": "我是A"},
    {
        "value": 180,
        "name": "我是B",
        "children": [{
            "value": 76,
            "name": "我是B.children",
            "children": [
                {"value": 12, "name": "我是B.children.a"},
                {"value": 28, "name": "我是B.children.b"},
                {"value": 20, "name": "我是B.children.c"},
                {"value": 16, "name": "我是B.children.d"},
            ],
        }],
    }]

c = TreeMap()
c.add("演示数据", data)
c.set_global_opts(title_opts=opts.TitleOpts(title="TreeMap-基本示例"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="567263fb209345c49f6d0202bb3077fd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_567263fb209345c49f6d0202bb3077fd = echarts.init(
#                     document.getElementById('567263fb209345c49f6d0202bb3077fd'), 'white', {renderer: 'canvas'});
#                 var option_567263fb209345c49f6d0202bb3077fd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "name": "\u6f14\u793a\u6570\u636e",
#             "data": [
#                 {
#                     "value": 40,
#                     "name": "\u6211\u662fA"
#                 },
#                 {
#                     "value": 180,
#                     "name": "\u6211\u662fB",
#                     "children": [
#                         {
#                             "value": 76,
#                             "name": "\u6211\u662fB.children",
#                             "children": [
#                                 {
#                                     "value": 12,
#                                     "name": "\u6211\u662fB.children.a"
#                                 },
#                                 {
#                                     "value": 28,
#                                     "name": "\u6211\u662fB.children.b"
#                                 },
#                                 {
#                                     "value": 20,
#                                     "name": "\u6211\u662fB.children.c"
#                                 },
#                                 {
#                                     "value": 16,
#                                     "name": "\u6211\u662fB.children.d"
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ],
#             "width": "80%",
#             "height": "80%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "drillDownIcon": "\u25b6",
#             "roam": true,
#             "nodeClick": "zoomToNode"
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6f14\u793a\u6570\u636e"
#             ],
#             "selected": {
#                 "\u6f14\u793a\u6570\u636e": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "TreeMap-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_567263fb209345c49f6d0202bb3077fd.setOption(option_567263fb209345c49f6d0202bb3077fd);
#         });
#     </script>

# %%
# 地图
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()
m.add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="f6bd1983ae3649138493bd12a1d51a10" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f6bd1983ae3649138493bd12a1d51a10 = echarts.init(
#                     document.getElementById('f6bd1983ae3649138493bd12a1d51a10'), 'white', {renderer: 'canvas'});
#                 var option_f6bd1983ae3649138493bd12a1d51a10 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 103
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 97
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 126
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 29
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_f6bd1983ae3649138493bd12a1d51a10.setOption(option_f6bd1983ae3649138493bd12a1d51a10);
#         });
#     </script>

# %% [markdown]
# # 定制主题

# %%
# 默认主题
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType

# 等价于 Bar(init_opts=opts.InitOpts(theme=ThemeType.WHITE))
c = Bar()
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("Theme-default"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7721f6318e1246ce92c64c6699ae4959" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7721f6318e1246ce92c64c6699ae4959 = echarts.init(
#                     document.getElementById('7721f6318e1246ce92c64c6699ae4959'), 'white', {renderer: 'canvas'});
#                 var option_7721f6318e1246ce92c64c6699ae4959 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 109,
#                 144,
#                 114,
#                 38,
#                 110,
#                 94,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 66,
#                 95,
#                 86,
#                 23,
#                 116,
#                 144,
#                 81
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 30,
#                 145,
#                 89,
#                 39,
#                 73,
#                 143,
#                 117
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 40,
#                 108,
#                 120,
#                 31,
#                 70,
#                 75,
#                 124
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Theme-default",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7721f6318e1246ce92c64c6699ae4959.setOption(option_7721f6318e1246ce92c64c6699ae4959);
#         });
#     </script>

# %%
# LIGHT主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("LIGHT主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="023300fc2f614ddaabd2a9e1b006bb6a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_023300fc2f614ddaabd2a9e1b006bb6a = echarts.init(
#                     document.getElementById('023300fc2f614ddaabd2a9e1b006bb6a'), 'light', {renderer: 'canvas'});
#                 var option_023300fc2f614ddaabd2a9e1b006bb6a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 140,
#                 146,
#                 140,
#                 140,
#                 59,
#                 33,
#                 24
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 39,
#                 66,
#                 39,
#                 105,
#                 145,
#                 72,
#                 78
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 90,
#                 107,
#                 22,
#                 78,
#                 20,
#                 40,
#                 133
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 56,
#                 87,
#                 31,
#                 43,
#                 47,
#                 34,
#                 87
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "LIGHT\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_023300fc2f614ddaabd2a9e1b006bb6a.setOption(option_023300fc2f614ddaabd2a9e1b006bb6a);
#         });
#     </script>

# %%
# DARK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("DARK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3df8fe865a4a4c7ebc279421eb7540ae" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3df8fe865a4a4c7ebc279421eb7540ae = echarts.init(
#                     document.getElementById('3df8fe865a4a4c7ebc279421eb7540ae'), 'dark', {renderer: 'canvas'});
#                 var option_3df8fe865a4a4c7ebc279421eb7540ae = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 38,
#                 71,
#                 106,
#                 48,
#                 33,
#                 49,
#                 37
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 99,
#                 56,
#                 61,
#                 40,
#                 129,
#                 42,
#                 73
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 68,
#                 74,
#                 88,
#                 89,
#                 56,
#                 26,
#                 71
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 147,
#                 104,
#                 146,
#                 126,
#                 79,
#                 39,
#                 112
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "DARK\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3df8fe865a4a4c7ebc279421eb7540ae.setOption(option_3df8fe865a4a4c7ebc279421eb7540ae);
#         });
#     </script>

# %%
# CHALK主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("CHALK主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#         <div id="dbe85fecd79746f2a160f489575c437a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'chalk'], function(echarts) {
#                 var chart_dbe85fecd79746f2a160f489575c437a = echarts.init(
#                     document.getElementById('dbe85fecd79746f2a160f489575c437a'), 'chalk', {renderer: 'canvas'});
#                 var option_dbe85fecd79746f2a160f489575c437a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 65,
#                 144,
#                 103,
#                 146,
#                 139,
#                 39,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 139,
#                 124,
#                 28,
#                 115,
#                 119,
#                 121,
#                 99
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 90,
#                 48,
#                 124,
#                 24,
#                 51,
#                 45,
#                 94
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 106,
#                 45,
#                 22,
#                 99,
#                 72,
#                 140,
#                 111
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "CHALK\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_dbe85fecd79746f2a160f489575c437a.setOption(option_dbe85fecd79746f2a160f489575c437a);
#         });
#     </script>

# %%
# ESSOS主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ESSOS))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ESSOS主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'essos':'https://assets.pyecharts.org/assets/themes/essos'
#         }
#     });
# </script>
#
#         <div id="da81b00ab44048c4aea10e608f62bc29" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'essos'], function(echarts) {
#                 var chart_da81b00ab44048c4aea10e608f62bc29 = echarts.init(
#                     document.getElementById('da81b00ab44048c4aea10e608f62bc29'), 'essos', {renderer: 'canvas'});
#                 var option_da81b00ab44048c4aea10e608f62bc29 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 108,
#                 24,
#                 33,
#                 37,
#                 85,
#                 120,
#                 68
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 102,
#                 124,
#                 135,
#                 102,
#                 140,
#                 83,
#                 128
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 38,
#                 86,
#                 145,
#                 119,
#                 31,
#                 35,
#                 133
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 37,
#                 97,
#                 113,
#                 127,
#                 40,
#                 98,
#                 149
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ESSOS\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_da81b00ab44048c4aea10e608f62bc29.setOption(option_da81b00ab44048c4aea10e608f62bc29);
#         });
#     </script>

# %%
# PURPLE_PASSION主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("PURPLE_PASSION主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="439bb32cede947e7bacf9b1286a7fb42" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_439bb32cede947e7bacf9b1286a7fb42 = echarts.init(
#                     document.getElementById('439bb32cede947e7bacf9b1286a7fb42'), 'purple-passion', {renderer: 'canvas'});
#                 var option_439bb32cede947e7bacf9b1286a7fb42 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 142,
#                 43,
#                 49,
#                 65,
#                 55,
#                 84,
#                 124
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 64,
#                 128,
#                 135,
#                 138,
#                 84,
#                 68,
#                 116
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 103,
#                 96,
#                 101,
#                 100,
#                 109,
#                 38,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 63,
#                 57,
#                 56,
#                 40,
#                 77,
#                 144,
#                 25
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "PURPLE_PASSION\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_439bb32cede947e7bacf9b1286a7fb42.setOption(option_439bb32cede947e7bacf9b1286a7fb42);
#         });
#     </script>

# %%
# ROMA主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("ROMA主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'roma':'https://assets.pyecharts.org/assets/themes/roma'
#         }
#     });
# </script>
#
#         <div id="0ea5989df2a243efbc4cead799e3e496" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_0ea5989df2a243efbc4cead799e3e496 = echarts.init(
#                     document.getElementById('0ea5989df2a243efbc4cead799e3e496'), 'roma', {renderer: 'canvas'});
#                 var option_0ea5989df2a243efbc4cead799e3e496 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 133,
#                 94,
#                 69,
#                 107,
#                 71,
#                 118,
#                 146
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 85,
#                 74,
#                 33,
#                 20,
#                 57,
#                 35,
#                 55
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 132,
#                 89,
#                 26,
#                 78,
#                 129,
#                 35,
#                 32
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 55,
#                 142,
#                 31,
#                 114,
#                 133,
#                 118,
#                 69
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "ROMA\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0ea5989df2a243efbc4cead799e3e496.setOption(option_0ea5989df2a243efbc4cead799e3e496);
#         });
#     </script>

# %%
# VINTAGE主题

c = Bar(init_opts=opts.InitOpts(theme=ThemeType.VINTAGE))
        
c.add_xaxis(Faker.choose())
c.add_yaxis("商家A", Faker.values())
c.add_yaxis("商家B", Faker.values())
c.add_yaxis("商家C", Faker.values())
c.add_yaxis("商家D", Faker.values())
c.set_global_opts(title_opts=opts.TitleOpts("VINTAGE主题"))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="c3a0a92c3fc2402f9118dac915ffaf6e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_c3a0a92c3fc2402f9118dac915ffaf6e = echarts.init(
#                     document.getElementById('c3a0a92c3fc2402f9118dac915ffaf6e'), 'vintage', {renderer: 'canvas'});
#                 var option_c3a0a92c3fc2402f9118dac915ffaf6e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 43,
#                 90,
#                 42,
#                 35,
#                 99,
#                 72,
#                 59
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 82,
#                 104,
#                 30,
#                 33,
#                 66,
#                 28,
#                 76
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 53,
#                 129,
#                 40,
#                 58,
#                 72,
#                 150,
#                 43
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 129,
#                 77,
#                 85,
#                 117,
#                 96,
#                 117,
#                 93
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "VINTAGE\u4e3b\u9898",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c3a0a92c3fc2402f9118dac915ffaf6e.setOption(option_c3a0a92c3fc2402f9118dac915ffaf6e);
#         });
#     </script>

# %% [markdown]
# # 实战项目一 - 见PPT

# %%
import pandas as pd
df = pd.read_csv("jobs.csv")
df.drop_duplicates(inplace=True)
df
# Out:
#                                                  title                company  \
# 0                                              招聘数据分析师           北京越铖国际科技有限公司
# 1                                                数据分析师      北京新东方教育科技（集团）有限公司
# 2                                            数据分析师(新浪)          新浪网技术(中国)有限公司
# 3                                                数据分析师         北京美科思远环境科技有限公司
# 4    助理、临床样本库采样人员、软件工程师、数据库管理工程师、机械设计与结构工程师、Android...  中国人民解放军总医院（北京市解放军医学院）
# ..                                                 ...                    ...
# 645                                      数据分析工程师(清控紫荆)     清控紫荆(北京)教育科技股份有限公司
# 646                  风险决策分析师-大数据方向009777(京东数字科技控股有限公司)           京东数字科技控股有限公司
# 647                                数据分析工程师（物流规划）(旷视科技)             北京旷视科技有限公司
# 648                       网络人工智能架构师大数据分析架构师(国内知名互联网企业)              国内知名互联网企业
# 649                             气象数据分析工程师(航天新气象科技有限公司)            航天新气象科技有限公司
#
#     company_size      industry type       salary company_type     source  \
# 0         20-99人    人事/行政/高级管理   全职   8000-12000           民营         斗米
# 1            NaN  计算机/互联网/信息技术   全职  12000-20000           民营  OFweek人才网
# 2     2000-5000人         数据分析师   全职  20000-25000     外商独资/办事处         猎聘
# 3         20-99人      环保/环境科学类   全职  12000-20000          股份制      北极星招聘
# 4            NaN            医疗   全职           面议         公立医院    康强医疗人才网
# ..           ...           ...  ...          ...          ...        ...
# 645       50-99人    其他互联网+技术职位   全职      25000以上           民营         猎聘
# 646   2000-5000人   能源/采掘/化工/环保   全职           面议     外商独资/办事处         猎聘
# 647   2000-5000人         数据分析师   全职           面议           民营         猎聘
# 648       50-99人        IT/互联网   全职      25000以上           民营         猎聘
# 649     100-499人         数据分析师   全职           面议           国企         猎聘
#
#     experience education  salary2
# 0           不限        不限  10000.0
# 1           不限        不限  16000.0
# 2         3-5年        本科  22500.0
# 3           不限        硕士  16000.0
# 4           不限        不限      NaN
# ..         ...       ...      ...
# 645       3-5年        本科  25000.0
# 646       3-5年        硕士      NaN
# 647       3-5年        本科      NaN
# 648      5-10年        本科  25000.0
# 649         不限        本科      NaN
#
# [650 rows x 11 columns]

# %%
# 统计各类规模的招聘公司的数量
from pyecharts.charts import Bar, Pie, Grid
from pyecharts import options as opts
s_size = df.company_size.value_counts()
bar = Bar()
bar.add_xaxis(s_size.index.tolist())
bar.add_yaxis("公司数量", s_size.values.tolist())
bar.set_global_opts(title_opts=opts.TitleOpts(title="各类规模的公司数量"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ae630fe47ad84a93ab399c38851c44a5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ae630fe47ad84a93ab399c38851c44a5 = echarts.init(
#                     document.getElementById('ae630fe47ad84a93ab399c38851c44a5'), 'white', {renderer: 'canvas'});
#                 var option_ae630fe47ad84a93ab399c38851c44a5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "data": [
#                 193,
#                 81,
#                 63,
#                 56,
#                 54,
#                 49,
#                 35,
#                 29,
#                 24,
#                 2,
#                 1,
#                 1
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "100-499\u4eba",
#                 "10000\u4eba\u4ee5\u4e0a",
#                 "500-999\u4eba",
#                 "50-99\u4eba",
#                 "2000-5000\u4eba",
#                 "1000-2000\u4eba",
#                 "5000-10000\u4eba",
#                 "20-99\u4eba",
#                 "1-49\u4eba",
#                 "\u5176\u5b83",
#                 "100",
#                 "1000-9999\u4eba"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5404\u7c7b\u89c4\u6a21\u7684\u516c\u53f8\u6570\u91cf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ae630fe47ad84a93ab399c38851c44a5.setOption(option_ae630fe47ad84a93ab399c38851c44a5);
#         });
#     </script>

# %%
# 统计职位来源
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_source = df["source"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_source.index.tolist(), s_source.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="职位来源"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="88f0e61714f64eee83781ad19f868ca9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_88f0e61714f64eee83781ad19f868ca9 = echarts.init(
#                     document.getElementById('88f0e61714f64eee83781ad19f868ca9'), 'white', {renderer: 'canvas'});
#                 var option_88f0e61714f64eee83781ad19f868ca9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u730e\u8058",
#                     "value": 580
#                 },
#                 {
#                     "name": "OFweek\u4eba\u624d\u7f51",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u6597\u7c73",
#                     "value": 17
#                 },
#                 {
#                     "name": "\u5317\u6781\u661f\u62db\u8058",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u767e\u59d3\u7f51",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u666e\u5de5\u62db\u8058\u7f51",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5de5\u5382\u76f4\u8058\u7f51",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u730e\u8058",
#                 "OFweek\u4eba\u624d\u7f51",
#                 "\u6597\u7c73",
#                 "\u5317\u6781\u661f\u62db\u8058",
#                 "\u767e\u59d3\u7f51",
#                 "\u666e\u5de5\u62db\u8058\u7f51",
#                 "\u5de5\u5382\u76f4\u8058\u7f51",
#                 "\u5eb7\u5f3a\u533b\u7597\u4eba\u624d\u7f51"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u804c\u4f4d\u6765\u6e90",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_88f0e61714f64eee83781ad19f868ca9.setOption(option_88f0e61714f64eee83781ad19f868ca9);
#         });
#     </script>

# %%
# 统计工作年限要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_exp = df["experience"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_exp.index.tolist(), s_exp.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="工作年限要求"),
                   legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34814881f5f841208ee3e00e2518043d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34814881f5f841208ee3e00e2518043d = echarts.init(
#                     document.getElementById('34814881f5f841208ee3e00e2518043d'), 'white', {renderer: 'canvas'});
#                 var option_34814881f5f841208ee3e00e2518043d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "3-5\u5e74",
#                     "value": 232
#                 },
#                 {
#                     "name": "1-3\u5e74",
#                     "value": 197
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 142
#                 },
#                 {
#                     "name": "5-10\u5e74",
#                     "value": 75
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a",
#                     "value": 4
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "3-5\u5e74",
#                 "1-3\u5e74",
#                 "\u4e0d\u9650",
#                 "5-10\u5e74",
#                 "10\u5e74\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5de5\u4f5c\u5e74\u9650\u8981\u6c42",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_34814881f5f841208ee3e00e2518043d.setOption(option_34814881f5f841208ee3e00e2518043d);
#         });
#     </script>

# %%
# 统计学历背景要求
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_edu = df["education"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_edu.index.tolist(), s_edu.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="学历背景要求"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ea327eb592254644a9c38abd263deacf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ea327eb592254644a9c38abd263deacf = echarts.init(
#                     document.getElementById('ea327eb592254644a9c38abd263deacf'), 'white', {renderer: 'canvas'});
#                 var option_ea327eb592254644a9c38abd263deacf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u672c\u79d1",
#                     "value": 489
#                 },
#                 {
#                     "name": "\u4e0d\u9650",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u7855\u58eb",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5927\u4e13",
#                     "value": 26
#                 },
#                 {
#                     "name": "\u521d\u4e2d",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u535a\u58eb",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u672c\u79d1",
#                 "\u4e0d\u9650",
#                 "\u7855\u58eb",
#                 "\u5927\u4e13",
#                 "\u521d\u4e2d",
#                 "\u535a\u58eb"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5b66\u5386\u80cc\u666f\u8981\u6c42",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ea327eb592254644a9c38abd263deacf.setOption(option_ea327eb592254644a9c38abd263deacf);
#         });
#     </script>

# %%
# 统计不同工资段的分布
from pyecharts import options as opts
from pyecharts.charts import Page, Pie
s_salary = df["salary"].value_counts()
pie = Pie()
pie.add("", [list(z) for z in zip(s_salary.index.tolist(), s_salary.values.tolist())])
pie.set_global_opts(title_opts=opts.TitleOpts(title="不同工资段的分布"),
                    legend_opts=opts.LegendOpts(orient='vertical', pos_left="0%", pos_top="10%"))
pie.set_series_opts()
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8d0828f4122f49b091ed00176b3fc0ce" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8d0828f4122f49b091ed00176b3fc0ce = echarts.init(
#                     document.getElementById('8d0828f4122f49b091ed00176b3fc0ce'), 'white', {renderer: 'canvas'});
#                 var option_8d0828f4122f49b091ed00176b3fc0ce = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "8000-12000",
#                     "value": 191
#                 },
#                 {
#                     "name": "12000-20000",
#                     "value": 170
#                 },
#                 {
#                     "name": "\u9762\u8bae",
#                     "value": 104
#                 },
#                 {
#                     "name": "20000-25000",
#                     "value": 60
#                 },
#                 {
#                     "name": "25000\u4ee5\u4e0a",
#                     "value": 59
#                 },
#                 {
#                     "name": "5000-8000",
#                     "value": 46
#                 },
#                 {
#                     "name": "3000-5000",
#                     "value": 5
#                 },
#                 {
#                     "name": "5001-8000",
#                     "value": 5
#                 },
#                 {
#                     "name": "6000-8000",
#                     "value": 2
#                 },
#                 {
#                     "name": "5500-15000",
#                     "value": 1
#                 },
#                 {
#                     "name": "3000-6000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2800-3500",
#                     "value": 1
#                 },
#                 {
#                     "name": "9000-12000",
#                     "value": 1
#                 },
#                 {
#                     "name": "3150-5650",
#                     "value": 1
#                 },
#                 {
#                     "name": "2000-3000",
#                     "value": 1
#                 },
#                 {
#                     "name": "5500-12000",
#                     "value": 1
#                 },
#                 {
#                     "name": "2500-4000",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "8000-12000",
#                 "12000-20000",
#                 "\u9762\u8bae",
#                 "20000-25000",
#                 "25000\u4ee5\u4e0a",
#                 "5000-8000",
#                 "3000-5000",
#                 "5001-8000",
#                 "6000-8000",
#                 "5500-15000",
#                 "3000-6000",
#                 "2800-3500",
#                 "9000-12000",
#                 "3150-5650",
#                 "2000-3000",
#                 "5500-12000",
#                 "2500-4000"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "0%",
#             "top": "10%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0d\u540c\u5de5\u8d44\u6bb5\u7684\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8d0828f4122f49b091ed00176b3fc0ce.setOption(option_8d0828f4122f49b091ed00176b3fc0ce);
#         });
#     </script>

# %%
# 统计哪些公司工资最高
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType
import numpy as np

df_avgsalary = df.groupby("company")["salary2"].agg(avgsalary="mean")
df_avgsalary.dropna(how="any", inplace=True)
companies = list(zip(df_avgsalary.index.tolist(), df_avgsalary["avgsalary"].astype(np.uint16).tolist()))
wc = WordCloud()
wc.add("", companies, word_size_range=[20, 100])
wc.set_global_opts(title_opts=opts.TitleOpts(title="哪些公司工资最高"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="ff85fb20cc4249f59a64a2b0844e465c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_ff85fb20cc4249f59a64a2b0844e465c = echarts.init(
#                     document.getElementById('ff85fb20cc4249f59a64a2b0844e465c'), 'white', {renderer: 'canvas'});
#                 var option_ff85fb20cc4249f59a64a2b0844e465c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "xx\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,107,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e07\u5b66\u79d1\u6280(\u5317\u4eac)\u6709\u9650\u516c\u53f8",
#                     "value": 4000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,76,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u51b0\u9274\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,147,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5357\u71d5\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 6500,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,102,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u53f8\u7fbd\u901a\u4fe1\u8bbe\u5907\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,148,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u60a6\u6613\u7f51\u7edc\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,110,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6295\u4e2d\u4fe1\u606f\u54a8\u8be2\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,145,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u65ed\u626c\u822a\u8fd0\u670d\u52a1\u6709\u9650\u516c\u53f814",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,79,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6ca3\u77f3\u6570\u636e\u670d\u52a1\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(38,27,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u6dc7\u6bd3\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 16000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(99,79,86)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u70db\u9f99\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,137,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79d1\u65ed\u7f51\u7edc\u79d1\u6280\u80a1\u4efd\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,59,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u79fb\u8bfa\u56fd\u9645\u7269\u6d41\u6709\u9650\u516c\u53f813",
#                     "value": 7000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(100,158,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8054\u851a\u4fe1\u606f\u79d1\u6280\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(70,77,115)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u8c6b\u8f89\u8d27\u7269\u8fd0\u8f93\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(78,140,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u91d1\u606a\u4f01\u4e1a\u7ba1\u7406\u54a8\u8be2\u6709\u9650\u516c\u53f8",
#                     "value": 13000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,27,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u94f8\u5ca9\u4fe1\u606f\u6280\u672f\u6709\u9650\u516c\u53f8",
#                     "value": 25000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,118,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u9877\u6167\u7269\u6d41\u6709\u9650\u516c\u53f8",
#                     "value": 10000,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,47,45)"
#                         }
#                     }
#                 },

# %%
# 统计各类型公司的数量
from pyecharts import options as opts
from pyecharts.charts import Page, PictorialBar
from pyecharts.globals import SymbolType

s_comptype = df["company_type"].value_counts(ascending=True)


companies = s_comptype.index.tolist()
comptypes = s_comptype.values.tolist()

c = PictorialBar()
c.add_xaxis(companies)
c.add_yaxis(
            "",
            comptypes,
            label_opts=opts.LabelOpts(is_show=False),
            symbol_size=18,
            symbol_repeat="fixed",
            symbol_offset=[0, 0],
            is_symbol_clip=True,
            symbol=SymbolType.ROUND_RECT,
        )
c.reversal_axis()
c.set_global_opts(
            title_opts=opts.TitleOpts(title="公司类型"),
            xaxis_opts=opts.AxisOpts(is_show=False),
            yaxis_opts=opts.AxisOpts(
                axistick_opts=opts.AxisTickOpts(is_show=False),
                axisline_opts=opts.AxisLineOpts(
                    linestyle_opts=opts.LineStyleOpts(opacity=0)
                ),
            ),
        )
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2e8afbc7a77146128cdf17ed642d3fe4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2e8afbc7a77146128cdf17ed642d3fe4 = echarts.init(
#                     document.getElementById('2e8afbc7a77146128cdf17ed642d3fe4'), 'white', {renderer: 'canvas'});
#                 var option_2e8afbc7a77146128cdf17ed642d3fe4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "roundRect",
#             "symbolSize": 18,
#             "symbolOffset": [
#                 0,
#                 0
#             ],
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "data": [
#                 1,
#                 1,
#                 1,
#                 2,
#                 4,
#                 34,
#                 42,
#                 45,
#                 62,
#                 458
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u80a1\u4efd\u5236",
#                 "\u516c\u7acb\u533b\u9662",
#                 "\u5176\u5b83",
#                 "\u4e2a\u4eba\u4f01\u4e1a",
#                 "\u4e8b\u4e1a\u5355\u4f4d",
#                 "\u56fd\u4f01",
#                 "\u4e2d\u5916\u5408\u8d44/\u5408\u4f5c",
#                 "\u5916\u5546\u72ec\u8d44/\u529e\u4e8b\u5904",
#                 "\u4e0a\u5e02\u516c\u53f8",
#                 "\u6c11\u8425"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u516c\u53f8\u7c7b\u578b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2e8afbc7a77146128cdf17ed642d3fe4.setOption(option_2e8afbc7a77146128cdf17ed642d3fe4);
#         });
#     </script>

# %% [markdown]
# # 实战项目二 - 见PPT

# %%
df = pd.read_csv("stocks.csv")
df.head()
# Out:
#    name industry area      pe  outstanding  totals  totalAssets  liquidAssets  \
# 0   N有方     软件服务   深圳  134.49         0.19    0.92         8.03          6.18
# 1   N泽璟     化学制药   江苏    0.00         0.55    2.40         2.97          1.17
# 2  N玉禾田     环境保护   安徽   18.46         0.35    1.38        24.84         14.23
# 3  热景生物     医疗保健   北京  251.27         0.14    0.62         6.98          5.45
# 4  鲁抗医药     化学制药   山东   73.98         8.52    8.80        70.58         27.59
#
#    fixedAssets  reserved  ...   bvps    pb  timeToMarket  undp  perundp  \
# 0         0.06      2.82  ...   9.81  5.77      20200123  1.23     1.34
# 1         0.56      2.86  ...   8.20  9.10      20200123 -4.09    -1.70
# 2         5.47      0.28  ...  13.60  3.13      20200123  7.88     5.70
# 3         1.25      4.46  ...  10.04  7.09      20190930  1.06     1.71
# 4        22.30     16.25  ...   3.42  3.33      19970226  3.51     0.40
#
#      rev  profit    gpr   npr   holders
# 0   0.00    0.00  22.88  5.66   19486.0
# 1   0.00    0.00   0.00  0.00   36598.0
# 2   0.00    0.00  21.73  9.09   68996.0
# 3   0.00    0.00  72.54  9.60   10316.0
# 4  15.07  -29.42  28.21  3.72  112796.0
#
# [5 rows x 22 columns]

# %%
# 计算市盈率中位数
df.pe.median()
# Out:
# 28.58

# %%
# 盈利能力排名
df_company = df[df.pe>0][["name", "pe", "pb"]].sort_values("pe").head(10)

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_company.name.values.tolist())
bar.add_yaxis("市盈率", df_company.pe.values.tolist())
bar.add_yaxis("市净率", df_company.pb.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="市盈率"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="32e352cae92a4cd286c455bc0089c18d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_32e352cae92a4cd286c455bc0089c18d = echarts.init(
#                     document.getElementById('32e352cae92a4cd286c455bc0089c18d'), 'white', {renderer: 'canvas'});
#                 var option_32e352cae92a4cd286c455bc0089c18d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5e02\u76c8\u7387",
#             "data": [
#                 2.74,
#                 2.75,
#                 3.05,
#                 4.11,
#                 4.13,
#                 4.26,
#                 4.3,
#                 4.39,
#                 4.52,
#                 4.63
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e02\u51c0\u7387",
#             "data": [
#                 1.08,
#                 1.23,
#                 1.07,
#                 1.04,
#                 0.9,
#                 0.72,
#                 1.14,
#                 0.6,
#                 0.87,
#                 0.57
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e02\u76c8\u7387",
#                 "\u5e02\u51c0\u7387"
#             ],
#             "selected": {
#                 "\u5e02\u76c8\u7387": true,
#                 "\u5e02\u51c0\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u795e\u706b\u80a1\u4efd",
#                 "\u6d59\u6c5f\u5e7f\u53a6",
#                 "\u65b0\u96c6\u80fd\u6e90",
#                 "\u5e7f\u5b87\u53d1\u5c55",
#                 "\u534e\u83f1\u94a2\u94c1",
#                 "\u65b0\u94a2\u80a1\u4efd",
#                 "\u4e94\u6d32\u4ea4\u901a",
#                 "\u6c11\u751f\u94f6\u884c",
#                 "\u5357\u94a2\u80a1\u4efd",
#                 "ST\u8f85\u4ec1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5e02\u76c8\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_32e352cae92a4cd286c455bc0089c18d.setOption(option_32e352cae92a4cd286c455bc0089c18d);
#         });
#     </script>

# %%
# 各地区公司数量
df_num = df.groupby("area")["name"].agg(company_num="count")

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Map
m = Map()

m.add("公司数量", [list(z) for z in zip(df_num.index.values.tolist(), df_num.company_num.values.tolist())], "china")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(max_=500, is_piecewise=True),
)
m.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="1f9ccecd8b234d858a99ee8a7593b2c6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_1f9ccecd8b234d858a99ee8a7593b2c6 = echarts.init(
#                     document.getElementById('1f9ccecd8b234d858a99ee8a7593b2c6'), 'white', {renderer: 'canvas'});
#                 var option_1f9ccecd8b234d858a99ee8a7593b2c6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u516c\u53f8\u6570\u91cf",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 305
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5185\u8499",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 348
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 125
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 209
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 323
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 429
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 464
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 302
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 141
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 53
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u53f8\u6570\u91cf"
#             ],
#             "selected": {
#                 "\u516c\u53f8\u6570\u91cf": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 500,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_1f9ccecd8b234d858a99ee8a7593b2c6.setOption(option_1f9ccecd8b234d858a99ee8a7593b2c6);
#         });
#     </script>

# %%
# 净利润率和毛利率中位数
npr = df["npr"].median()/100
gpr = df["gpr"].median()/100

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid, Page
from pyecharts.globals import SymbolType

l = Liquid()
l.add("lq", [gpr, npr])
l.set_global_opts(title_opts=opts.TitleOpts(title="利润率"))
l.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="3143e2bd1b2145d3a76611d31368bcd4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_3143e2bd1b2145d3a76611d31368bcd4 = echarts.init(
#                     document.getElementById('3143e2bd1b2145d3a76611d31368bcd4'), 'white', {renderer: 'canvas'});
#                 var option_3143e2bd1b2145d3a76611d31368bcd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.2718,
#                 0.0738
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "outline": {
#                 "show": true
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5229\u6da6\u7387",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3143e2bd1b2145d3a76611d31368bcd4.setOption(option_3143e2bd1b2145d3a76611d31368bcd4);
#         });
#     </script>

# %%
df_npr = df.groupby("industry")["npr"].agg(avg_npr="mean").sort_values("avg_npr", ascending=False)
df_top = df_npr.head(10)
df_top["avg_npr"] = df_top["avg_npr"].apply(lambda x: float("{:.2f}".format(x)))
df_top
# Out:
# C:\Users\linushen\Documents\15DaysPython\Anaconda\install\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           avg_npr
# industry
# 证券         238.11
# 多元金融        65.45
# 路桥          43.23
# 水力发电        41.61
# 保险          39.60
# 影视音像        36.98
# 银行          34.50
# 商品城         30.27
# 机场          26.31
# 园区开发        25.26

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

bar = Bar()
bar.add_xaxis(df_top.index.tolist())
bar.add_yaxis("净利润率", df_top.avg_npr.values.tolist())

bar.set_global_opts(title_opts=opts.TitleOpts(title="净利润率排名"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d61a2667c4704b678189b812ea03bbcf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d61a2667c4704b678189b812ea03bbcf = echarts.init(
#                     document.getElementById('d61a2667c4704b678189b812ea03bbcf'), 'white', {renderer: 'canvas'});
#                 var option_d61a2667c4704b678189b812ea03bbcf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u51c0\u5229\u6da6\u7387",
#             "data": [
#                 238.11,
#                 65.45,
#                 43.23,
#                 41.61,
#                 39.6,
#                 36.98,
#                 34.5,
#                 30.27,
#                 26.31,
#                 25.26
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51c0\u5229\u6da6\u7387"
#             ],
#             "selected": {
#                 "\u51c0\u5229\u6da6\u7387": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8bc1\u5238",
#                 "\u591a\u5143\u91d1\u878d",
#                 "\u8def\u6865",
#                 "\u6c34\u529b\u53d1\u7535",
#                 "\u4fdd\u9669",
#                 "\u5f71\u89c6\u97f3\u50cf",
#                 "\u94f6\u884c",
#                 "\u5546\u54c1\u57ce",
#                 "\u673a\u573a",
#                 "\u56ed\u533a\u5f00\u53d1"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u51c0\u5229\u6da6\u7387\u6392\u540d",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d61a2667c4704b678189b812ea03bbcf.setOption(option_d61a2667c4704b678189b812ea03bbcf);
#         });
#     </script>

# %%
# 各行业公司数量
df_industry = df.groupby("industry")["name"].agg(company_num="count")

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

words = [list(z) for z in zip(df_industry.index.values.tolist(), df_industry.company_num.values.tolist())]
wc = WordCloud()
wc.add("", words, word_size_range=[20, 100], shape="diamond")
wc.set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-基本示例"))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="04e60e3d0732483ea276836165885ad2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_04e60e3d0732483ea276836165885ad2 = echarts.init(
#                     document.getElementById('04e60e3d0732483ea276836165885ad2'), 'white', {renderer: 'canvas'});
#                 var option_04e60e3d0732483ea276836165885ad2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "IT\u8bbe\u5907",
#                     "value": 37,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,68,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e13\u7528\u673a\u68b0",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,120,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u6210\u836f",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,158,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e73\u5236\u54c1",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,114,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 72,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,105,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ed3\u50a8\u7269\u6d41",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,160,1)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f9b\u6c14\u4f9b\u70ed",
#                     "value": 29,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,122,153)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4fdd\u9669",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,122,31)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5143\u5668\u4ef6",
#                     "value": 183,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(82,136,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5168\u56fd\u5730\u4ea7",
#                     "value": 35,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,64,142)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5171\u4ea4\u901a",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,122,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u8def",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,96,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5546\u4e1a",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,17,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u5efa\u6750",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,112,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u4e1a\u7efc\u5408",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,112,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u7528\u673a\u68b0",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(89,23,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u519c\u836f\u5316\u80a5",
#                     "value": 43,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,4,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u7248\u4e1a",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,12,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5b66\u5236\u836f",
#                     "value": 104,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,11,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u539f\u6599",
#                     "value": 164,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,28,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u5de5\u673a\u68b0",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,97,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5316\u7ea4",

# %% [markdown]
# # 实战项目三 - 见PPT

# %%
df = pd.read_csv("houses.csv", sep='>', index_col=0)
df = df.drop_duplicates(["title", "price",
                    "xiaoqu_name", "size",
                    "buildyear", "huxing",
                    "chaoxiang", "zhuangxiu",
                    "cenggao", "district_name",
                    "sub_district_name"])
df.head(2)
# Out:
#                         _id                        title  price  up_price  \
# 0  5dd2198f18bba2b4a9a0b854     大华电梯两房/房型正气/开门南北通/房东诚意出售  690.0   76531.0
# 1  5dd2198f18bba2b4a9a0b855  非底楼 满五年唯一 税费少 婚房装修 楼称佳 户型方正  330.0   52290.0
#
#          xiaoqu_name   size  buildyear huxing chaoxiang zhuangxiu  \
# 0  大华锦绣华城(十六街区)(公寓)   90.16       2010  2室2厅         南        简装
# 1               芳雅苑   63.11       1995  2室1厅         南        精装
#
#        cenggao louxing district_name sub_district_name
# 0   中楼层(共18层)       板楼            浦东                北蔡
# 1    低楼层(共6层)       板楼            浦东                北蔡

# %%
# 每个区的均价
df_avg = df.groupby("district_name")["up_price"].agg(avg_price="mean").sort_index().sort_values("avg_price")

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = Bar()
avg_price = np.round(df_avg.avg_price.values).tolist()
bar.add_xaxis(df_avg.index.values.tolist())
bar.add_yaxis("均价", avg_price)

bar.set_global_opts(title_opts=opts.TitleOpts(title="上海各区均价"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b7395057c2b54a20bf1388ebbc325bc4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b7395057c2b54a20bf1388ebbc325bc4 = echarts.init(
#                     document.getElementById('b7395057c2b54a20bf1388ebbc325bc4'), 'white', {renderer: 'canvas'});
#                 var option_b7395057c2b54a20bf1388ebbc325bc4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5747\u4ef7",
#             "data": [
#                 19382.0,
#                 23728.0,
#                 36142.0,
#                 36309.0,
#                 37088.0,
#                 42185.0,
#                 49007.0,
#                 55620.0,
#                 58060.0,
#                 62052.0,
#                 66926.0,
#                 72458.0,
#                 75622.0,
#                 75852.0,
#                 96033.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5747\u4ef7"
#             ],
#             "selected": {
#                 "\u5747\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u91d1\u5c71",
#                 "\u5949\u8d24",
#                 "\u5609\u5b9a",
#                 "\u677e\u6c5f",
#                 "\u9752\u6d66",
#                 "\u5b9d\u5c71",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c",
#                 "\u666e\u9640",
#                 "\u6768\u6d66",
#                 "\u8679\u53e3",
#                 "\u957f\u5b81",
#                 "\u9759\u5b89",
#                 "\u5f90\u6c47",
#                 "\u9ec4\u6d66"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u5747\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b7395057c2b54a20bf1388ebbc325bc4.setOption(option_b7395057c2b54a20bf1388ebbc325bc4);
#         });
#     </script>

# %%
# 房源在各个区的分布情况
df_district = df.groupby("district_name")["price"].agg(house_num="count").sort_values(by="house_num")

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
pie = Pie()
districts = df_district.index.values.tolist()
values = df_district.house_num.values.tolist()
pie.add("", [list(z) for z in zip(districts, values)])
pie.set_global_opts(
    title_opts=opts.TitleOpts(title="房源分布"),
    legend_opts=opts.LegendOpts(orient="verticle", pos_right=20))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="40cfa0f8381b426ca9c53d50e32b83dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_40cfa0f8381b426ca9c53d50e32b83dd = echarts.init(
#                     document.getElementById('40cfa0f8381b426ca9c53d50e32b83dd'), 'white', {renderer: 'canvas'});
#                 var option_40cfa0f8381b426ca9c53d50e32b83dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91d1\u5c71",
#                     "value": 925
#                 },
#                 {
#                     "name": "\u9752\u6d66",
#                     "value": 1660
#                 },
#                 {
#                     "name": "\u5949\u8d24",
#                     "value": 2072
#                 },
#                 {
#                     "name": "\u9ec4\u6d66",
#                     "value": 2100
#                 },
#                 {
#                     "name": "\u8679\u53e3",
#                     "value": 2324
#                 },
#                 {
#                     "name": "\u957f\u5b81",
#                     "value": 3679
#                 },
#                 {
#                     "name": "\u5609\u5b9a",
#                     "value": 4059
#                 },
#                 {
#                     "name": "\u9759\u5b89",
#                     "value": 4429
#                 },
#                 {
#                     "name": "\u666e\u9640",
#                     "value": 4555
#                 },
#                 {
#                     "name": "\u5f90\u6c47",
#                     "value": 4556
#                 },
#                 {
#                     "name": "\u677e\u6c5f",
#                     "value": 4669
#                 },
#                 {
#                     "name": "\u6768\u6d66",
#                     "value": 4872
#                 },
#                 {
#                     "name": "\u5b9d\u5c71",
#                     "value": 5145
#                 },
#                 {
#                     "name": "\u95f5\u884c",
#                     "value": 9853
#                 },
#                 {
#                     "name": "\u6d66\u4e1c",
#                     "value": 18726
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u5c71",
#                 "\u9752\u6d66",
#                 "\u5949\u8d24",
#                 "\u9ec4\u6d66",
#                 "\u8679\u53e3",
#                 "\u957f\u5b81",
#                 "\u5609\u5b9a",
#                 "\u9759\u5b89",
#                 "\u666e\u9640",
#                 "\u5f90\u6c47",
#                 "\u677e\u6c5f",
#                 "\u6768\u6d66",
#                 "\u5b9d\u5c71",
#                 "\u95f5\u884c",
#                 "\u6d66\u4e1c"
#             ],
#             "selected": {},
#             "show": true,
#             "right": 20,
#             "orient": "verticle",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u623f\u6e90\u5206\u5e03",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_40cfa0f8381b426ca9c53d50e32b83dd.setOption(option_40cfa0f8381b426ca9c53d50e32b83dd);
#         });
#     </script>

# %%
# 房源的装修情况
df_zhuangxiu = df[df.zhuangxiu!=""].groupby("zhuangxiu")["price"].agg(house_num="count").sort_values(by="house_num")

# %%
zhuangxiu = df_zhuangxiu.index.values.tolist()
house_num = df_zhuangxiu.house_num.values.tolist()

from pyecharts import options as opts
from pyecharts.charts import Pie
pie = Pie()
pie.add("", [list(z) for z in zip(zhuangxiu, house_num)])
pie.set_global_opts(title_opts=opts.TitleOpts(title="装修"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1b894f2c501e46bc99a6eae1bf30276c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1b894f2c501e46bc99a6eae1bf30276c = echarts.init(
#                     document.getElementById('1b894f2c501e46bc99a6eae1bf30276c'), 'white', {renderer: 'canvas'});
#                 var option_1b894f2c501e46bc99a6eae1bf30276c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": " \u6bdb\u576f ",
#                     "value": 5720
#                 },
#                 {
#                     "name": " \u5176\u4ed6 ",
#                     "value": 5832
#                 },
#                 {
#                     "name": " \u7b80\u88c5 ",
#                     "value": 24233
#                 },
#                 {
#                     "name": " \u7cbe\u88c5 ",
#                     "value": 34319
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 " \u6bdb\u576f ",
#                 " \u5176\u4ed6 ",
#                 " \u7b80\u88c5 ",
#                 " \u7cbe\u88c5 "
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u88c5\u4fee",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_1b894f2c501e46bc99a6eae1bf30276c.setOption(option_1b894f2c501e46bc99a6eae1bf30276c);
#         });
#     </script>

# %%
# 用地图展现每个区房价
from pyecharts import options as opts
from pyecharts.charts import Map

districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
avg_price = np.round(df_avg.avg_price.values).tolist()
print(districts)
print(avg_price)
m = Map()
m.add("房价", [list(z) for z in zip(districts, avg_price)], "上海")
m.set_global_opts(
    title_opts=opts.TitleOpts(title="上海各区房价"),
    visualmap_opts=opts.VisualMapOpts(max_=100000, is_piecewise=True),
)
m.render_notebook()
# Out:
# ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']
# [19382.0, 23728.0, 36142.0, 36309.0, 37088.0, 42185.0, 49007.0, 55620.0, 58060.0, 62052.0, 66926.0, 72458.0, 75622.0, 75852.0, 96033.0]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="aa5cc990de904335bd6c83a25c0eb6dd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_aa5cc990de904335bd6c83a25c0eb6dd = echarts.init(
#                     document.getElementById('aa5cc990de904335bd6c83a25c0eb6dd'), 'white', {renderer: 'canvas'});
#                 var option_aa5cc990de904335bd6c83a25c0eb6dd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u623f\u4ef7",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 19382.0
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 23728.0
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 36142.0
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 36309.0
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 37088.0
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 42185.0
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 49007.0
#                 },
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": 55620.0
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 58060.0
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": 62052.0
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 66926.0
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": 72458.0
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": 75622.0
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": 75852.0
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": 96033.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u623f\u4ef7"
#             ],
#             "selected": {
#                 "\u623f\u4ef7": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u623f\u4ef7",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_aa5cc990de904335bd6c83a25c0eb6dd.setOption(option_aa5cc990de904335bd6c83a25c0eb6dd);
#         });
#     </script>
